# %% [markdown]
# This is the initial notebook to explore the data and run the first models.

# %%
import pandas as pd
import numpy as np

from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
from sklearn.preprocessing import OneHotEncoder

from fastai.imports import *
from fastai.tabular.all import *

from numpy import random
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_log_error
from sklearn import metrics
from sklearn.model_selection import KFold, cross_val_score

import eli5
from eli5.sklearn import PermutationImportance

from scipy.stats import skew, norm
from catboost import CatBoostRegressor

# %%
test = pd.read_csv('test.csv')
sample = pd.read_csv('sample_submission.csv')
train = pd.read_csv('train.csv')

# %% [markdown]
# Based on initial analysis the train and test datasets have similar characteristics, so it will be easier to combine them for imputation and data analysis work.

# %%
train_test = pd.concat([train, test], ignore_index=True)

# %%
pd.isnull(train_test).sum()[pd.isnull(train_test).sum() > 0]
# Out:
# MSZoning           4
# LotFrontage      486
# Alley           2721
# Utilities          2
# Exterior1st        1
# Exterior2nd        1
# MasVnrType        24
# MasVnrArea        23
# BsmtQual          81
# BsmtCond          82
# BsmtExposure      82
# BsmtFinType1      79
# BsmtFinSF1         1
# BsmtFinType2      80
# BsmtFinSF2         1
# BsmtUnfSF          1
# TotalBsmtSF        1
# Electrical         1
# BsmtFullBath       2
# BsmtHalfBath       2
# KitchenQual        1
# Functional         2
# FireplaceQu     1420
# GarageType       157
# GarageYrBlt      159
# GarageFinish     159
# GarageCars         1
# GarageArea         1
# GarageQual       159
# GarageCond       159
# PoolQC          2909
# Fence           2348
# MiscFeature     2814
# SaleType           1
# SalePrice       1459
# dtype: int64

# %% [markdown]
# It looks like Alley, FireplaceQu, PoolQC, Fence and MiscFeature have significant numbers of missing data. So it will be best to eliminate those rows. There are a number of rows that have less than 5 rows with missing data. Since some of these are categorical and some are continuous data, their missing data will be replaced with the most frequent value.

# %%
drop_high_nan=['Alley','FireplaceQu','PoolQC','Fence','MiscFeature']
train_test=train_test.drop(drop_high_nan,axis=1)
small_nan_cols = ['MSZoning', 'Utilities', 'Exterior1st', 'Exterior2nd', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 
                  'TotalBsmtSF', 'Electrical', 'BsmtFullBath', 'BsmtHalfBath', 'KitchenQual', 'Functional', 'GarageCars', 
                  'GarageArea','SaleType', 'SaleCondition']
small_impute = SimpleImputer(strategy='most_frequent')
train_test[small_nan_cols] = pd.DataFrame(small_impute.fit_transform(train_test[small_nan_cols]),columns=small_nan_cols)

# %% [markdown]
# The following columns seem to have one value significantly larger than the rest, and it would probably be best to use the mode, or most common, value to feel each NaN value: MasVnrType, MasVnrArea, BsmtCond, BsmtExposure, BsmtFinType2, GarageType, GarageFinish, GarageQual, and GarageCond. That is represents 9 out of the 13 columns.
#
# BsmtQual has two values larger than the rest: Gd and TA. But it only has 2.8% NaNs, so simply using the mode might be good enough.
#
# GarageYrBlt has 59 NaNs out 2919 rows which is only 2%. It has a dispersed set of values, so it might be easiest just to have any NaNs have the same value as YearBuilt.
#
# BsmtFinType1 has only 2.7% value of NaNs, and most two of its largest values are GLQ and Unf. It might be easiest to use the mode here.
#
# LotFrontage has 486 NaNs out of 2919 rows which is a pretty high 16.7%. It has a dispersed range of values, but looking at its characteristics from the describe function above, it seems to have a pretty even distribution with a mean of 10,168 and a median of 9,453. So using the mean to fill in the NaNs seems reasonable. If it turns out this value has a high impact on the predictability of the SalePrice, then it might be good to revisit this assumption.

# %%
mode_cols = ['MasVnrType', 'MasVnrArea', 'BsmtCond', 'BsmtExposure', 'BsmtFinType2', 'GarageType', 'GarageFinish', 
             'GarageQual','GarageCond', 'BsmtQual', 'BsmtFinType1']
mode_impute = SimpleImputer(strategy='most_frequent')
train_test[mode_cols] = pd.DataFrame(mode_impute.fit_transform(train_test[mode_cols]),columns=mode_cols)
train_test['LotFrontage'].fillna((train_test['LotFrontage'].mean()), inplace=True)
train_test['GarageYrBlt'] = train_test['GarageYrBlt'].fillna(train_test['YearBuilt'])

# %%
pd.isnull(train_test).sum()[pd.isnull(train_test).sum() > 0]
# Out:
# SalePrice    1459
# dtype: int64

# %%
train_test['BsmtQual'].unique()
# Out:
# array(['Gd', 'TA', 'Ex', 'Fa'], dtype=object)

# %%
train_test['BsmtFinType1'].unique()
# Out:
# array(['GLQ', 'ALQ', 'Unf', 'Rec', 'BLQ', 'LwQ'], dtype=object)

# %%
train_test.BsmtQual = train_test.BsmtQual.replace({"Ex": 110, "Gd": 95, "TA": 85, "Fa": 75, "Po": 60, "NA": 0})

# %%
train_test.BsmtFinType1 = train_test.BsmtFinType1.replace({"GLQ": 6, "ALQ": 5, "BLQ": 4, "Rec": 3, "LwQ": 2, "Unf": 1,
                                                         "NA": 0})

# %% [markdown]
# It will be necessary to identify all the columns that have non-numeric object values and then convert them to numeric values.

# %%
obj_cols = list(train_test.select_dtypes(['object']).columns)
obj_cols
# Out:
# ['MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'KitchenQual',
#  'Functional',
#  'GarageType',
#  'GarageFinish',
#  'GarageCars',
#  'GarageArea',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'SaleType',
#  'SaleCondition']

# %%
for column in obj_cols:
     train_test[column] = pd.factorize(train_test[column], sort=True)[0]
# Out:
# C:\Users\tompe\anaconda3\lib\site-packages\pandas\core\algorithms.py:798: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   uniques = Index(uniques)

# %% [markdown]
# To create some new columns that might compound the effects of the existing columns with higher impact on the xgb score.

# %%
train_test['QualCondSum'] = train_test['OverallQual'] + train_test['OverallCond']
train_test['RemodTime'] = train_test['YearRemodAdd'] - train_test['YearBuilt']
train_test['BsmtFinTypeSF1'] = train_test['BsmtFinType1'] * train_test['BsmtFinSF1']
train_test['TotalFlrSF'] = train_test['1stFlrSF'] + train_test['2ndFlrSF']
train_test['TotalFinSF'] = train_test['GrLivArea'] + train_test['BsmtFinSF1']
train_test['GarageCarArea'] = train_test['GarageArea'] * train_test['GarageCars']
train_test['TotalSF'] = train_test['1stFlrSF'] + train_test['2ndFlrSF'] + train_test['TotalBsmtSF']

# %% [markdown]
# To now eliminate the columns that have negative or zero influence on the xgb score.

# %%
train_test.drop(['Utilities','Street','TotRmsAbvGrd','3SsnPorch','YrSold','Exterior2nd','LotConfig',
                              'HouseStyle','EnclosedPorch','WoodDeckSF','Foundation','RoofMatl','Electrical',
                              'GarageType','LotFrontage','SaleType','MoSold','BsmtExposure','1stFlrSF',
                              'BsmtFinSF1','Exterior1st','KitchenQual','TotalFlrSF'], axis=1, inplace=True)

# %% [markdown]
# To look at how many features have a skew above 0.5, since high skew can be an issue in regression analysis.

# %%
skew_features = train_test.apply(lambda x: skew(x)).sort_values(ascending=False)

# %%
high_skew = skew_features[skew_features > 0.5]
skew_index = high_skew.index

# %%
skew_index
# Out:
# Index(['MiscVal', 'PoolArea', 'LotArea', 'LowQualFinSF', 'Heating',
#        'Condition2', 'LandSlope', 'KitchenAbvGr', 'ScreenPorch',
#        'BsmtHalfBath', 'BsmtFinSF2', 'Condition1', 'OpenPorchSF', 'BldgType',
#        'RemodTime', 'MasVnrArea', 'RoofStyle', 'MSSubClass', 'GarageCarArea',
#        'GrLivArea', 'TotalFinSF', 'BsmtFinTypeSF1', 'TotalSF', '2ndFlrSF',
#        'BsmtQual', 'Fireplaces', 'HalfBath', 'BsmtFullBath', 'OverallCond'],
#       dtype='object')

# %%
print("There are {} numerical features with Skew > 0.5 :".format(high_skew.shape[0]))
skewness = pd.DataFrame({'Skew' :high_skew})
skew_features.head(30)
# Out:
# There are 29 numerical features with Skew > 0.5 :
# MiscVal           21.947195
# PoolArea          16.898328
# LotArea           12.822431
# LowQualFinSF      12.088761
# Heating           12.078788
# Condition2        12.060093
# LandSlope          4.975157
# KitchenAbvGr       4.302254
# ScreenPorch        3.946694
# BsmtHalfBath       3.931594
# BsmtFinSF2         3.476562
# Condition1         2.983114
# OpenPorchSF        2.535114
# BldgType           2.192261
# RemodTime          2.063712
# MasVnrArea         1.556310
# RoofStyle          1.553307
# MSSubClass         1.375457
# GarageCarArea      1.296672
# GrLivArea          1.269358
# TotalFinSF         1.159630
# BsmtFinTypeSF1     0.932490
# TotalSF            0.922771
# 2ndFlrSF           0.861675
# BsmtQual           0.796302
# Fireplaces         0.733495
# HalfBath           0.694566
# BsmtFullBath       0.624832
# OverallCond        0.570312
# HeatingQC          0.486656
# dtype: float64

# %% [markdown]
# To normalize the features with skew above 0.5.

# %%
for i in skew_index:
    train_test[i] = np.log1p(train_test[i])
# Out:
# C:\Users\tompe\anaconda3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# To create a column with the log of the SalePrice to match the evaluation process in the contest.

# %%
train_test['LogSalePrice'] = train_test['SalePrice'].apply(np.log)

# %% [markdown]
# To separate the train_test dataset back into the train and test datasets, identify the independent and dependent columns, and create the validation split.

# %%
train = train_test[train_test['SalePrice'].notnull()].copy()
test = train_test[train_test['SalePrice'].isnull()].drop(['SalePrice','LogSalePrice'],axis=1)
X = train.drop(['SalePrice','LogSalePrice'],axis=1)
y = train.LogSalePrice

# %%
X,y = shuffle(X,y, random_state=42)
X = X.reset_index(drop=True)
y = y.reset_index(drop=True)

# %%
def rmse_cv(model,X,y):
    rmse = np.sqrt(-cross_val_score(model, X, y, scoring="neg_mean_squared_error", cv=6))
    return rmse

# %%
cat_model = CatBoostRegressor()

# %%
print(rmse_cv(cat_model,X,y).mean())

# %%
submit = test[['Id']]
submit = submit.reset_index(drop=True)

# %%
cat_model.fit(X,y)
# Out:
# Learning rate set to 0.043466
# 0:	learn: 0.3874866	total: 3.71ms	remaining: 3.71s
# 1:	learn: 0.3760215	total: 7.14ms	remaining: 3.56s
# 2:	learn: 0.3651214	total: 10.1ms	remaining: 3.34s
# 3:	learn: 0.3551511	total: 13.2ms	remaining: 3.29s
# 4:	learn: 0.3454911	total: 16.3ms	remaining: 3.25s
# 5:	learn: 0.3363021	total: 18.8ms	remaining: 3.12s
# 6:	learn: 0.3267778	total: 22ms	remaining: 3.12s
# 7:	learn: 0.3192633	total: 23.5ms	remaining: 2.91s
# 8:	learn: 0.3108241	total: 26.5ms	remaining: 2.91s
# 9:	learn: 0.3027483	total: 28.8ms	remaining: 2.85s
# 10:	learn: 0.2951138	total: 31.2ms	remaining: 2.81s
# 11:	learn: 0.2884878	total: 33.7ms	remaining: 2.77s
# 12:	learn: 0.2814578	total: 36ms	remaining: 2.74s
# 13:	learn: 0.2748698	total: 39.2ms	remaining: 2.76s
# 14:	learn: 0.2682594	total: 41.9ms	remaining: 2.75s
# 15:	learn: 0.2622846	total: 44.3ms	remaining: 2.72s
# 16:	learn: 0.2558103	total: 46.7ms	remaining: 2.7s
# 17:	learn: 0.2496203	total: 49.2ms	remaining: 2.68s
# 18:	learn: 0.2442277	total: 52ms	remaining: 2.68s
# 19:	learn: 0.2386126	total: 54.6ms	remaining: 2.67s
# 20:	learn: 0.2335640	total: 57ms	remaining: 2.66s
# 21:	learn: 0.2285386	total: 59.4ms	remaining: 2.64s
# 22:	learn: 0.2243093	total: 61.6ms	remaining: 2.62s
# 23:	learn: 0.2197111	total: 64ms	remaining: 2.6s
# 24:	learn: 0.2155128	total: 66.3ms	remaining: 2.59s
# 25:	learn: 0.2114084	total: 68.7ms	remaining: 2.57s
# 26:	learn: 0.2072881	total: 71ms	remaining: 2.56s
# 27:	learn: 0.2035652	total: 73.4ms	remaining: 2.55s
# 28:	learn: 0.1999289	total: 75.6ms	remaining: 2.53s
# 29:	learn: 0.1964565	total: 77.9ms	remaining: 2.52s
# 30:	learn: 0.1932759	total: 80.2ms	remaining: 2.51s
# 31:	learn: 0.1902281	total: 82.6ms	remaining: 2.5s
# 32:	learn: 0.1872553	total: 85.1ms	remaining: 2.49s
# 33:	learn: 0.1840122	total: 87.4ms	remaining: 2.48s
# 34:	learn: 0.1813936	total: 89.8ms	remaining: 2.48s
# 35:	learn: 0.1784802	total: 92ms	remaining: 2.46s
# 36:	learn: 0.1759125	total: 94.4ms	remaining: 2.46s
# 37:	learn: 0.1734589	total: 96.7ms	remaining: 2.45s
# 38:	learn: 0.1711430	total: 99.1ms	remaining: 2.44s
# 39:	learn: 0.1687859	total: 101ms	remaining: 2.43s
# 40:	learn: 0.1666621	total: 104ms	remaining: 2.43s
# 41:	learn: 0.1646583	total: 106ms	remaining: 2.42s
# 42:	learn: 0.1626505	total: 109ms	remaining: 2.42s
# 43:	learn: 0.1607315	total: 111ms	remaining: 2.42s
# 44:	learn: 0.1589416	total: 114ms	remaining: 2.41s
# 45:	learn: 0.1569385	total: 116ms	remaining: 2.41s
# 46:	learn: 0.1553827	total: 119ms	remaining: 2.4s
# 47:	learn: 0.1537614	total: 121ms	remaining: 2.4s
# 48:	learn: 0.1523231	total: 123ms	remaining: 2.39s
# 49:	learn: 0.1508452	total: 125ms	remaining: 2.38s
# 50:	learn: 0.1494573	total: 128ms	remaining: 2.38s
# 51:	learn: 0.1480789	total: 130ms	remaining: 2.37s
# 52:	learn: 0.1468504	total: 133ms	remaining: 2.37s
# 53:	learn: 0.1458151	total: 135ms	remaining: 2.36s
# 54:	learn: 0.1445129	total: 137ms	remaining: 2.36s
# 55:	learn: 0.1432367	total: 140ms	remaining: 2.35s
# 56:	learn: 0.1422210	total: 142ms	remaining: 2.35s
# 57:	learn: 0.1411504	total: 144ms	remaining: 2.34s
# 58:	learn: 0.1400673	total: 147ms	remaining: 2.34s
# 59:	learn: 0.1390797	total: 149ms	remaining: 2.34s
# 60:	learn: 0.1379840	total: 152ms	remaining: 2.33s
# 61:	learn: 0.1370077	total: 154ms	remaining: 2.33s
# 62:	learn: 0.1359647	total: 156ms	remaining: 2.33s
# 63:	learn: 0.1349242	total: 159ms	remaining: 2.32s
# 64:	learn: 0.1340362	total: 161ms	remaining: 2.31s
# 65:	learn: 0.1332432	total: 164ms	remaining: 2.32s
# 66:	learn: 0.1324098	total: 167ms	remaining: 2.32s
# 67:	learn: 0.1316698	total: 170ms	remaining: 2.32s
# 68:	learn: 0.1308619	total: 172ms	remaining: 2.32s
# 69:	learn: 0.1301214	total: 174ms	remaining: 2.32s
# 70:	learn: 0.1293489	total: 177ms	remaining: 2.31s
# 71:	learn: 0.1286875	total: 179ms	remaining: 2.31s
# 72:	learn: 0.1280876	total: 182ms	remaining: 2.31s
# 73:	learn: 0.1273800	total: 184ms	remaining: 2.31s
# 74:	learn: 0.1266342	total: 187ms	remaining: 2.3s
# 75:	learn: 0.1258904	total: 189ms	remaining: 2.29s
# 76:	learn: 0.1253418	total: 191ms	remaining: 2.29s
# 77:	learn: 0.1247264	total: 193ms	remaining: 2.29s
# 78:	learn: 0.1239805	total: 196ms	remaining: 2.29s
# 79:	learn: 0.1234550	total: 199ms	remaining: 2.28s
# 80:	learn: 0.1229444	total: 201ms	remaining: 2.28s
# 81:	learn: 0.1223609	total: 204ms	remaining: 2.28s
# 82:	learn: 0.1218317	total: 207ms	remaining: 2.28s
# 83:	learn: 0.1214342	total: 209ms	remaining: 2.28s
# 84:	learn: 0.1209428	total: 212ms	remaining: 2.28s
# 85:	learn: 0.1203096	total: 214ms	remaining: 2.28s
# 86:	learn: 0.1198443	total: 217ms	remaining: 2.28s
# 87:	learn: 0.1193421	total: 220ms	remaining: 2.28s
# 88:	learn: 0.1188500	total: 223ms	remaining: 2.28s
# 89:	learn: 0.1183991	total: 226ms	remaining: 2.28s
# 90:	learn: 0.1178970	total: 228ms	remaining: 2.28s
# 91:	learn: 0.1174390	total: 231ms	remaining: 2.28s
# 92:	learn: 0.1170985	total: 234ms	remaining: 2.28s
# 93:	learn: 0.1167645	total: 237ms	remaining: 2.28s
# 94:	learn: 0.1163389	total: 240ms	remaining: 2.28s
# 95:	learn: 0.1160351	total: 244ms	remaining: 2.29s
# 96:	learn: 0.1157022	total: 246ms	remaining: 2.29s
# 97:	learn: 0.1152908	total: 249ms	remaining: 2.29s
# 98:	learn: 0.1149108	total: 251ms	remaining: 2.28s
# 99:	learn: 0.1145076	total: 253ms	remaining: 2.28s
# 100:	learn: 0.1141522	total: 256ms	remaining: 2.27s
# 101:	learn: 0.1137593	total: 258ms	remaining: 2.27s
# 102:	learn: 0.1133806	total: 261ms	remaining: 2.27s
# 103:	learn: 0.1129996	total: 264ms	remaining: 2.27s
# 104:	learn: 0.1126370	total: 266ms	remaining: 2.27s
# 105:	learn: 0.1123383	total: 269ms	remaining: 2.27s
# 106:	learn: 0.1119398	total: 271ms	remaining: 2.26s
# 107:	learn: 0.1115405	total: 274ms	remaining: 2.26s
# 108:	learn: 0.1112522	total: 276ms	remaining: 2.26s
# 109:	learn: 0.1108776	total: 279ms	remaining: 2.25s
# 110:	learn: 0.1105894	total: 281ms	remaining: 2.25s
# 111:	learn: 0.1103501	total: 283ms	remaining: 2.24s
# 112:	learn: 0.1099840	total: 286ms	remaining: 2.24s
# 113:	learn: 0.1096947	total: 288ms	remaining: 2.24s
# 114:	learn: 0.1092437	total: 290ms	remaining: 2.23s
# 115:	learn: 0.1089707	total: 293ms	remaining: 2.23s
# 116:	learn: 0.1087289	total: 295ms	remaining: 2.23s
# 117:	learn: 0.1084790	total: 297ms	remaining: 2.22s
# 118:	learn: 0.1081777	total: 300ms	remaining: 2.22s
# 119:	learn: 0.1078948	total: 302ms	remaining: 2.22s
# 120:	learn: 0.1076097	total: 305ms	remaining: 2.21s
# 121:	learn: 0.1073747	total: 307ms	remaining: 2.21s
# 122:	learn: 0.1072319	total: 309ms	remaining: 2.21s
# 123:	learn: 0.1069439	total: 312ms	remaining: 2.2s
# 124:	learn: 0.1066761	total: 314ms	remaining: 2.2s
# 125:	learn: 0.1064298	total: 316ms	remaining: 2.19s
# 126:	learn: 0.1061815	total: 319ms	remaining: 2.19s
# 127:	learn: 0.1059334	total: 322ms	remaining: 2.19s
# 128:	learn: 0.1057433	total: 324ms	remaining: 2.19s
# 129:	learn: 0.1055008	total: 326ms	remaining: 2.18s
# 130:	learn: 0.1052920	total: 329ms	remaining: 2.18s
# 131:	learn: 0.1050892	total: 331ms	remaining: 2.18s
# 132:	learn: 0.1048736	total: 333ms	remaining: 2.17s
# 133:	learn: 0.1046117	total: 336ms	remaining: 2.17s
# 134:	learn: 0.1044115	total: 339ms	remaining: 2.17s
# 135:	learn: 0.1041357	total: 341ms	remaining: 2.17s
# 136:	learn: 0.1039109	total: 344ms	remaining: 2.17s
# 137:	learn: 0.1037649	total: 346ms	remaining: 2.16s
# 138:	learn: 0.1036223	total: 348ms	remaining: 2.16s
# 139:	learn: 0.1034710	total: 351ms	remaining: 2.15s
# 140:	learn: 0.1032688	total: 353ms	remaining: 2.15s
# 141:	learn: 0.1031394	total: 356ms	remaining: 2.15s
# 142:	learn: 0.1030554	total: 359ms	remaining: 2.15s
# 143:	learn: 0.1027498	total: 362ms	remaining: 2.15s
# 144:	learn: 0.1026448	total: 364ms	remaining: 2.15s
# 145:	learn: 0.1024211	total: 367ms	remaining: 2.15s
# 146:	learn: 0.1022435	total: 370ms	remaining: 2.15s
# 147:	learn: 0.1020039	total: 372ms	remaining: 2.14s
# 148:	learn: 0.1019077	total: 375ms	remaining: 2.14s
# 149:	learn: 0.1016691	total: 378ms	remaining: 2.14s
# 150:	learn: 0.1014665	total: 380ms	remaining: 2.14s
# 151:	learn: 0.1013297	total: 383ms	remaining: 2.13s
# 152:	learn: 0.1011511	total: 385ms	remaining: 2.13s
# 153:	learn: 0.1009020	total: 387ms	remaining: 2.13s
# 154:	learn: 0.1007104	total: 390ms	remaining: 2.12s
# 155:	learn: 0.1003851	total: 392ms	remaining: 2.12s
# 156:	learn: 0.1000731	total: 395ms	remaining: 2.12s
# 157:	learn: 0.0999148	total: 398ms	remaining: 2.12s
# 158:	learn: 0.0996826	total: 401ms	remaining: 2.12s
# 159:	learn: 0.0994631	total: 403ms	remaining: 2.12s
# 160:	learn: 0.0993341	total: 406ms	remaining: 2.12s
# 161:	learn: 0.0990786	total: 409ms	remaining: 2.11s
# 162:	learn: 0.0989348	total: 411ms	remaining: 2.11s
# 163:	learn: 0.0987456	total: 414ms	remaining: 2.11s
# 164:	learn: 0.0985821	total: 416ms	remaining: 2.11s
# 165:	learn: 0.0983896	total: 424ms	remaining: 2.13s
# 166:	learn: 0.0982369	total: 427ms	remaining: 2.13s
# 167:	learn: 0.0980198	total: 429ms	remaining: 2.13s
# 168:	learn: 0.0979219	total: 432ms	remaining: 2.13s
# 169:	learn: 0.0977619	total: 435ms	remaining: 2.12s
# 170:	learn: 0.0976045	total: 437ms	remaining: 2.12s
# 171:	learn: 0.0974664	total: 440ms	remaining: 2.12s
# 172:	learn: 0.0972603	total: 443ms	remaining: 2.12s
# 173:	learn: 0.0971390	total: 445ms	remaining: 2.11s
# 174:	learn: 0.0969912	total: 448ms	remaining: 2.11s
# 175:	learn: 0.0968606	total: 450ms	remaining: 2.11s
# 176:	learn: 0.0967357	total: 454ms	remaining: 2.11s
# 177:	learn: 0.0966118	total: 456ms	remaining: 2.11s
# 178:	learn: 0.0965347	total: 459ms	remaining: 2.1s
# 179:	learn: 0.0963909	total: 462ms	remaining: 2.1s
# 180:	learn: 0.0962663	total: 464ms	remaining: 2.1s
# 181:	learn: 0.0960634	total: 467ms	remaining: 2.1s
# 182:	learn: 0.0959183	total: 469ms	remaining: 2.09s
# 183:	learn: 0.0957518	total: 471ms	remaining: 2.09s
# 184:	learn: 0.0956518	total: 474ms	remaining: 2.09s
# 185:	learn: 0.0954684	total: 476ms	remaining: 2.08s
# 186:	learn: 0.0952843	total: 479ms	remaining: 2.08s
# 187:	learn: 0.0951447	total: 481ms	remaining: 2.08s
# 188:	learn: 0.0948904	total: 483ms	remaining: 2.07s
# 189:	learn: 0.0947496	total: 486ms	remaining: 2.07s
# 190:	learn: 0.0946250	total: 488ms	remaining: 2.07s
# 191:	learn: 0.0945144	total: 490ms	remaining: 2.06s
# 192:	learn: 0.0943906	total: 493ms	remaining: 2.06s
# 193:	learn: 0.0942717	total: 495ms	remaining: 2.06s
# 194:	learn: 0.0941641	total: 498ms	remaining: 2.05s
# 195:	learn: 0.0940744	total: 500ms	remaining: 2.05s
# 196:	learn: 0.0938885	total: 502ms	remaining: 2.05s
# 197:	learn: 0.0936509	total: 505ms	remaining: 2.04s
# 198:	learn: 0.0934473	total: 508ms	remaining: 2.04s
# 199:	learn: 0.0931785	total: 511ms	remaining: 2.04s
# 200:	learn: 0.0929519	total: 514ms	remaining: 2.04s
# 201:	learn: 0.0927012	total: 517ms	remaining: 2.04s
# 202:	learn: 0.0925833	total: 520ms	remaining: 2.04s
# 203:	learn: 0.0923977	total: 522ms	remaining: 2.04s
# 204:	learn: 0.0923106	total: 525ms	remaining: 2.03s
# 205:	learn: 0.0921195	total: 527ms	remaining: 2.03s
# 206:	learn: 0.0920070	total: 530ms	remaining: 2.03s
# 207:	learn: 0.0919169	total: 532ms	remaining: 2.02s
# 208:	learn: 0.0917796	total: 535ms	remaining: 2.02s
# 209:	learn: 0.0916850	total: 537ms	remaining: 2.02s
# 210:	learn: 0.0915569	total: 539ms	remaining: 2.02s
# 211:	learn: 0.0914482	total: 542ms	remaining: 2.02s
# 212:	learn: 0.0913076	total: 545ms	remaining: 2.01s
# 213:	learn: 0.0911301	total: 548ms	remaining: 2.01s
# 214:	learn: 0.0910257	total: 550ms	remaining: 2.01s
# 215:	learn: 0.0908864	total: 553ms	remaining: 2.01s
# 216:	learn: 0.0907528	total: 556ms	remaining: 2s
# 217:	learn: 0.0905534	total: 559ms	remaining: 2s
# 218:	learn: 0.0904938	total: 561ms	remaining: 2s
# 219:	learn: 0.0904178	total: 564ms	remaining: 2s
# 220:	learn: 0.0902688	total: 566ms	remaining: 2s
# 221:	learn: 0.0901918	total: 569ms	remaining: 1.99s
# 222:	learn: 0.0900164	total: 571ms	remaining: 1.99s
# 223:	learn: 0.0898606	total: 574ms	remaining: 1.99s
# 224:	learn: 0.0897724	total: 577ms	remaining: 1.99s
# 225:	learn: 0.0895634	total: 579ms	remaining: 1.98s
# 226:	learn: 0.0894669	total: 582ms	remaining: 1.98s
# 227:	learn: 0.0892746	total: 584ms	remaining: 1.98s
# 228:	learn: 0.0890874	total: 587ms	remaining: 1.98s
# 229:	learn: 0.0889946	total: 590ms	remaining: 1.97s
# 230:	learn: 0.0888912	total: 593ms	remaining: 1.97s
# 231:	learn: 0.0888150	total: 595ms	remaining: 1.97s
# 232:	learn: 0.0886384	total: 598ms	remaining: 1.97s
# 233:	learn: 0.0885659	total: 600ms	remaining: 1.96s
# 234:	learn: 0.0883733	total: 603ms	remaining: 1.96s
# 235:	learn: 0.0882849	total: 606ms	remaining: 1.96s
# 236:	learn: 0.0882344	total: 608ms	remaining: 1.96s
# 237:	learn: 0.0880890	total: 611ms	remaining: 1.96s
# 238:	learn: 0.0878946	total: 614ms	remaining: 1.96s
# 239:	learn: 0.0877812	total: 617ms	remaining: 1.95s
# 240:	learn: 0.0876497	total: 621ms	remaining: 1.96s
# 241:	learn: 0.0875472	total: 624ms	remaining: 1.95s
# 242:	learn: 0.0873752	total: 627ms	remaining: 1.95s
# 243:	learn: 0.0872351	total: 630ms	remaining: 1.95s
# 244:	learn: 0.0871635	total: 634ms	remaining: 1.95s
# 245:	learn: 0.0870120	total: 636ms	remaining: 1.95s
# 246:	learn: 0.0868888	total: 639ms	remaining: 1.95s
# 247:	learn: 0.0867273	total: 641ms	remaining: 1.94s
# 248:	learn: 0.0865258	total: 644ms	remaining: 1.94s
# 249:	learn: 0.0864779	total: 646ms	remaining: 1.94s
# 250:	learn: 0.0862603	total: 649ms	remaining: 1.94s
# 251:	learn: 0.0860371	total: 652ms	remaining: 1.93s
# 252:	learn: 0.0859562	total: 654ms	remaining: 1.93s
# 253:	learn: 0.0858254	total: 657ms	remaining: 1.93s
# 254:	learn: 0.0856369	total: 659ms	remaining: 1.93s
# 255:	learn: 0.0854525	total: 662ms	remaining: 1.92s
# 256:	learn: 0.0852411	total: 664ms	remaining: 1.92s
# 257:	learn: 0.0850867	total: 667ms	remaining: 1.92s
# 258:	learn: 0.0849590	total: 669ms	remaining: 1.91s
# 259:	learn: 0.0848696	total: 671ms	remaining: 1.91s
# 260:	learn: 0.0847281	total: 673ms	remaining: 1.91s
# 261:	learn: 0.0845263	total: 676ms	remaining: 1.9s
# 262:	learn: 0.0844757	total: 678ms	remaining: 1.9s
# 263:	learn: 0.0843105	total: 681ms	remaining: 1.9s
# 264:	learn: 0.0841976	total: 683ms	remaining: 1.89s
# 265:	learn: 0.0840733	total: 685ms	remaining: 1.89s
# 266:	learn: 0.0839347	total: 688ms	remaining: 1.89s
# 267:	learn: 0.0837383	total: 690ms	remaining: 1.89s
# 268:	learn: 0.0836081	total: 693ms	remaining: 1.88s
# 269:	learn: 0.0834921	total: 695ms	remaining: 1.88s
# 270:	learn: 0.0834415	total: 698ms	remaining: 1.88s
# 271:	learn: 0.0832549	total: 718ms	remaining: 1.92s
# 272:	learn: 0.0831032	total: 726ms	remaining: 1.93s
# 273:	learn: 0.0829943	total: 731ms	remaining: 1.94s
# 274:	learn: 0.0828845	total: 736ms	remaining: 1.94s
# 275:	learn: 0.0827568	total: 740ms	remaining: 1.94s
# 276:	learn: 0.0826490	total: 743ms	remaining: 1.94s
# 277:	learn: 0.0825280	total: 746ms	remaining: 1.94s
# 278:	learn: 0.0823605	total: 750ms	remaining: 1.94s
# 279:	learn: 0.0822746	total: 752ms	remaining: 1.93s
# 280:	learn: 0.0821274	total: 756ms	remaining: 1.93s
# 281:	learn: 0.0819972	total: 758ms	remaining: 1.93s
# 282:	learn: 0.0819435	total: 761ms	remaining: 1.93s
# 283:	learn: 0.0818915	total: 764ms	remaining: 1.92s
# 284:	learn: 0.0817487	total: 766ms	remaining: 1.92s
# 285:	learn: 0.0816755	total: 768ms	remaining: 1.92s
# 286:	learn: 0.0815270	total: 771ms	remaining: 1.91s
# 287:	learn: 0.0814616	total: 773ms	remaining: 1.91s
# 288:	learn: 0.0813856	total: 775ms	remaining: 1.91s
# 289:	learn: 0.0813089	total: 777ms	remaining: 1.9s
# 290:	learn: 0.0812746	total: 780ms	remaining: 1.9s
# 291:	learn: 0.0812367	total: 782ms	remaining: 1.9s
# 292:	learn: 0.0810761	total: 785ms	remaining: 1.89s
# 293:	learn: 0.0809575	total: 789ms	remaining: 1.89s
# 294:	learn: 0.0807693	total: 791ms	remaining: 1.89s
# 295:	learn: 0.0805954	total: 794ms	remaining: 1.89s
# 296:	learn: 0.0804255	total: 798ms	remaining: 1.89s
# 297:	learn: 0.0803444	total: 801ms	remaining: 1.89s
# 298:	learn: 0.0803097	total: 804ms	remaining: 1.88s
# 299:	learn: 0.0802558	total: 806ms	remaining: 1.88s
# 300:	learn: 0.0802322	total: 808ms	remaining: 1.88s
# 301:	learn: 0.0801043	total: 810ms	remaining: 1.87s
# 302:	learn: 0.0799426	total: 813ms	remaining: 1.87s
# 303:	learn: 0.0799196	total: 815ms	remaining: 1.86s
# 304:	learn: 0.0797360	total: 818ms	remaining: 1.86s
# 305:	learn: 0.0796513	total: 820ms	remaining: 1.86s
# 306:	learn: 0.0796161	total: 823ms	remaining: 1.86s
# 307:	learn: 0.0795416	total: 825ms	remaining: 1.85s
# 308:	learn: 0.0795061	total: 828ms	remaining: 1.85s
# 309:	learn: 0.0794823	total: 830ms	remaining: 1.85s
# 310:	learn: 0.0793302	total: 833ms	remaining: 1.84s
# 311:	learn: 0.0792011	total: 835ms	remaining: 1.84s
# 312:	learn: 0.0791278	total: 838ms	remaining: 1.84s
# 313:	learn: 0.0790705	total: 840ms	remaining: 1.83s
# 314:	learn: 0.0789417	total: 843ms	remaining: 1.83s
# 315:	learn: 0.0788400	total: 846ms	remaining: 1.83s
# 316:	learn: 0.0787668	total: 848ms	remaining: 1.83s
# 317:	learn: 0.0787357	total: 850ms	remaining: 1.82s
# 318:	learn: 0.0786727	total: 853ms	remaining: 1.82s
# 319:	learn: 0.0785648	total: 856ms	remaining: 1.82s
# 320:	learn: 0.0784081	total: 858ms	remaining: 1.81s
# 321:	learn: 0.0783097	total: 861ms	remaining: 1.81s
# 322:	learn: 0.0782000	total: 863ms	remaining: 1.81s
# 323:	learn: 0.0781097	total: 866ms	remaining: 1.81s
# 324:	learn: 0.0779614	total: 869ms	remaining: 1.8s
# 325:	learn: 0.0778724	total: 871ms	remaining: 1.8s
# 326:	learn: 0.0777539	total: 874ms	remaining: 1.8s
# 327:	learn: 0.0776613	total: 876ms	remaining: 1.79s
# 328:	learn: 0.0776438	total: 878ms	remaining: 1.79s
# 329:	learn: 0.0775241	total: 881ms	remaining: 1.79s
# 330:	learn: 0.0774234	total: 883ms	remaining: 1.78s
# 331:	learn: 0.0773497	total: 886ms	remaining: 1.78s
# 332:	learn: 0.0772633	total: 888ms	remaining: 1.78s
# 333:	learn: 0.0771756	total: 891ms	remaining: 1.78s
# 334:	learn: 0.0770878	total: 893ms	remaining: 1.77s
# 335:	learn: 0.0770149	total: 896ms	remaining: 1.77s
# 336:	learn: 0.0769905	total: 898ms	remaining: 1.77s
# 337:	learn: 0.0768685	total: 901ms	remaining: 1.76s
# 338:	learn: 0.0767591	total: 903ms	remaining: 1.76s
# 339:	learn: 0.0766108	total: 905ms	remaining: 1.76s
# 340:	learn: 0.0764617	total: 908ms	remaining: 1.75s
# 341:	learn: 0.0763836	total: 910ms	remaining: 1.75s
# 342:	learn: 0.0762919	total: 912ms	remaining: 1.75s
# 343:	learn: 0.0761872	total: 915ms	remaining: 1.74s
# 344:	learn: 0.0760362	total: 917ms	remaining: 1.74s
# 345:	learn: 0.0760161	total: 919ms	remaining: 1.74s
# 346:	learn: 0.0759746	total: 922ms	remaining: 1.73s
# 347:	learn: 0.0759118	total: 924ms	remaining: 1.73s
# 348:	learn: 0.0758339	total: 927ms	remaining: 1.73s
# 349:	learn: 0.0758112	total: 930ms	remaining: 1.73s
# 350:	learn: 0.0757835	total: 932ms	remaining: 1.72s
# 351:	learn: 0.0757524	total: 934ms	remaining: 1.72s
# 352:	learn: 0.0756321	total: 937ms	remaining: 1.72s
# 353:	learn: 0.0755152	total: 939ms	remaining: 1.71s
# 354:	learn: 0.0754307	total: 942ms	remaining: 1.71s
# 355:	learn: 0.0752664	total: 944ms	remaining: 1.71s
# 356:	learn: 0.0752256	total: 946ms	remaining: 1.7s
# 357:	learn: 0.0751177	total: 948ms	remaining: 1.7s
# 358:	learn: 0.0749945	total: 952ms	remaining: 1.7s
# 359:	learn: 0.0749129	total: 955ms	remaining: 1.7s
# 360:	learn: 0.0748178	total: 957ms	remaining: 1.69s
# 361:	learn: 0.0746883	total: 960ms	remaining: 1.69s
# 362:	learn: 0.0746502	total: 962ms	remaining: 1.69s
# 363:	learn: 0.0745122	total: 964ms	remaining: 1.68s
# 364:	learn: 0.0744443	total: 967ms	remaining: 1.68s
# 365:	learn: 0.0743439	total: 969ms	remaining: 1.68s
# 366:	learn: 0.0742666	total: 971ms	remaining: 1.68s
# 367:	learn: 0.0741576	total: 974ms	remaining: 1.67s
# 368:	learn: 0.0741184	total: 976ms	remaining: 1.67s
# 369:	learn: 0.0739772	total: 978ms	remaining: 1.67s
# 370:	learn: 0.0739030	total: 982ms	remaining: 1.66s
# 371:	learn: 0.0737773	total: 985ms	remaining: 1.66s
# 372:	learn: 0.0736940	total: 988ms	remaining: 1.66s
# 373:	learn: 0.0736827	total: 990ms	remaining: 1.66s
# 374:	learn: 0.0736170	total: 993ms	remaining: 1.65s
# 375:	learn: 0.0736091	total: 996ms	remaining: 1.65s
# 376:	learn: 0.0734891	total: 999ms	remaining: 1.65s
# 377:	learn: 0.0734019	total: 1s	remaining: 1.65s
# 378:	learn: 0.0733851	total: 1s	remaining: 1.65s
# 379:	learn: 0.0732956	total: 1.01s	remaining: 1.64s
# 380:	learn: 0.0732250	total: 1.01s	remaining: 1.64s
# 381:	learn: 0.0730907	total: 1.01s	remaining: 1.64s
# 382:	learn: 0.0729427	total: 1.01s	remaining: 1.64s
# 383:	learn: 0.0728675	total: 1.02s	remaining: 1.63s
# 384:	learn: 0.0727783	total: 1.02s	remaining: 1.63s
# 385:	learn: 0.0726502	total: 1.02s	remaining: 1.63s
# 386:	learn: 0.0725222	total: 1.02s	remaining: 1.62s
# 387:	learn: 0.0725007	total: 1.03s	remaining: 1.62s
# 388:	learn: 0.0723975	total: 1.03s	remaining: 1.62s
# 389:	learn: 0.0723114	total: 1.03s	remaining: 1.61s
# 390:	learn: 0.0723044	total: 1.03s	remaining: 1.61s
# 391:	learn: 0.0722056	total: 1.04s	remaining: 1.61s
# 392:	learn: 0.0721392	total: 1.04s	remaining: 1.6s
# 393:	learn: 0.0720208	total: 1.04s	remaining: 1.6s
# 394:	learn: 0.0720082	total: 1.04s	remaining: 1.6s
# 395:	learn: 0.0718993	total: 1.04s	remaining: 1.59s
# 396:	learn: 0.0717791	total: 1.05s	remaining: 1.59s
# 397:	learn: 0.0716939	total: 1.05s	remaining: 1.59s
# 398:	learn: 0.0715461	total: 1.05s	remaining: 1.58s
# 399:	learn: 0.0714556	total: 1.05s	remaining: 1.58s
# 400:	learn: 0.0713341	total: 1.06s	remaining: 1.58s
# 401:	learn: 0.0712628	total: 1.06s	remaining: 1.57s
# 402:	learn: 0.0711939	total: 1.06s	remaining: 1.57s
# 403:	learn: 0.0711196	total: 1.06s	remaining: 1.57s
# 404:	learn: 0.0710081	total: 1.07s	remaining: 1.57s
# 405:	learn: 0.0709523	total: 1.07s	remaining: 1.56s
# 406:	learn: 0.0708417	total: 1.07s	remaining: 1.56s
# 407:	learn: 0.0706825	total: 1.07s	remaining: 1.56s
# 408:	learn: 0.0705583	total: 1.07s	remaining: 1.55s
# 409:	learn: 0.0704532	total: 1.08s	remaining: 1.55s
# 410:	learn: 0.0703712	total: 1.08s	remaining: 1.55s
# 411:	learn: 0.0702579	total: 1.08s	remaining: 1.54s
# 412:	learn: 0.0701343	total: 1.08s	remaining: 1.54s
# 413:	learn: 0.0700363	total: 1.09s	remaining: 1.54s
# 414:	learn: 0.0699032	total: 1.09s	remaining: 1.53s
# 415:	learn: 0.0698457	total: 1.09s	remaining: 1.53s
# 416:	learn: 0.0696996	total: 1.09s	remaining: 1.53s
# 417:	learn: 0.0695919	total: 1.1s	remaining: 1.53s
# 418:	learn: 0.0695667	total: 1.1s	remaining: 1.52s
# 419:	learn: 0.0694881	total: 1.1s	remaining: 1.52s
# 420:	learn: 0.0694231	total: 1.1s	remaining: 1.52s
# 421:	learn: 0.0693010	total: 1.1s	remaining: 1.51s
# 422:	learn: 0.0692335	total: 1.11s	remaining: 1.51s
# 423:	learn: 0.0691141	total: 1.11s	remaining: 1.51s
# 424:	learn: 0.0689960	total: 1.11s	remaining: 1.5s
# 425:	learn: 0.0689510	total: 1.11s	remaining: 1.5s
# 426:	learn: 0.0688913	total: 1.12s	remaining: 1.5s
# 427:	learn: 0.0687497	total: 1.12s	remaining: 1.5s
# 428:	learn: 0.0686233	total: 1.12s	remaining: 1.49s
# 429:	learn: 0.0685249	total: 1.12s	remaining: 1.49s
# 430:	learn: 0.0684343	total: 1.13s	remaining: 1.49s
# 431:	learn: 0.0683510	total: 1.13s	remaining: 1.49s
# 432:	learn: 0.0681936	total: 1.13s	remaining: 1.48s
# 433:	learn: 0.0681392	total: 1.13s	remaining: 1.48s
# 434:	learn: 0.0680773	total: 1.14s	remaining: 1.48s
# 435:	learn: 0.0680703	total: 1.14s	remaining: 1.47s
# 436:	learn: 0.0680124	total: 1.14s	remaining: 1.47s
# 437:	learn: 0.0679488	total: 1.14s	remaining: 1.47s
# 438:	learn: 0.0678471	total: 1.15s	remaining: 1.46s
# 439:	learn: 0.0677827	total: 1.15s	remaining: 1.46s
# 440:	learn: 0.0676805	total: 1.15s	remaining: 1.46s
# 441:	learn: 0.0676158	total: 1.15s	remaining: 1.46s
# 442:	learn: 0.0675415	total: 1.16s	remaining: 1.45s
# 443:	learn: 0.0674871	total: 1.16s	remaining: 1.45s
# 444:	learn: 0.0673920	total: 1.16s	remaining: 1.45s
# 445:	learn: 0.0672868	total: 1.16s	remaining: 1.45s
# 446:	learn: 0.0672013	total: 1.17s	remaining: 1.44s
# 447:	learn: 0.0671429	total: 1.17s	remaining: 1.44s
# 448:	learn: 0.0670179	total: 1.17s	remaining: 1.44s
# 449:	learn: 0.0669279	total: 1.17s	remaining: 1.43s
# 450:	learn: 0.0668609	total: 1.18s	remaining: 1.43s
# 451:	learn: 0.0667141	total: 1.18s	remaining: 1.43s
# 452:	learn: 0.0666559	total: 1.18s	remaining: 1.43s
# 453:	learn: 0.0666006	total: 1.18s	remaining: 1.42s
# 454:	learn: 0.0665518	total: 1.18s	remaining: 1.42s
# 455:	learn: 0.0665091	total: 1.19s	remaining: 1.42s
# 456:	learn: 0.0664546	total: 1.19s	remaining: 1.42s
# 457:	learn: 0.0664303	total: 1.19s	remaining: 1.41s
# 458:	learn: 0.0663516	total: 1.2s	remaining: 1.41s
# 459:	learn: 0.0662906	total: 1.2s	remaining: 1.41s
# 460:	learn: 0.0662159	total: 1.2s	remaining: 1.4s
# 461:	learn: 0.0661161	total: 1.2s	remaining: 1.4s
# 462:	learn: 0.0660193	total: 1.21s	remaining: 1.4s
# 463:	learn: 0.0659271	total: 1.21s	remaining: 1.4s
# 464:	learn: 0.0658411	total: 1.21s	remaining: 1.4s
# 465:	learn: 0.0657016	total: 1.22s	remaining: 1.39s
# 466:	learn: 0.0656004	total: 1.22s	remaining: 1.39s
# 467:	learn: 0.0654975	total: 1.22s	remaining: 1.39s
# 468:	learn: 0.0654291	total: 1.23s	remaining: 1.39s
# 469:	learn: 0.0653356	total: 1.23s	remaining: 1.38s
# 470:	learn: 0.0652374	total: 1.23s	remaining: 1.38s
# 471:	learn: 0.0651483	total: 1.23s	remaining: 1.38s
# 472:	learn: 0.0650538	total: 1.24s	remaining: 1.38s
# 473:	learn: 0.0650026	total: 1.24s	remaining: 1.38s
# 474:	learn: 0.0649461	total: 1.24s	remaining: 1.37s
# 475:	learn: 0.0648820	total: 1.24s	remaining: 1.37s
# 476:	learn: 0.0648233	total: 1.25s	remaining: 1.37s
# 477:	learn: 0.0647572	total: 1.25s	remaining: 1.36s
# 478:	learn: 0.0646744	total: 1.25s	remaining: 1.36s
# 479:	learn: 0.0646061	total: 1.26s	remaining: 1.36s
# 480:	learn: 0.0645438	total: 1.26s	remaining: 1.36s
# 481:	learn: 0.0644261	total: 1.26s	remaining: 1.36s
# 482:	learn: 0.0643210	total: 1.26s	remaining: 1.35s
# 483:	learn: 0.0642522	total: 1.27s	remaining: 1.35s
# 484:	learn: 0.0641710	total: 1.28s	remaining: 1.36s
# 485:	learn: 0.0641179	total: 1.29s	remaining: 1.36s
# 486:	learn: 0.0641124	total: 1.3s	remaining: 1.36s
# 487:	learn: 0.0640261	total: 1.3s	remaining: 1.36s
# 488:	learn: 0.0640079	total: 1.3s	remaining: 1.36s
# 489:	learn: 0.0638976	total: 1.31s	remaining: 1.36s
# 490:	learn: 0.0638087	total: 1.31s	remaining: 1.36s
# 491:	learn: 0.0637850	total: 1.31s	remaining: 1.36s
# 492:	learn: 0.0637169	total: 1.32s	remaining: 1.36s
# 493:	learn: 0.0636307	total: 1.32s	remaining: 1.35s
# 494:	learn: 0.0635519	total: 1.32s	remaining: 1.35s
# 495:	learn: 0.0634889	total: 1.33s	remaining: 1.35s
# 496:	learn: 0.0634352	total: 1.33s	remaining: 1.35s
# 497:	learn: 0.0633233	total: 1.33s	remaining: 1.34s
# 498:	learn: 0.0632437	total: 1.33s	remaining: 1.34s
# 499:	learn: 0.0631559	total: 1.34s	remaining: 1.34s
# 500:	learn: 0.0630835	total: 1.34s	remaining: 1.33s
# 501:	learn: 0.0629954	total: 1.34s	remaining: 1.33s
# 502:	learn: 0.0629051	total: 1.34s	remaining: 1.33s
# 503:	learn: 0.0628506	total: 1.35s	remaining: 1.32s
# 504:	learn: 0.0627705	total: 1.35s	remaining: 1.32s
# 505:	learn: 0.0626860	total: 1.35s	remaining: 1.32s
# 506:	learn: 0.0626490	total: 1.35s	remaining: 1.32s
# 507:	learn: 0.0626001	total: 1.36s	remaining: 1.31s
# 508:	learn: 0.0625372	total: 1.36s	remaining: 1.31s
# 509:	learn: 0.0624943	total: 1.36s	remaining: 1.31s
# 510:	learn: 0.0624836	total: 1.36s	remaining: 1.3s
# 511:	learn: 0.0624187	total: 1.36s	remaining: 1.3s
# 512:	learn: 0.0623506	total: 1.37s	remaining: 1.3s
# 513:	learn: 0.0622482	total: 1.37s	remaining: 1.29s
# 514:	learn: 0.0621552	total: 1.37s	remaining: 1.29s
# 515:	learn: 0.0620846	total: 1.38s	remaining: 1.29s
# 516:	learn: 0.0620007	total: 1.38s	remaining: 1.29s
# 517:	learn: 0.0619361	total: 1.38s	remaining: 1.28s
# 518:	learn: 0.0618534	total: 1.38s	remaining: 1.28s
# 519:	learn: 0.0618119	total: 1.39s	remaining: 1.28s
# 520:	learn: 0.0617822	total: 1.39s	remaining: 1.28s
# 521:	learn: 0.0617339	total: 1.39s	remaining: 1.27s
# 522:	learn: 0.0616918	total: 1.4s	remaining: 1.27s
# 523:	learn: 0.0616384	total: 1.4s	remaining: 1.27s
# 524:	learn: 0.0615833	total: 1.4s	remaining: 1.27s
# 525:	learn: 0.0614943	total: 1.4s	remaining: 1.26s
# 526:	learn: 0.0613866	total: 1.4s	remaining: 1.26s
# 527:	learn: 0.0613061	total: 1.41s	remaining: 1.26s
# 528:	learn: 0.0612084	total: 1.41s	remaining: 1.25s
# 529:	learn: 0.0611688	total: 1.41s	remaining: 1.25s
# 530:	learn: 0.0611204	total: 1.41s	remaining: 1.25s
# 531:	learn: 0.0610427	total: 1.42s	remaining: 1.25s
# 532:	learn: 0.0609606	total: 1.42s	remaining: 1.24s
# 533:	learn: 0.0608695	total: 1.42s	remaining: 1.24s
# 534:	learn: 0.0608010	total: 1.42s	remaining: 1.24s
# 535:	learn: 0.0607376	total: 1.43s	remaining: 1.23s
# 536:	learn: 0.0606539	total: 1.43s	remaining: 1.23s
# 537:	learn: 0.0605477	total: 1.43s	remaining: 1.23s
# 538:	learn: 0.0604358	total: 1.43s	remaining: 1.23s
# 539:	learn: 0.0603853	total: 1.43s	remaining: 1.22s
# 540:	learn: 0.0603467	total: 1.44s	remaining: 1.22s
# 541:	learn: 0.0602763	total: 1.44s	remaining: 1.22s
# 542:	learn: 0.0602178	total: 1.44s	remaining: 1.21s
# 543:	learn: 0.0601620	total: 1.44s	remaining: 1.21s
# 544:	learn: 0.0601093	total: 1.45s	remaining: 1.21s
# 545:	learn: 0.0600461	total: 1.45s	remaining: 1.2s
# 546:	learn: 0.0600114	total: 1.45s	remaining: 1.2s
# 547:	learn: 0.0599179	total: 1.45s	remaining: 1.2s
# 548:	learn: 0.0598501	total: 1.46s	remaining: 1.2s
# 549:	learn: 0.0597733	total: 1.46s	remaining: 1.19s
# 550:	learn: 0.0596885	total: 1.46s	remaining: 1.19s
# 551:	learn: 0.0595908	total: 1.46s	remaining: 1.19s
# 552:	learn: 0.0595310	total: 1.46s	remaining: 1.18s
# 553:	learn: 0.0594719	total: 1.47s	remaining: 1.18s
# 554:	learn: 0.0593661	total: 1.47s	remaining: 1.18s
# 555:	learn: 0.0593010	total: 1.47s	remaining: 1.18s
# 556:	learn: 0.0592291	total: 1.47s	remaining: 1.17s
# 557:	learn: 0.0591617	total: 1.48s	remaining: 1.17s
# 558:	learn: 0.0590670	total: 1.48s	remaining: 1.17s
# 559:	learn: 0.0590565	total: 1.48s	remaining: 1.16s
# 560:	learn: 0.0589863	total: 1.48s	remaining: 1.16s
# 561:	learn: 0.0589050	total: 1.49s	remaining: 1.16s
# 562:	learn: 0.0588921	total: 1.49s	remaining: 1.15s
# 563:	learn: 0.0588124	total: 1.49s	remaining: 1.15s
# 564:	learn: 0.0587213	total: 1.49s	remaining: 1.15s
# 565:	learn: 0.0586435	total: 1.5s	remaining: 1.15s
# 566:	learn: 0.0585799	total: 1.5s	remaining: 1.14s
# 567:	learn: 0.0585636	total: 1.5s	remaining: 1.14s
# 568:	learn: 0.0585309	total: 1.5s	remaining: 1.14s
# 569:	learn: 0.0584630	total: 1.5s	remaining: 1.13s
# 570:	learn: 0.0584066	total: 1.51s	remaining: 1.13s
# 571:	learn: 0.0583079	total: 1.51s	remaining: 1.13s
# 572:	learn: 0.0582682	total: 1.51s	remaining: 1.13s
# 573:	learn: 0.0582589	total: 1.51s	remaining: 1.12s
# 574:	learn: 0.0582409	total: 1.52s	remaining: 1.12s
# 575:	learn: 0.0581306	total: 1.52s	remaining: 1.12s
# 576:	learn: 0.0580951	total: 1.52s	remaining: 1.11s
# 577:	learn: 0.0580592	total: 1.52s	remaining: 1.11s
# 578:	learn: 0.0580048	total: 1.52s	remaining: 1.11s
# 579:	learn: 0.0579555	total: 1.53s	remaining: 1.11s
# 580:	learn: 0.0578892	total: 1.53s	remaining: 1.1s
# 581:	learn: 0.0578549	total: 1.53s	remaining: 1.1s
# 582:	learn: 0.0578340	total: 1.53s	remaining: 1.1s
# 583:	learn: 0.0577746	total: 1.54s	remaining: 1.09s
# 584:	learn: 0.0577062	total: 1.54s	remaining: 1.09s
# 585:	learn: 0.0576118	total: 1.54s	remaining: 1.09s
# 586:	learn: 0.0575421	total: 1.54s	remaining: 1.09s
# 587:	learn: 0.0574899	total: 1.55s	remaining: 1.08s
# 588:	learn: 0.0574283	total: 1.55s	remaining: 1.08s
# 589:	learn: 0.0573529	total: 1.55s	remaining: 1.08s
# 590:	learn: 0.0572665	total: 1.55s	remaining: 1.07s
# 591:	learn: 0.0572104	total: 1.56s	remaining: 1.07s
# 592:	learn: 0.0571228	total: 1.56s	remaining: 1.07s
# 593:	learn: 0.0570650	total: 1.56s	remaining: 1.07s
# 594:	learn: 0.0569820	total: 1.56s	remaining: 1.06s
# 595:	learn: 0.0569406	total: 1.56s	remaining: 1.06s
# 596:	learn: 0.0568877	total: 1.57s	remaining: 1.06s
# 597:	learn: 0.0568117	total: 1.57s	remaining: 1.05s
# 598:	learn: 0.0567636	total: 1.57s	remaining: 1.05s
# 599:	learn: 0.0566922	total: 1.57s	remaining: 1.05s
# 600:	learn: 0.0566361	total: 1.58s	remaining: 1.05s
# 601:	learn: 0.0566044	total: 1.58s	remaining: 1.04s
# 602:	learn: 0.0565862	total: 1.58s	remaining: 1.04s
# 603:	learn: 0.0565480	total: 1.59s	remaining: 1.04s
# 604:	learn: 0.0565061	total: 1.59s	remaining: 1.04s
# 605:	learn: 0.0564991	total: 1.59s	remaining: 1.03s
# 606:	learn: 0.0564692	total: 1.59s	remaining: 1.03s
# 607:	learn: 0.0563882	total: 1.6s	remaining: 1.03s
# 608:	learn: 0.0563581	total: 1.6s	remaining: 1.03s
# 609:	learn: 0.0562992	total: 1.6s	remaining: 1.02s
# 610:	learn: 0.0562663	total: 1.6s	remaining: 1.02s
# 611:	learn: 0.0561987	total: 1.6s	remaining: 1.02s
# 612:	learn: 0.0561183	total: 1.61s	remaining: 1.01s
# 613:	learn: 0.0560847	total: 1.61s	remaining: 1.01s
# 614:	learn: 0.0560489	total: 1.61s	remaining: 1.01s
# 615:	learn: 0.0559870	total: 1.61s	remaining: 1.01s
# 616:	learn: 0.0559290	total: 1.62s	remaining: 1s
# 617:	learn: 0.0558568	total: 1.62s	remaining: 1s
# 618:	learn: 0.0558359	total: 1.62s	remaining: 999ms
# 619:	learn: 0.0557765	total: 1.62s	remaining: 996ms
# 620:	learn: 0.0557270	total: 1.63s	remaining: 993ms
# 621:	learn: 0.0556899	total: 1.63s	remaining: 990ms
# 622:	learn: 0.0556402	total: 1.63s	remaining: 987ms
# 623:	learn: 0.0555678	total: 1.63s	remaining: 985ms
# 624:	learn: 0.0555056	total: 1.64s	remaining: 982ms
# 625:	learn: 0.0554789	total: 1.64s	remaining: 979ms
# 626:	learn: 0.0553678	total: 1.64s	remaining: 976ms
# 627:	learn: 0.0553225	total: 1.64s	remaining: 973ms
# 628:	learn: 0.0552525	total: 1.65s	remaining: 971ms
# 629:	learn: 0.0551968	total: 1.65s	remaining: 968ms
# 630:	learn: 0.0551851	total: 1.65s	remaining: 965ms
# 631:	learn: 0.0551308	total: 1.65s	remaining: 963ms
# 632:	learn: 0.0550735	total: 1.66s	remaining: 960ms
# 633:	learn: 0.0550590	total: 1.66s	remaining: 957ms
# 634:	learn: 0.0549846	total: 1.66s	remaining: 954ms
# 635:	learn: 0.0549073	total: 1.66s	remaining: 952ms
# 636:	learn: 0.0548406	total: 1.67s	remaining: 949ms
# 637:	learn: 0.0548031	total: 1.67s	remaining: 946ms
# 638:	learn: 0.0546983	total: 1.67s	remaining: 943ms
# 639:	learn: 0.0546418	total: 1.67s	remaining: 940ms
# 640:	learn: 0.0545979	total: 1.67s	remaining: 938ms
# 641:	learn: 0.0545134	total: 1.68s	remaining: 935ms
# 642:	learn: 0.0544515	total: 1.68s	remaining: 933ms
# 643:	learn: 0.0544012	total: 1.68s	remaining: 930ms
# 644:	learn: 0.0543451	total: 1.68s	remaining: 927ms
# 645:	learn: 0.0542718	total: 1.69s	remaining: 924ms
# 646:	learn: 0.0542110	total: 1.69s	remaining: 922ms
# 647:	learn: 0.0541070	total: 1.69s	remaining: 919ms
# 648:	learn: 0.0540460	total: 1.69s	remaining: 916ms
# 649:	learn: 0.0539981	total: 1.7s	remaining: 914ms
# 650:	learn: 0.0539933	total: 1.7s	remaining: 911ms
# 651:	learn: 0.0539164	total: 1.7s	remaining: 908ms
# 652:	learn: 0.0538915	total: 1.7s	remaining: 905ms
# 653:	learn: 0.0538540	total: 1.71s	remaining: 902ms
# 654:	learn: 0.0538503	total: 1.71s	remaining: 900ms
# 655:	learn: 0.0537455	total: 1.71s	remaining: 897ms
# 656:	learn: 0.0537190	total: 1.71s	remaining: 894ms
# 657:	learn: 0.0536727	total: 1.71s	remaining: 891ms
# 658:	learn: 0.0535840	total: 1.72s	remaining: 889ms
# 659:	learn: 0.0535541	total: 1.72s	remaining: 886ms
# 660:	learn: 0.0535512	total: 1.72s	remaining: 883ms
# 661:	learn: 0.0535275	total: 1.72s	remaining: 880ms
# 662:	learn: 0.0534785	total: 1.73s	remaining: 877ms
# 663:	learn: 0.0534291	total: 1.73s	remaining: 875ms
# 664:	learn: 0.0533720	total: 1.73s	remaining: 872ms
# 665:	learn: 0.0532824	total: 1.73s	remaining: 869ms
# 666:	learn: 0.0532021	total: 1.74s	remaining: 866ms
# 667:	learn: 0.0531623	total: 1.74s	remaining: 864ms
# 668:	learn: 0.0530984	total: 1.74s	remaining: 861ms
# 669:	learn: 0.0530272	total: 1.74s	remaining: 858ms
# 670:	learn: 0.0529912	total: 1.74s	remaining: 855ms
# 671:	learn: 0.0529238	total: 1.75s	remaining: 853ms
# 672:	learn: 0.0528475	total: 1.75s	remaining: 850ms
# 673:	learn: 0.0528068	total: 1.75s	remaining: 847ms
# 674:	learn: 0.0527559	total: 1.75s	remaining: 845ms
# 675:	learn: 0.0527002	total: 1.76s	remaining: 842ms
# 676:	learn: 0.0526447	total: 1.76s	remaining: 839ms
# 677:	learn: 0.0526391	total: 1.76s	remaining: 836ms
# 678:	learn: 0.0525985	total: 1.76s	remaining: 834ms
# 679:	learn: 0.0525241	total: 1.77s	remaining: 831ms
# 680:	learn: 0.0524840	total: 1.77s	remaining: 829ms
# 681:	learn: 0.0524202	total: 1.77s	remaining: 826ms
# 682:	learn: 0.0523394	total: 1.77s	remaining: 824ms
# 683:	learn: 0.0523360	total: 1.78s	remaining: 821ms
# 684:	learn: 0.0522928	total: 1.78s	remaining: 818ms
# 685:	learn: 0.0522406	total: 1.78s	remaining: 816ms
# 686:	learn: 0.0521751	total: 1.78s	remaining: 813ms
# 687:	learn: 0.0521461	total: 1.79s	remaining: 811ms
# 688:	learn: 0.0520531	total: 1.79s	remaining: 809ms
# 689:	learn: 0.0519729	total: 1.79s	remaining: 806ms
# 690:	learn: 0.0519298	total: 1.8s	remaining: 804ms
# 691:	learn: 0.0518871	total: 1.8s	remaining: 801ms
# 692:	learn: 0.0518271	total: 1.8s	remaining: 799ms
# 693:	learn: 0.0517768	total: 1.8s	remaining: 796ms
# 694:	learn: 0.0517319	total: 1.81s	remaining: 794ms
# 695:	learn: 0.0517285	total: 1.81s	remaining: 791ms
# 696:	learn: 0.0516614	total: 1.81s	remaining: 789ms
# 697:	learn: 0.0516083	total: 1.82s	remaining: 786ms
# 698:	learn: 0.0515600	total: 1.82s	remaining: 783ms
# 699:	learn: 0.0514900	total: 1.82s	remaining: 781ms
# 700:	learn: 0.0513934	total: 1.82s	remaining: 779ms
# 701:	learn: 0.0513439	total: 1.83s	remaining: 776ms
# 702:	learn: 0.0512468	total: 1.83s	remaining: 774ms
# 703:	learn: 0.0512417	total: 1.83s	remaining: 771ms
# 704:	learn: 0.0512372	total: 1.84s	remaining: 768ms
# 705:	learn: 0.0511929	total: 1.84s	remaining: 766ms
# 706:	learn: 0.0511549	total: 1.84s	remaining: 764ms
# 707:	learn: 0.0511497	total: 1.84s	remaining: 761ms
# 708:	learn: 0.0510527	total: 1.85s	remaining: 758ms
# 709:	learn: 0.0510448	total: 1.85s	remaining: 756ms
# 710:	learn: 0.0509753	total: 1.85s	remaining: 753ms
# 711:	learn: 0.0509431	total: 1.86s	remaining: 751ms
# 712:	learn: 0.0509061	total: 1.86s	remaining: 748ms
# 713:	learn: 0.0508678	total: 1.86s	remaining: 746ms
# 714:	learn: 0.0508632	total: 1.86s	remaining: 743ms
# 715:	learn: 0.0508087	total: 1.87s	remaining: 740ms
# 716:	learn: 0.0507959	total: 1.87s	remaining: 738ms
# 717:	learn: 0.0507912	total: 1.87s	remaining: 735ms
# 718:	learn: 0.0507587	total: 1.88s	remaining: 733ms
# 719:	learn: 0.0506669	total: 1.88s	remaining: 730ms
# 720:	learn: 0.0506132	total: 1.88s	remaining: 728ms
# 721:	learn: 0.0506100	total: 1.88s	remaining: 725ms
# 722:	learn: 0.0505453	total: 1.89s	remaining: 723ms
# 723:	learn: 0.0504938	total: 1.89s	remaining: 720ms
# 724:	learn: 0.0504272	total: 1.89s	remaining: 718ms
# 725:	learn: 0.0504239	total: 1.89s	remaining: 715ms
# 726:	learn: 0.0503677	total: 1.9s	remaining: 712ms
# 727:	learn: 0.0502620	total: 1.9s	remaining: 709ms
# 728:	learn: 0.0502054	total: 1.9s	remaining: 707ms
# 729:	learn: 0.0501493	total: 1.91s	remaining: 705ms
# 730:	learn: 0.0500803	total: 1.91s	remaining: 702ms
# 731:	learn: 0.0500493	total: 1.91s	remaining: 699ms
# 732:	learn: 0.0500193	total: 1.91s	remaining: 697ms
# 733:	learn: 0.0499498	total: 1.92s	remaining: 694ms
# 734:	learn: 0.0498698	total: 1.92s	remaining: 692ms
# 735:	learn: 0.0498317	total: 1.92s	remaining: 689ms
# 736:	learn: 0.0498021	total: 1.92s	remaining: 686ms
# 737:	learn: 0.0497449	total: 1.93s	remaining: 683ms
# 738:	learn: 0.0496724	total: 1.93s	remaining: 681ms
# 739:	learn: 0.0496261	total: 1.93s	remaining: 678ms
# 740:	learn: 0.0495865	total: 1.93s	remaining: 676ms
# 741:	learn: 0.0495249	total: 1.94s	remaining: 673ms
# 742:	learn: 0.0494824	total: 1.94s	remaining: 670ms
# 743:	learn: 0.0494248	total: 1.94s	remaining: 667ms
# 744:	learn: 0.0493630	total: 1.94s	remaining: 665ms
# 745:	learn: 0.0493002	total: 1.94s	remaining: 662ms
# 746:	learn: 0.0492317	total: 1.95s	remaining: 659ms
# 747:	learn: 0.0492277	total: 1.95s	remaining: 657ms
# 748:	learn: 0.0492181	total: 1.95s	remaining: 654ms
# 749:	learn: 0.0491740	total: 1.95s	remaining: 651ms
# 750:	learn: 0.0491191	total: 1.96s	remaining: 648ms
# 751:	learn: 0.0491147	total: 1.96s	remaining: 646ms
# 752:	learn: 0.0490870	total: 1.96s	remaining: 643ms
# 753:	learn: 0.0490166	total: 1.96s	remaining: 641ms
# 754:	learn: 0.0489924	total: 1.97s	remaining: 638ms
# 755:	learn: 0.0489401	total: 1.97s	remaining: 636ms
# 756:	learn: 0.0489080	total: 1.97s	remaining: 633ms
# 757:	learn: 0.0488457	total: 1.98s	remaining: 631ms
# 758:	learn: 0.0487943	total: 1.98s	remaining: 628ms
# 759:	learn: 0.0487295	total: 1.98s	remaining: 626ms
# 760:	learn: 0.0486819	total: 1.98s	remaining: 623ms
# 761:	learn: 0.0486503	total: 1.99s	remaining: 620ms
# 762:	learn: 0.0486137	total: 1.99s	remaining: 618ms
# 763:	learn: 0.0486074	total: 1.99s	remaining: 615ms
# 764:	learn: 0.0485577	total: 1.99s	remaining: 613ms
# 765:	learn: 0.0484750	total: 2s	remaining: 610ms
# 766:	learn: 0.0484329	total: 2s	remaining: 608ms
# 767:	learn: 0.0484306	total: 2s	remaining: 605ms
# 768:	learn: 0.0483851	total: 2s	remaining: 602ms
# 769:	learn: 0.0483742	total: 2.01s	remaining: 599ms
# 770:	learn: 0.0483183	total: 2.01s	remaining: 597ms
# 771:	learn: 0.0482539	total: 2.01s	remaining: 594ms
# 772:	learn: 0.0482473	total: 2.01s	remaining: 592ms
# 773:	learn: 0.0481808	total: 2.02s	remaining: 589ms
# 774:	learn: 0.0481655	total: 2.02s	remaining: 586ms
# 775:	learn: 0.0481437	total: 2.02s	remaining: 584ms
# 776:	learn: 0.0480734	total: 2.02s	remaining: 581ms
# 777:	learn: 0.0480510	total: 2.03s	remaining: 578ms
# 778:	learn: 0.0479871	total: 2.03s	remaining: 576ms
# 779:	learn: 0.0479476	total: 2.03s	remaining: 573ms
# 780:	learn: 0.0478822	total: 2.03s	remaining: 571ms
# 781:	learn: 0.0478762	total: 2.04s	remaining: 568ms
# 782:	learn: 0.0478122	total: 2.04s	remaining: 565ms
# 783:	learn: 0.0477532	total: 2.04s	remaining: 563ms
# 784:	learn: 0.0476898	total: 2.04s	remaining: 560ms
# 785:	learn: 0.0476855	total: 2.05s	remaining: 557ms
# 786:	learn: 0.0476550	total: 2.05s	remaining: 555ms
# 787:	learn: 0.0476045	total: 2.05s	remaining: 552ms
# 788:	learn: 0.0475546	total: 2.05s	remaining: 550ms
# 789:	learn: 0.0474929	total: 2.06s	remaining: 547ms
# 790:	learn: 0.0474496	total: 2.06s	remaining: 544ms
# 791:	learn: 0.0474304	total: 2.06s	remaining: 542ms
# 792:	learn: 0.0473664	total: 2.06s	remaining: 539ms
# 793:	learn: 0.0472907	total: 2.07s	remaining: 536ms
# 794:	learn: 0.0472248	total: 2.07s	remaining: 534ms
# 795:	learn: 0.0471762	total: 2.07s	remaining: 531ms
# 796:	learn: 0.0471615	total: 2.07s	remaining: 529ms
# 797:	learn: 0.0471052	total: 2.08s	remaining: 526ms
# 798:	learn: 0.0470330	total: 2.08s	remaining: 523ms
# 799:	learn: 0.0470030	total: 2.08s	remaining: 521ms
# 800:	learn: 0.0469683	total: 2.08s	remaining: 518ms
# 801:	learn: 0.0469386	total: 2.09s	remaining: 515ms
# 802:	learn: 0.0468938	total: 2.09s	remaining: 512ms
# 803:	learn: 0.0468417	total: 2.09s	remaining: 510ms
# 804:	learn: 0.0467653	total: 2.09s	remaining: 507ms
# 805:	learn: 0.0467136	total: 2.1s	remaining: 504ms
# 806:	learn: 0.0467107	total: 2.1s	remaining: 502ms
# 807:	learn: 0.0466884	total: 2.1s	remaining: 499ms
# 808:	learn: 0.0466345	total: 2.1s	remaining: 497ms
# 809:	learn: 0.0465918	total: 2.11s	remaining: 494ms
# 810:	learn: 0.0465893	total: 2.11s	remaining: 492ms
# 811:	learn: 0.0465515	total: 2.11s	remaining: 489ms
# 812:	learn: 0.0465020	total: 2.12s	remaining: 487ms
# 813:	learn: 0.0464201	total: 2.12s	remaining: 484ms
# 814:	learn: 0.0463709	total: 2.12s	remaining: 481ms
# 815:	learn: 0.0463347	total: 2.12s	remaining: 479ms
# 816:	learn: 0.0462724	total: 2.13s	remaining: 476ms
# 817:	learn: 0.0462097	total: 2.13s	remaining: 473ms
# 818:	learn: 0.0461631	total: 2.13s	remaining: 471ms
# 819:	learn: 0.0461197	total: 2.13s	remaining: 468ms
# 820:	learn: 0.0460891	total: 2.13s	remaining: 465ms
# 821:	learn: 0.0460547	total: 2.14s	remaining: 463ms
# 822:	learn: 0.0460093	total: 2.14s	remaining: 460ms
# 823:	learn: 0.0459518	total: 2.14s	remaining: 458ms
# 824:	learn: 0.0458777	total: 2.14s	remaining: 455ms
# 825:	learn: 0.0458728	total: 2.15s	remaining: 452ms
# 826:	learn: 0.0458196	total: 2.15s	remaining: 450ms
# 827:	learn: 0.0457916	total: 2.15s	remaining: 447ms
# 828:	learn: 0.0457749	total: 2.15s	remaining: 444ms
# 829:	learn: 0.0457292	total: 2.16s	remaining: 442ms
# 830:	learn: 0.0456985	total: 2.16s	remaining: 439ms
# 831:	learn: 0.0456370	total: 2.16s	remaining: 437ms
# 832:	learn: 0.0456034	total: 2.16s	remaining: 434ms
# 833:	learn: 0.0455766	total: 2.17s	remaining: 431ms
# 834:	learn: 0.0455307	total: 2.17s	remaining: 429ms
# 835:	learn: 0.0454537	total: 2.17s	remaining: 427ms
# 836:	learn: 0.0454521	total: 2.18s	remaining: 424ms
# 837:	learn: 0.0453953	total: 2.18s	remaining: 421ms
# 838:	learn: 0.0453487	total: 2.18s	remaining: 419ms
# 839:	learn: 0.0452828	total: 2.18s	remaining: 416ms
# 840:	learn: 0.0452479	total: 2.19s	remaining: 413ms
# 841:	learn: 0.0452106	total: 2.19s	remaining: 411ms
# 842:	learn: 0.0451716	total: 2.19s	remaining: 408ms
# 843:	learn: 0.0451155	total: 2.19s	remaining: 406ms
# 844:	learn: 0.0451071	total: 2.2s	remaining: 403ms
# 845:	learn: 0.0450663	total: 2.2s	remaining: 400ms
# 846:	learn: 0.0449968	total: 2.2s	remaining: 398ms
# 847:	learn: 0.0449390	total: 2.2s	remaining: 395ms
# 848:	learn: 0.0449250	total: 2.21s	remaining: 393ms
# 849:	learn: 0.0448766	total: 2.21s	remaining: 390ms
# 850:	learn: 0.0448361	total: 2.21s	remaining: 387ms
# 851:	learn: 0.0447897	total: 2.21s	remaining: 385ms
# 852:	learn: 0.0447765	total: 2.22s	remaining: 382ms
# 853:	learn: 0.0447630	total: 2.22s	remaining: 379ms
# 854:	learn: 0.0447239	total: 2.22s	remaining: 377ms
# 855:	learn: 0.0447097	total: 2.22s	remaining: 374ms
# 856:	learn: 0.0446781	total: 2.23s	remaining: 371ms
# 857:	learn: 0.0446231	total: 2.23s	remaining: 369ms
# 858:	learn: 0.0445729	total: 2.23s	remaining: 366ms
# 859:	learn: 0.0445074	total: 2.23s	remaining: 364ms
# 860:	learn: 0.0444949	total: 2.24s	remaining: 361ms
# 861:	learn: 0.0444541	total: 2.24s	remaining: 358ms
# 862:	learn: 0.0443822	total: 2.24s	remaining: 356ms
# 863:	learn: 0.0443782	total: 2.24s	remaining: 353ms
# 864:	learn: 0.0443314	total: 2.25s	remaining: 351ms
# 865:	learn: 0.0442771	total: 2.25s	remaining: 348ms
# 866:	learn: 0.0442184	total: 2.25s	remaining: 345ms
# 867:	learn: 0.0441531	total: 2.25s	remaining: 343ms
# 868:	learn: 0.0441483	total: 2.25s	remaining: 340ms
# 869:	learn: 0.0441412	total: 2.26s	remaining: 337ms
# 870:	learn: 0.0440947	total: 2.26s	remaining: 335ms
# 871:	learn: 0.0440307	total: 2.26s	remaining: 332ms
# 872:	learn: 0.0440134	total: 2.27s	remaining: 330ms
# 873:	learn: 0.0439782	total: 2.27s	remaining: 327ms
# 874:	learn: 0.0439148	total: 2.27s	remaining: 324ms
# 875:	learn: 0.0438568	total: 2.27s	remaining: 322ms
# 876:	learn: 0.0438551	total: 2.28s	remaining: 319ms
# 877:	learn: 0.0438092	total: 2.28s	remaining: 317ms
# 878:	learn: 0.0437531	total: 2.28s	remaining: 314ms
# 879:	learn: 0.0437289	total: 2.28s	remaining: 311ms
# 880:	learn: 0.0436859	total: 2.29s	remaining: 309ms
# 881:	learn: 0.0436511	total: 2.29s	remaining: 306ms
# 882:	learn: 0.0435642	total: 2.29s	remaining: 304ms
# 883:	learn: 0.0435115	total: 2.29s	remaining: 301ms
# 884:	learn: 0.0435068	total: 2.29s	remaining: 298ms
# 885:	learn: 0.0434996	total: 2.3s	remaining: 296ms
# 886:	learn: 0.0434481	total: 2.3s	remaining: 293ms
# 887:	learn: 0.0433990	total: 2.3s	remaining: 290ms
# 888:	learn: 0.0433567	total: 2.31s	remaining: 288ms
# 889:	learn: 0.0433527	total: 2.31s	remaining: 285ms
# 890:	learn: 0.0433391	total: 2.31s	remaining: 283ms
# 891:	learn: 0.0432712	total: 2.31s	remaining: 280ms
# 892:	learn: 0.0432653	total: 2.31s	remaining: 277ms
# 893:	learn: 0.0432456	total: 2.32s	remaining: 275ms
# 894:	learn: 0.0432416	total: 2.32s	remaining: 272ms
# 895:	learn: 0.0431803	total: 2.32s	remaining: 270ms
# 896:	learn: 0.0431346	total: 2.32s	remaining: 267ms
# 897:	learn: 0.0430700	total: 2.33s	remaining: 264ms
# 898:	learn: 0.0430032	total: 2.33s	remaining: 262ms
# 899:	learn: 0.0429590	total: 2.33s	remaining: 259ms
# 900:	learn: 0.0429452	total: 2.33s	remaining: 256ms
# 901:	learn: 0.0429075	total: 2.34s	remaining: 254ms
# 902:	learn: 0.0428377	total: 2.34s	remaining: 251ms
# 903:	learn: 0.0428008	total: 2.34s	remaining: 249ms
# 904:	learn: 0.0427744	total: 2.34s	remaining: 246ms
# 905:	learn: 0.0427444	total: 2.35s	remaining: 243ms
# 906:	learn: 0.0427118	total: 2.35s	remaining: 241ms
# 907:	learn: 0.0426827	total: 2.35s	remaining: 238ms
# 908:	learn: 0.0426346	total: 2.35s	remaining: 236ms
# 909:	learn: 0.0426149	total: 2.36s	remaining: 233ms
# 910:	learn: 0.0426124	total: 2.36s	remaining: 231ms
# 911:	learn: 0.0425900	total: 2.36s	remaining: 228ms
# 912:	learn: 0.0425237	total: 2.37s	remaining: 225ms
# 913:	learn: 0.0424885	total: 2.37s	remaining: 223ms
# 914:	learn: 0.0424872	total: 2.37s	remaining: 220ms
# 915:	learn: 0.0424108	total: 2.37s	remaining: 218ms
# 916:	learn: 0.0423920	total: 2.38s	remaining: 215ms
# 917:	learn: 0.0423551	total: 2.38s	remaining: 212ms
# 918:	learn: 0.0423090	total: 2.38s	remaining: 210ms
# 919:	learn: 0.0423076	total: 2.38s	remaining: 207ms
# 920:	learn: 0.0422545	total: 2.38s	remaining: 205ms
# 921:	learn: 0.0421887	total: 2.39s	remaining: 202ms
# 922:	learn: 0.0421368	total: 2.39s	remaining: 199ms
# 923:	learn: 0.0420709	total: 2.39s	remaining: 197ms
# 924:	learn: 0.0420304	total: 2.39s	remaining: 194ms
# 925:	learn: 0.0419722	total: 2.4s	remaining: 192ms
# 926:	learn: 0.0419213	total: 2.4s	remaining: 189ms
# 927:	learn: 0.0418843	total: 2.4s	remaining: 186ms
# 928:	learn: 0.0418177	total: 2.4s	remaining: 184ms
# 929:	learn: 0.0417903	total: 2.41s	remaining: 181ms
# 930:	learn: 0.0417458	total: 2.41s	remaining: 179ms
# 931:	learn: 0.0417164	total: 2.41s	remaining: 176ms
# 932:	learn: 0.0417022	total: 2.41s	remaining: 173ms
# 933:	learn: 0.0416764	total: 2.42s	remaining: 171ms
# 934:	learn: 0.0416444	total: 2.42s	remaining: 168ms
# 935:	learn: 0.0416138	total: 2.42s	remaining: 166ms
# 936:	learn: 0.0415458	total: 2.42s	remaining: 163ms
# 937:	learn: 0.0415401	total: 2.43s	remaining: 160ms
# 938:	learn: 0.0414862	total: 2.43s	remaining: 158ms
# 939:	learn: 0.0414455	total: 2.43s	remaining: 155ms
# 940:	learn: 0.0413937	total: 2.43s	remaining: 153ms
# 941:	learn: 0.0413555	total: 2.44s	remaining: 150ms
# 942:	learn: 0.0413391	total: 2.44s	remaining: 147ms
# 943:	learn: 0.0413006	total: 2.44s	remaining: 145ms
# 944:	learn: 0.0412990	total: 2.44s	remaining: 142ms
# 945:	learn: 0.0412560	total: 2.44s	remaining: 140ms
# 946:	learn: 0.0412538	total: 2.45s	remaining: 137ms
# 947:	learn: 0.0411941	total: 2.45s	remaining: 134ms
# 948:	learn: 0.0411344	total: 2.45s	remaining: 132ms
# 949:	learn: 0.0411091	total: 2.45s	remaining: 129ms
# 950:	learn: 0.0411060	total: 2.46s	remaining: 127ms
# 951:	learn: 0.0410357	total: 2.46s	remaining: 124ms
# 952:	learn: 0.0409787	total: 2.46s	remaining: 121ms
# 953:	learn: 0.0409554	total: 2.46s	remaining: 119ms
# 954:	learn: 0.0409452	total: 2.47s	remaining: 116ms
# 955:	learn: 0.0409020	total: 2.47s	remaining: 114ms
# 956:	learn: 0.0408488	total: 2.47s	remaining: 111ms
# 957:	learn: 0.0407796	total: 2.47s	remaining: 108ms
# 958:	learn: 0.0407349	total: 2.48s	remaining: 106ms
# 959:	learn: 0.0406966	total: 2.48s	remaining: 103ms
# 960:	learn: 0.0406590	total: 2.48s	remaining: 101ms
# 961:	learn: 0.0406039	total: 2.48s	remaining: 98.1ms
# 962:	learn: 0.0405713	total: 2.48s	remaining: 95.5ms
# 963:	learn: 0.0405258	total: 2.49s	remaining: 92.9ms
# 964:	learn: 0.0404711	total: 2.49s	remaining: 90.3ms
# 965:	learn: 0.0404281	total: 2.49s	remaining: 87.7ms
# 966:	learn: 0.0403988	total: 2.49s	remaining: 85.1ms
# 967:	learn: 0.0403489	total: 2.5s	remaining: 82.5ms
# 968:	learn: 0.0403116	total: 2.5s	remaining: 79.9ms
# 969:	learn: 0.0402903	total: 2.5s	remaining: 77.4ms
# 970:	learn: 0.0402443	total: 2.5s	remaining: 74.8ms
# 971:	learn: 0.0402194	total: 2.5s	remaining: 72.2ms
# 972:	learn: 0.0401570	total: 2.51s	remaining: 69.6ms
# 973:	learn: 0.0401393	total: 2.51s	remaining: 67ms
# 974:	learn: 0.0401167	total: 2.51s	remaining: 64.4ms
# 975:	learn: 0.0400615	total: 2.52s	remaining: 61.9ms
# 976:	learn: 0.0400138	total: 2.52s	remaining: 59.3ms
# 977:	learn: 0.0399917	total: 2.52s	remaining: 56.7ms
# 978:	learn: 0.0399461	total: 2.52s	remaining: 54.1ms
# 979:	learn: 0.0399052	total: 2.52s	remaining: 51.5ms
# 980:	learn: 0.0398553	total: 2.53s	remaining: 48.9ms
# 981:	learn: 0.0398079	total: 2.53s	remaining: 46.4ms
# 982:	learn: 0.0397836	total: 2.53s	remaining: 43.8ms
# 983:	learn: 0.0397719	total: 2.53s	remaining: 41.2ms
# 984:	learn: 0.0397597	total: 2.54s	remaining: 38.6ms
# 985:	learn: 0.0397576	total: 2.54s	remaining: 36ms
# 986:	learn: 0.0397564	total: 2.54s	remaining: 33.5ms
# 987:	learn: 0.0397050	total: 2.54s	remaining: 30.9ms
# 988:	learn: 0.0396426	total: 2.55s	remaining: 28.3ms
# 989:	learn: 0.0396133	total: 2.55s	remaining: 25.8ms
# 990:	learn: 0.0395861	total: 2.55s	remaining: 23.2ms
# 991:	learn: 0.0395709	total: 2.56s	remaining: 20.6ms
# 992:	learn: 0.0395301	total: 2.56s	remaining: 18ms
# 993:	learn: 0.0394924	total: 2.56s	remaining: 15.5ms
# 994:	learn: 0.0394526	total: 2.56s	remaining: 12.9ms
# 995:	learn: 0.0394515	total: 2.56s	remaining: 10.3ms
# 996:	learn: 0.0394225	total: 2.57s	remaining: 7.73ms
# 997:	learn: 0.0393913	total: 2.57s	remaining: 5.15ms
# 998:	learn: 0.0393582	total: 2.57s	remaining: 2.58ms
# 999:	learn: 0.0393174	total: 2.58s	remaining: 0us

# %%
submit_predict = cat_model.predict(test)
submit_predict = np.exp(submit_predict)

# %%
submit['SalePrice'] = submit_predict

# %%
submit.to_csv('submit_cv_cat_boost.csv', index=False)

# %% [markdown]
# Reducing feature skewness actually slightly increased the Kaggle score.
