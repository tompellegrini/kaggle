# %% [markdown]
# This is the initial notebook to explore the data and run the first models.

# %%
import pandas as pd
import numpy as np

from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
from sklearn.preprocessing import OneHotEncoder

from fastai.imports import *
from fastai.tabular.all import *

from numpy import random
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_log_error
from sklearn import metrics
from sklearn.model_selection import KFold, cross_val_score

import eli5
from eli5.sklearn import PermutationImportance

from scipy.stats import skew, norm
from catboost import CatBoostRegressor

# %%
test = pd.read_csv('test.csv')
sample = pd.read_csv('sample_submission.csv')
train = pd.read_csv('train.csv')

# %% [markdown]
# Based on initial analysis the train and test datasets have similar characteristics, so it will be easier to combine them for imputation and data analysis work.

# %%
train_test = pd.concat([train, test], ignore_index=True)

# %%
pd.isnull(train_test).sum()[pd.isnull(train_test).sum() > 0]
# Out:
# MSZoning           4
# LotFrontage      486
# Alley           2721
# Utilities          2
# Exterior1st        1
# Exterior2nd        1
# MasVnrType        24
# MasVnrArea        23
# BsmtQual          81
# BsmtCond          82
# BsmtExposure      82
# BsmtFinType1      79
# BsmtFinSF1         1
# BsmtFinType2      80
# BsmtFinSF2         1
# BsmtUnfSF          1
# TotalBsmtSF        1
# Electrical         1
# BsmtFullBath       2
# BsmtHalfBath       2
# KitchenQual        1
# Functional         2
# FireplaceQu     1420
# GarageType       157
# GarageYrBlt      159
# GarageFinish     159
# GarageCars         1
# GarageArea         1
# GarageQual       159
# GarageCond       159
# PoolQC          2909
# Fence           2348
# MiscFeature     2814
# SaleType           1
# SalePrice       1459
# dtype: int64

# %% [markdown]
# It looks like Alley, FireplaceQu, PoolQC, Fence and MiscFeature have significant numbers of missing data. So it will be best to eliminate those rows. There are a number of rows that have less than 5 rows with missing data. Since some of these are categorical and some are continuous data, their missing data will be replaced with the most frequent value.

# %%
drop_high_nan=['Alley','FireplaceQu','PoolQC','Fence','MiscFeature']
train_test=train_test.drop(drop_high_nan,axis=1)
small_nan_cols = ['MSZoning', 'Utilities', 'Exterior1st', 'Exterior2nd', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 
                  'TotalBsmtSF', 'Electrical', 'BsmtFullBath', 'BsmtHalfBath', 'KitchenQual', 'Functional', 'GarageCars', 
                  'GarageArea','SaleType', 'SaleCondition']
small_impute = SimpleImputer(strategy='most_frequent')
train_test[small_nan_cols] = pd.DataFrame(small_impute.fit_transform(train_test[small_nan_cols]),columns=small_nan_cols)

# %% [markdown]
# The following columns seem to have one value significantly larger than the rest, and it would probably be best to use the mode, or most common, value to feel each NaN value: MasVnrType, MasVnrArea, BsmtCond, BsmtExposure, BsmtFinType2, GarageType, GarageFinish, GarageQual, and GarageCond. That is represents 9 out of the 13 columns.
#
# BsmtQual has two values larger than the rest: Gd and TA. But it only has 2.8% NaNs, so simply using the mode might be good enough.
#
# GarageYrBlt has 59 NaNs out 2919 rows which is only 2%. It has a dispersed set of values, so it might be easiest just to have any NaNs have the same value as YearBuilt.
#
# BsmtFinType1 has only 2.7% value of NaNs, and most two of its largest values are GLQ and Unf. It might be easiest to use the mode here.
#
# LotFrontage has 486 NaNs out of 2919 rows which is a pretty high 16.7%. It has a dispersed range of values, but looking at its characteristics from the describe function above, it seems to have a pretty even distribution with a mean of 10,168 and a median of 9,453. So using the mean to fill in the NaNs seems reasonable. If it turns out this value has a high impact on the predictability of the SalePrice, then it might be good to revisit this assumption.

# %%
mode_cols = ['MasVnrType', 'MasVnrArea', 'BsmtCond', 'BsmtExposure', 'BsmtFinType2', 'GarageType', 'GarageFinish', 
             'GarageQual','GarageCond', 'BsmtQual', 'BsmtFinType1']
mode_impute = SimpleImputer(strategy='most_frequent')
train_test[mode_cols] = pd.DataFrame(mode_impute.fit_transform(train_test[mode_cols]),columns=mode_cols)
train_test['LotFrontage'].fillna((train_test['LotFrontage'].mean()), inplace=True)
train_test['GarageYrBlt'] = train_test['GarageYrBlt'].fillna(train_test['YearBuilt'])

# %%
pd.isnull(train_test).sum()[pd.isnull(train_test).sum() > 0]
# Out:
# SalePrice    1459
# dtype: int64

# %%
train_test['BsmtQual'].unique()
# Out:
# array(['Gd', 'TA', 'Ex', 'Fa'], dtype=object)

# %%
train_test['BsmtFinType1'].unique()
# Out:
# array(['GLQ', 'ALQ', 'Unf', 'Rec', 'BLQ', 'LwQ'], dtype=object)

# %%
train_test.BsmtQual = train_test.BsmtQual.replace({"Ex": 110, "Gd": 95, "TA": 85, "Fa": 75, "Po": 60, "NA": 0})

# %%
train_test.BsmtFinType1 = train_test.BsmtFinType1.replace({"GLQ": 6, "ALQ": 5, "BLQ": 4, "Rec": 3, "LwQ": 2, "Unf": 1,
                                                         "NA": 0})

# %% [markdown]
# It will be necessary to identify all the columns that have non-numeric object values and then convert them to numeric values.

# %%
obj_cols = list(train_test.select_dtypes(['object']).columns)
obj_cols
# Out:
# ['MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'KitchenQual',
#  'Functional',
#  'GarageType',
#  'GarageFinish',
#  'GarageCars',
#  'GarageArea',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'SaleType',
#  'SaleCondition']

# %%
for column in obj_cols:
     train_test[column] = pd.factorize(train_test[column], sort=True)[0]
# Out:
# C:\Users\tompe\anaconda3\lib\site-packages\pandas\core\algorithms.py:798: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   uniques = Index(uniques)

# %% [markdown]
# To create some new columns that might compound the effects of the existing columns with higher impact on the xgb score.

# %%
train_test['QualCondSum'] = train_test['OverallQual'] + train_test['OverallCond']
train_test['RemodTime'] = train_test['YearRemodAdd'] - train_test['YearBuilt']
train_test['BsmtFinTypeSF1'] = train_test['BsmtFinType1'] * train_test['BsmtFinSF1']
train_test['TotalFlrSF'] = train_test['1stFlrSF'] + train_test['2ndFlrSF']
train_test['TotalFinSF'] = train_test['GrLivArea'] + train_test['BsmtFinSF1']
train_test['GarageCarArea'] = train_test['GarageArea'] * train_test['GarageCars']
train_test['TotalSF'] = train_test['1stFlrSF'] + train_test['2ndFlrSF'] + train_test['TotalBsmtSF']

# %% [markdown]
# To now eliminate the columns that have negative or zero influence on the xgb score.

# %%
train_test.drop(['Utilities','Street','TotRmsAbvGrd','3SsnPorch','YrSold','Exterior2nd','LotConfig',
                              'HouseStyle','EnclosedPorch','WoodDeckSF','Foundation','RoofMatl','Electrical',
                              'GarageType','LotFrontage','SaleType','MoSold','BsmtExposure','1stFlrSF',
                              'BsmtFinSF1','Exterior1st','KitchenQual','TotalFlrSF'], axis=1, inplace=True)

# %% [markdown]
# To look at how many features have a skew above 0.5, since high skew can be an issue in regression analysis.

# %%
skew_features = train_test.apply(lambda x: skew(x)).sort_values(ascending=False)

# %%
high_skew = skew_features[skew_features > 0.5]
skew_index = high_skew.index

# %%
skew_index
# Out:
# Index(['MiscVal', 'PoolArea', 'LotArea', 'LowQualFinSF', 'Heating',
#        'Condition2', 'LandSlope', 'KitchenAbvGr', 'ScreenPorch',
#        'BsmtHalfBath', 'BsmtFinSF2', 'Condition1', 'OpenPorchSF', 'BldgType',
#        'RemodTime', 'MasVnrArea', 'RoofStyle', 'MSSubClass', 'GarageCarArea',
#        'GrLivArea', 'TotalFinSF', 'BsmtFinTypeSF1', 'TotalSF', '2ndFlrSF',
#        'BsmtQual', 'Fireplaces', 'HalfBath', 'BsmtFullBath', 'OverallCond'],
#       dtype='object')

# %%
print("There are {} numerical features with Skew > 0.5 :".format(high_skew.shape[0]))
skewness = pd.DataFrame({'Skew' :high_skew})
skew_features.head(30)
# Out:
# There are 29 numerical features with Skew > 0.5 :
# MiscVal           21.947195
# PoolArea          16.898328
# LotArea           12.822431
# LowQualFinSF      12.088761
# Heating           12.078788
# Condition2        12.060093
# LandSlope          4.975157
# KitchenAbvGr       4.302254
# ScreenPorch        3.946694
# BsmtHalfBath       3.931594
# BsmtFinSF2         3.476562
# Condition1         2.983114
# OpenPorchSF        2.535114
# BldgType           2.192261
# RemodTime          2.063712
# MasVnrArea         1.556310
# RoofStyle          1.553307
# MSSubClass         1.375457
# GarageCarArea      1.296672
# GrLivArea          1.269358
# TotalFinSF         1.159630
# BsmtFinTypeSF1     0.932490
# TotalSF            0.922771
# 2ndFlrSF           0.861675
# BsmtQual           0.796302
# Fireplaces         0.733495
# HalfBath           0.694566
# BsmtFullBath       0.624832
# OverallCond        0.570312
# HeatingQC          0.486656
# dtype: float64

# %% [markdown]
# To normalize the features with skew above 0.5.

# %%
for i in skew_index:
    train_test[i] = np.log1p(train_test[i])
# Out:
# C:\Users\tompe\anaconda3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# To create a column with the log of the SalePrice to match the evaluation process in the contest.

# %%
train_test['LogSalePrice'] = train_test['SalePrice'].apply(np.log)

# %% [markdown]
# To separate the train_test dataset back into the train and test datasets, identify the independent and dependent columns, and create the validation split.

# %%
train = train_test[train_test['SalePrice'].notnull()].copy()
test = train_test[train_test['SalePrice'].isnull()].drop(['SalePrice','LogSalePrice'],axis=1)
X = train.drop(['SalePrice','LogSalePrice'],axis=1)
y = train.LogSalePrice

# %%
def rmse(y, y_pred):
    return np.sqrt(mean_squared_error(y, y_pred))

# %%
X_train,X_val,y_train,y_val = train_test_split(X,y,test_size = 0.5,random_state=42)
X_train,y_train =X,y

# %%
cat = CatBoostRegressor()
cat_model = cat.fit(X_train,y_train,
                     eval_set = (X_val,y_val),
                     plot=True,
                     verbose = 0)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))

# %%
cat_pred = cat_model.predict(X_val)
cat_score = rmse(y_val, cat_pred)
cat_score
# Out:
# 0.03240179521645853

# %%
submit = test[['Id']]
submit = submit.reset_index(drop=True)

# %%
cat.fit(X,y)
# Out:
# Learning rate set to 0.043466
# 0:	learn: 0.3871859	total: 4.13ms	remaining: 4.13s
# 1:	learn: 0.3755345	total: 7.37ms	remaining: 3.68s
# 2:	learn: 0.3645334	total: 10.4ms	remaining: 3.44s
# 3:	learn: 0.3545474	total: 13.5ms	remaining: 3.35s
# 4:	learn: 0.3447667	total: 17.1ms	remaining: 3.4s
# 5:	learn: 0.3356328	total: 19.9ms	remaining: 3.29s
# 6:	learn: 0.3264438	total: 22.9ms	remaining: 3.25s
# 7:	learn: 0.3179319	total: 26.4ms	remaining: 3.28s
# 8:	learn: 0.3098801	total: 29.1ms	remaining: 3.2s
# 9:	learn: 0.3020381	total: 31.7ms	remaining: 3.13s
# 10:	learn: 0.2945284	total: 34ms	remaining: 3.06s
# 11:	learn: 0.2867855	total: 36.3ms	remaining: 2.99s
# 12:	learn: 0.2801866	total: 39ms	remaining: 2.96s
# 13:	learn: 0.2737452	total: 41.9ms	remaining: 2.95s
# 14:	learn: 0.2670141	total: 44.8ms	remaining: 2.94s
# 15:	learn: 0.2606411	total: 48ms	remaining: 2.95s
# 16:	learn: 0.2547670	total: 51.1ms	remaining: 2.96s
# 17:	learn: 0.2495707	total: 54.2ms	remaining: 2.96s
# 18:	learn: 0.2440967	total: 56.9ms	remaining: 2.94s
# 19:	learn: 0.2386674	total: 59.6ms	remaining: 2.92s
# 20:	learn: 0.2333756	total: 62.2ms	remaining: 2.9s
# 21:	learn: 0.2284646	total: 64.6ms	remaining: 2.87s
# 22:	learn: 0.2236614	total: 67.3ms	remaining: 2.86s
# 23:	learn: 0.2188091	total: 70.1ms	remaining: 2.85s
# 24:	learn: 0.2145691	total: 73ms	remaining: 2.85s
# 25:	learn: 0.2105761	total: 75.8ms	remaining: 2.84s
# 26:	learn: 0.2067418	total: 78.4ms	remaining: 2.83s
# 27:	learn: 0.2030423	total: 81.2ms	remaining: 2.82s
# 28:	learn: 0.1997640	total: 83.6ms	remaining: 2.8s
# 29:	learn: 0.1964362	total: 86.2ms	remaining: 2.79s
# 30:	learn: 0.1933137	total: 88.8ms	remaining: 2.77s
# 31:	learn: 0.1897295	total: 91.2ms	remaining: 2.76s
# 32:	learn: 0.1865523	total: 93.5ms	remaining: 2.74s
# 33:	learn: 0.1836305	total: 95.9ms	remaining: 2.72s
# 34:	learn: 0.1806412	total: 98.3ms	remaining: 2.71s
# 35:	learn: 0.1779864	total: 101ms	remaining: 2.7s
# 36:	learn: 0.1756981	total: 103ms	remaining: 2.69s
# 37:	learn: 0.1732304	total: 106ms	remaining: 2.68s
# 38:	learn: 0.1707251	total: 108ms	remaining: 2.66s
# 39:	learn: 0.1683662	total: 111ms	remaining: 2.65s
# 40:	learn: 0.1663134	total: 113ms	remaining: 2.65s
# 41:	learn: 0.1642576	total: 116ms	remaining: 2.64s
# 42:	learn: 0.1622398	total: 118ms	remaining: 2.63s
# 43:	learn: 0.1605155	total: 121ms	remaining: 2.63s
# 44:	learn: 0.1586854	total: 124ms	remaining: 2.62s
# 45:	learn: 0.1567927	total: 126ms	remaining: 2.62s
# 46:	learn: 0.1550749	total: 129ms	remaining: 2.61s
# 47:	learn: 0.1536929	total: 131ms	remaining: 2.6s
# 48:	learn: 0.1523769	total: 134ms	remaining: 2.6s
# 49:	learn: 0.1508815	total: 137ms	remaining: 2.59s
# 50:	learn: 0.1492371	total: 139ms	remaining: 2.59s
# 51:	learn: 0.1478949	total: 142ms	remaining: 2.59s
# 52:	learn: 0.1465231	total: 144ms	remaining: 2.58s
# 53:	learn: 0.1451961	total: 146ms	remaining: 2.56s
# 54:	learn: 0.1438966	total: 149ms	remaining: 2.56s
# 55:	learn: 0.1424718	total: 151ms	remaining: 2.55s
# 56:	learn: 0.1412375	total: 154ms	remaining: 2.54s
# 57:	learn: 0.1399248	total: 156ms	remaining: 2.53s
# 58:	learn: 0.1388544	total: 158ms	remaining: 2.52s
# 59:	learn: 0.1375327	total: 160ms	remaining: 2.51s
# 60:	learn: 0.1363208	total: 163ms	remaining: 2.5s
# 61:	learn: 0.1353932	total: 165ms	remaining: 2.5s
# 62:	learn: 0.1344401	total: 168ms	remaining: 2.5s
# 63:	learn: 0.1335884	total: 170ms	remaining: 2.49s
# 64:	learn: 0.1327419	total: 173ms	remaining: 2.48s
# 65:	learn: 0.1319439	total: 175ms	remaining: 2.48s
# 66:	learn: 0.1312981	total: 177ms	remaining: 2.47s
# 67:	learn: 0.1304314	total: 180ms	remaining: 2.46s
# 68:	learn: 0.1294188	total: 182ms	remaining: 2.46s
# 69:	learn: 0.1287507	total: 185ms	remaining: 2.45s
# 70:	learn: 0.1281793	total: 187ms	remaining: 2.44s
# 71:	learn: 0.1274794	total: 189ms	remaining: 2.44s
# 72:	learn: 0.1269010	total: 192ms	remaining: 2.43s
# 73:	learn: 0.1262924	total: 195ms	remaining: 2.44s
# 74:	learn: 0.1254837	total: 197ms	remaining: 2.43s
# 75:	learn: 0.1248972	total: 200ms	remaining: 2.43s
# 76:	learn: 0.1242599	total: 202ms	remaining: 2.43s
# 77:	learn: 0.1235820	total: 205ms	remaining: 2.42s
# 78:	learn: 0.1229583	total: 208ms	remaining: 2.42s
# 79:	learn: 0.1224770	total: 210ms	remaining: 2.41s
# 80:	learn: 0.1218555	total: 213ms	remaining: 2.41s
# 81:	learn: 0.1213092	total: 216ms	remaining: 2.41s
# 82:	learn: 0.1207525	total: 219ms	remaining: 2.41s
# 83:	learn: 0.1202349	total: 221ms	remaining: 2.41s
# 84:	learn: 0.1197133	total: 224ms	remaining: 2.41s
# 85:	learn: 0.1193171	total: 227ms	remaining: 2.41s
# 86:	learn: 0.1189152	total: 230ms	remaining: 2.41s
# 87:	learn: 0.1184788	total: 233ms	remaining: 2.41s
# 88:	learn: 0.1181017	total: 235ms	remaining: 2.41s
# 89:	learn: 0.1176068	total: 238ms	remaining: 2.41s
# 90:	learn: 0.1171307	total: 240ms	remaining: 2.4s
# 91:	learn: 0.1167212	total: 243ms	remaining: 2.4s
# 92:	learn: 0.1163189	total: 245ms	remaining: 2.39s
# 93:	learn: 0.1158616	total: 247ms	remaining: 2.38s
# 94:	learn: 0.1154273	total: 250ms	remaining: 2.38s
# 95:	learn: 0.1150855	total: 252ms	remaining: 2.37s
# 96:	learn: 0.1147062	total: 255ms	remaining: 2.37s
# 97:	learn: 0.1143056	total: 257ms	remaining: 2.37s
# 98:	learn: 0.1138107	total: 260ms	remaining: 2.36s
# 99:	learn: 0.1134659	total: 263ms	remaining: 2.37s
# 100:	learn: 0.1131744	total: 266ms	remaining: 2.36s
# 101:	learn: 0.1128401	total: 268ms	remaining: 2.36s
# 102:	learn: 0.1125037	total: 271ms	remaining: 2.36s
# 103:	learn: 0.1122148	total: 274ms	remaining: 2.36s
# 104:	learn: 0.1118976	total: 276ms	remaining: 2.35s
# 105:	learn: 0.1115463	total: 278ms	remaining: 2.35s
# 106:	learn: 0.1112335	total: 281ms	remaining: 2.34s
# 107:	learn: 0.1109344	total: 283ms	remaining: 2.34s
# 108:	learn: 0.1107067	total: 286ms	remaining: 2.34s
# 109:	learn: 0.1103589	total: 288ms	remaining: 2.33s
# 110:	learn: 0.1100414	total: 291ms	remaining: 2.33s
# 111:	learn: 0.1097191	total: 294ms	remaining: 2.33s
# 112:	learn: 0.1092955	total: 296ms	remaining: 2.32s
# 113:	learn: 0.1089132	total: 298ms	remaining: 2.32s
# 114:	learn: 0.1085449	total: 301ms	remaining: 2.31s
# 115:	learn: 0.1083260	total: 303ms	remaining: 2.31s
# 116:	learn: 0.1080606	total: 305ms	remaining: 2.3s
# 117:	learn: 0.1078211	total: 308ms	remaining: 2.3s
# 118:	learn: 0.1075451	total: 310ms	remaining: 2.29s
# 119:	learn: 0.1070963	total: 312ms	remaining: 2.29s
# 120:	learn: 0.1067746	total: 315ms	remaining: 2.29s
# 121:	learn: 0.1065172	total: 317ms	remaining: 2.28s
# 122:	learn: 0.1061878	total: 319ms	remaining: 2.27s
# 123:	learn: 0.1060044	total: 322ms	remaining: 2.27s
# 124:	learn: 0.1058612	total: 324ms	remaining: 2.27s
# 125:	learn: 0.1056693	total: 326ms	remaining: 2.26s
# 126:	learn: 0.1054345	total: 329ms	remaining: 2.26s
# 127:	learn: 0.1053168	total: 330ms	remaining: 2.25s
# 128:	learn: 0.1050972	total: 332ms	remaining: 2.24s
# 129:	learn: 0.1048453	total: 334ms	remaining: 2.24s
# 130:	learn: 0.1046987	total: 337ms	remaining: 2.23s
# 131:	learn: 0.1044387	total: 339ms	remaining: 2.23s
# 132:	learn: 0.1042671	total: 341ms	remaining: 2.23s
# 133:	learn: 0.1040704	total: 344ms	remaining: 2.22s
# 134:	learn: 0.1038375	total: 346ms	remaining: 2.22s
# 135:	learn: 0.1036701	total: 349ms	remaining: 2.21s
# 136:	learn: 0.1034368	total: 351ms	remaining: 2.21s
# 137:	learn: 0.1032778	total: 354ms	remaining: 2.21s
# 138:	learn: 0.1030004	total: 356ms	remaining: 2.2s
# 139:	learn: 0.1028472	total: 358ms	remaining: 2.2s
# 140:	learn: 0.1026884	total: 361ms	remaining: 2.2s
# 141:	learn: 0.1024627	total: 363ms	remaining: 2.19s
# 142:	learn: 0.1022111	total: 365ms	remaining: 2.19s
# 143:	learn: 0.1020597	total: 367ms	remaining: 2.18s
# 144:	learn: 0.1018557	total: 370ms	remaining: 2.18s
# 145:	learn: 0.1015364	total: 372ms	remaining: 2.17s
# 146:	learn: 0.1013921	total: 374ms	remaining: 2.17s
# 147:	learn: 0.1010950	total: 377ms	remaining: 2.17s
# 148:	learn: 0.1009457	total: 379ms	remaining: 2.16s
# 149:	learn: 0.1006643	total: 381ms	remaining: 2.16s
# 150:	learn: 0.1004926	total: 384ms	remaining: 2.16s
# 151:	learn: 0.1003540	total: 386ms	remaining: 2.15s
# 152:	learn: 0.1002124	total: 389ms	remaining: 2.15s
# 153:	learn: 0.1000963	total: 392ms	remaining: 2.15s
# 154:	learn: 0.0999689	total: 394ms	remaining: 2.15s
# 155:	learn: 0.0998197	total: 397ms	remaining: 2.15s
# 156:	learn: 0.0995930	total: 399ms	remaining: 2.14s
# 157:	learn: 0.0993288	total: 402ms	remaining: 2.14s
# 158:	learn: 0.0991732	total: 405ms	remaining: 2.14s
# 159:	learn: 0.0990340	total: 407ms	remaining: 2.14s
# 160:	learn: 0.0988872	total: 410ms	remaining: 2.14s
# 161:	learn: 0.0986772	total: 412ms	remaining: 2.13s
# 162:	learn: 0.0984604	total: 415ms	remaining: 2.13s
# 163:	learn: 0.0982549	total: 419ms	remaining: 2.13s
# 164:	learn: 0.0980294	total: 422ms	remaining: 2.13s
# 165:	learn: 0.0978767	total: 425ms	remaining: 2.13s
# 166:	learn: 0.0977551	total: 427ms	remaining: 2.13s
# 167:	learn: 0.0974910	total: 430ms	remaining: 2.13s
# 168:	learn: 0.0973189	total: 433ms	remaining: 2.13s
# 169:	learn: 0.0971530	total: 435ms	remaining: 2.12s
# 170:	learn: 0.0969902	total: 438ms	remaining: 2.12s
# 171:	learn: 0.0967852	total: 441ms	remaining: 2.12s
# 172:	learn: 0.0965300	total: 444ms	remaining: 2.12s
# 173:	learn: 0.0963929	total: 447ms	remaining: 2.12s
# 174:	learn: 0.0963230	total: 450ms	remaining: 2.12s
# 175:	learn: 0.0961477	total: 453ms	remaining: 2.12s
# 176:	learn: 0.0960504	total: 455ms	remaining: 2.12s
# 177:	learn: 0.0959663	total: 457ms	remaining: 2.11s
# 178:	learn: 0.0958049	total: 460ms	remaining: 2.11s
# 179:	learn: 0.0956535	total: 462ms	remaining: 2.1s
# 180:	learn: 0.0955447	total: 465ms	remaining: 2.1s
# 181:	learn: 0.0954236	total: 467ms	remaining: 2.1s
# 182:	learn: 0.0952977	total: 469ms	remaining: 2.1s
# 183:	learn: 0.0951001	total: 472ms	remaining: 2.09s
# 184:	learn: 0.0949162	total: 474ms	remaining: 2.09s
# 185:	learn: 0.0948116	total: 476ms	remaining: 2.08s
# 186:	learn: 0.0946473	total: 479ms	remaining: 2.08s
# 187:	learn: 0.0946062	total: 481ms	remaining: 2.08s
# 188:	learn: 0.0944910	total: 484ms	remaining: 2.08s
# 189:	learn: 0.0943686	total: 486ms	remaining: 2.07s
# 190:	learn: 0.0941966	total: 488ms	remaining: 2.07s
# 191:	learn: 0.0940195	total: 491ms	remaining: 2.06s
# 192:	learn: 0.0938382	total: 493ms	remaining: 2.06s
# 193:	learn: 0.0935982	total: 496ms	remaining: 2.06s
# 194:	learn: 0.0933053	total: 498ms	remaining: 2.06s
# 195:	learn: 0.0931300	total: 501ms	remaining: 2.05s
# 196:	learn: 0.0929378	total: 503ms	remaining: 2.05s
# 197:	learn: 0.0927721	total: 505ms	remaining: 2.05s
# 198:	learn: 0.0926035	total: 508ms	remaining: 2.04s
# 199:	learn: 0.0924665	total: 510ms	remaining: 2.04s
# 200:	learn: 0.0923449	total: 513ms	remaining: 2.04s
# 201:	learn: 0.0921779	total: 515ms	remaining: 2.03s
# 202:	learn: 0.0920019	total: 517ms	remaining: 2.03s
# 203:	learn: 0.0918820	total: 520ms	remaining: 2.03s
# 204:	learn: 0.0917242	total: 522ms	remaining: 2.02s
# 205:	learn: 0.0915434	total: 524ms	remaining: 2.02s
# 206:	learn: 0.0913245	total: 527ms	remaining: 2.02s
# 207:	learn: 0.0911359	total: 529ms	remaining: 2.02s
# 208:	learn: 0.0910280	total: 532ms	remaining: 2.01s
# 209:	learn: 0.0909318	total: 534ms	remaining: 2.01s
# 210:	learn: 0.0908554	total: 536ms	remaining: 2s
# 211:	learn: 0.0907267	total: 539ms	remaining: 2s
# 212:	learn: 0.0905876	total: 542ms	remaining: 2s
# 213:	learn: 0.0903579	total: 544ms	remaining: 2s
# 214:	learn: 0.0902110	total: 547ms	remaining: 2s
# 215:	learn: 0.0901006	total: 550ms	remaining: 1.99s
# 216:	learn: 0.0899783	total: 552ms	remaining: 1.99s
# 217:	learn: 0.0897929	total: 555ms	remaining: 1.99s
# 218:	learn: 0.0897280	total: 558ms	remaining: 1.99s
# 219:	learn: 0.0896037	total: 561ms	remaining: 1.99s
# 220:	learn: 0.0895293	total: 563ms	remaining: 1.99s
# 221:	learn: 0.0894677	total: 566ms	remaining: 1.98s
# 222:	learn: 0.0892371	total: 569ms	remaining: 1.98s
# 223:	learn: 0.0891858	total: 571ms	remaining: 1.98s
# 224:	learn: 0.0891086	total: 575ms	remaining: 1.98s
# 225:	learn: 0.0889252	total: 578ms	remaining: 1.98s
# 226:	learn: 0.0887998	total: 580ms	remaining: 1.98s
# 227:	learn: 0.0886528	total: 583ms	remaining: 1.97s
# 228:	learn: 0.0885812	total: 586ms	remaining: 1.97s
# 229:	learn: 0.0884702	total: 588ms	remaining: 1.97s
# 230:	learn: 0.0882771	total: 591ms	remaining: 1.97s
# 231:	learn: 0.0881281	total: 594ms	remaining: 1.97s
# 232:	learn: 0.0879758	total: 596ms	remaining: 1.96s
# 233:	learn: 0.0879096	total: 599ms	remaining: 1.96s
# 234:	learn: 0.0878181	total: 602ms	remaining: 1.96s
# 235:	learn: 0.0876806	total: 605ms	remaining: 1.96s
# 236:	learn: 0.0874538	total: 608ms	remaining: 1.96s
# 237:	learn: 0.0873204	total: 611ms	remaining: 1.96s
# 238:	learn: 0.0871554	total: 614ms	remaining: 1.96s
# 239:	learn: 0.0870397	total: 617ms	remaining: 1.95s
# 240:	learn: 0.0869822	total: 621ms	remaining: 1.96s
# 241:	learn: 0.0869109	total: 624ms	remaining: 1.96s
# 242:	learn: 0.0867594	total: 628ms	remaining: 1.96s
# 243:	learn: 0.0866104	total: 631ms	remaining: 1.95s
# 244:	learn: 0.0865133	total: 633ms	remaining: 1.95s
# 245:	learn: 0.0864743	total: 636ms	remaining: 1.95s
# 246:	learn: 0.0864307	total: 639ms	remaining: 1.95s
# 247:	learn: 0.0863082	total: 642ms	remaining: 1.95s
# 248:	learn: 0.0861257	total: 645ms	remaining: 1.95s
# 249:	learn: 0.0859983	total: 648ms	remaining: 1.94s
# 250:	learn: 0.0859137	total: 653ms	remaining: 1.95s
# 251:	learn: 0.0858117	total: 658ms	remaining: 1.95s
# 252:	learn: 0.0856912	total: 662ms	remaining: 1.96s
# 253:	learn: 0.0856355	total: 667ms	remaining: 1.96s
# 254:	learn: 0.0854517	total: 673ms	remaining: 1.96s
# 255:	learn: 0.0852919	total: 677ms	remaining: 1.97s
# 256:	learn: 0.0851440	total: 681ms	remaining: 1.97s
# 257:	learn: 0.0850161	total: 689ms	remaining: 1.98s
# 258:	learn: 0.0848143	total: 694ms	remaining: 1.99s
# 259:	learn: 0.0846924	total: 699ms	remaining: 1.99s
# 260:	learn: 0.0846030	total: 704ms	remaining: 1.99s
# 261:	learn: 0.0844782	total: 709ms	remaining: 2s
# 262:	learn: 0.0844089	total: 713ms	remaining: 2s
# 263:	learn: 0.0842530	total: 718ms	remaining: 2s
# 264:	learn: 0.0841307	total: 732ms	remaining: 2.03s
# 265:	learn: 0.0840340	total: 736ms	remaining: 2.03s
# 266:	learn: 0.0838600	total: 740ms	remaining: 2.03s
# 267:	learn: 0.0837371	total: 744ms	remaining: 2.03s
# 268:	learn: 0.0836016	total: 748ms	remaining: 2.03s
# 269:	learn: 0.0835704	total: 752ms	remaining: 2.03s
# 270:	learn: 0.0835194	total: 756ms	remaining: 2.03s
# 271:	learn: 0.0833351	total: 759ms	remaining: 2.03s
# 272:	learn: 0.0832975	total: 763ms	remaining: 2.03s
# 273:	learn: 0.0832098	total: 781ms	remaining: 2.07s
# 274:	learn: 0.0830281	total: 785ms	remaining: 2.07s
# 275:	learn: 0.0829054	total: 788ms	remaining: 2.07s
# 276:	learn: 0.0828161	total: 793ms	remaining: 2.07s
# 277:	learn: 0.0827760	total: 797ms	remaining: 2.07s
# 278:	learn: 0.0825880	total: 800ms	remaining: 2.07s
# 279:	learn: 0.0825189	total: 803ms	remaining: 2.06s
# 280:	learn: 0.0824492	total: 807ms	remaining: 2.06s
# 281:	learn: 0.0823273	total: 810ms	remaining: 2.06s
# 282:	learn: 0.0821727	total: 813ms	remaining: 2.06s
# 283:	learn: 0.0820822	total: 817ms	remaining: 2.06s
# 284:	learn: 0.0820138	total: 819ms	remaining: 2.06s
# 285:	learn: 0.0819785	total: 822ms	remaining: 2.05s
# 286:	learn: 0.0818349	total: 825ms	remaining: 2.05s
# 287:	learn: 0.0817519	total: 829ms	remaining: 2.05s
# 288:	learn: 0.0816474	total: 832ms	remaining: 2.04s
# 289:	learn: 0.0814871	total: 834ms	remaining: 2.04s
# 290:	learn: 0.0814367	total: 838ms	remaining: 2.04s
# 291:	learn: 0.0812629	total: 841ms	remaining: 2.04s
# 292:	learn: 0.0811543	total: 844ms	remaining: 2.04s
# 293:	learn: 0.0809938	total: 847ms	remaining: 2.03s
# 294:	learn: 0.0808533	total: 850ms	remaining: 2.03s
# 295:	learn: 0.0807465	total: 853ms	remaining: 2.03s
# 296:	learn: 0.0806035	total: 855ms	remaining: 2.02s
# 297:	learn: 0.0804181	total: 858ms	remaining: 2.02s
# 298:	learn: 0.0803853	total: 861ms	remaining: 2.02s
# 299:	learn: 0.0802543	total: 864ms	remaining: 2.02s
# 300:	learn: 0.0801634	total: 867ms	remaining: 2.01s
# 301:	learn: 0.0800816	total: 870ms	remaining: 2.01s
# 302:	learn: 0.0800506	total: 872ms	remaining: 2.01s
# 303:	learn: 0.0798615	total: 876ms	remaining: 2s
# 304:	learn: 0.0797393	total: 879ms	remaining: 2s
# 305:	learn: 0.0795775	total: 881ms	remaining: 2s
# 306:	learn: 0.0793825	total: 884ms	remaining: 2s
# 307:	learn: 0.0792863	total: 887ms	remaining: 1.99s
# 308:	learn: 0.0791758	total: 890ms	remaining: 1.99s
# 309:	learn: 0.0789873	total: 893ms	remaining: 1.99s
# 310:	learn: 0.0789192	total: 896ms	remaining: 1.99s
# 311:	learn: 0.0788128	total: 899ms	remaining: 1.98s
# 312:	learn: 0.0787306	total: 901ms	remaining: 1.98s
# 313:	learn: 0.0786034	total: 904ms	remaining: 1.98s
# 314:	learn: 0.0784828	total: 908ms	remaining: 1.97s
# 315:	learn: 0.0783915	total: 910ms	remaining: 1.97s
# 316:	learn: 0.0782172	total: 913ms	remaining: 1.97s
# 317:	learn: 0.0781381	total: 916ms	remaining: 1.96s
# 318:	learn: 0.0780395	total: 919ms	remaining: 1.96s
# 319:	learn: 0.0778684	total: 921ms	remaining: 1.96s
# 320:	learn: 0.0777795	total: 924ms	remaining: 1.95s
# 321:	learn: 0.0776826	total: 926ms	remaining: 1.95s
# 322:	learn: 0.0776476	total: 928ms	remaining: 1.95s
# 323:	learn: 0.0775662	total: 931ms	remaining: 1.94s
# 324:	learn: 0.0775456	total: 933ms	remaining: 1.94s
# 325:	learn: 0.0773902	total: 935ms	remaining: 1.93s
# 326:	learn: 0.0772722	total: 938ms	remaining: 1.93s
# 327:	learn: 0.0772309	total: 940ms	remaining: 1.93s
# 328:	learn: 0.0771334	total: 942ms	remaining: 1.92s
# 329:	learn: 0.0770301	total: 945ms	remaining: 1.92s
# 330:	learn: 0.0768936	total: 947ms	remaining: 1.91s
# 331:	learn: 0.0768064	total: 950ms	remaining: 1.91s
# 332:	learn: 0.0766460	total: 952ms	remaining: 1.91s
# 333:	learn: 0.0765465	total: 955ms	remaining: 1.9s
# 334:	learn: 0.0764350	total: 957ms	remaining: 1.9s
# 335:	learn: 0.0764220	total: 959ms	remaining: 1.9s
# 336:	learn: 0.0762806	total: 962ms	remaining: 1.89s
# 337:	learn: 0.0761616	total: 964ms	remaining: 1.89s
# 338:	learn: 0.0760384	total: 966ms	remaining: 1.88s
# 339:	learn: 0.0759313	total: 969ms	remaining: 1.88s
# 340:	learn: 0.0758480	total: 971ms	remaining: 1.88s
# 341:	learn: 0.0757774	total: 973ms	remaining: 1.87s
# 342:	learn: 0.0756667	total: 976ms	remaining: 1.87s
# 343:	learn: 0.0755793	total: 978ms	remaining: 1.86s
# 344:	learn: 0.0754381	total: 980ms	remaining: 1.86s
# 345:	learn: 0.0753030	total: 983ms	remaining: 1.86s
# 346:	learn: 0.0752570	total: 986ms	remaining: 1.85s
# 347:	learn: 0.0751666	total: 989ms	remaining: 1.85s
# 348:	learn: 0.0750234	total: 992ms	remaining: 1.85s
# 349:	learn: 0.0749102	total: 994ms	remaining: 1.85s
# 350:	learn: 0.0749004	total: 996ms	remaining: 1.84s
# 351:	learn: 0.0747749	total: 999ms	remaining: 1.84s
# 352:	learn: 0.0746933	total: 1s	remaining: 1.83s
# 353:	learn: 0.0746405	total: 1s	remaining: 1.83s
# 354:	learn: 0.0745428	total: 1.01s	remaining: 1.83s
# 355:	learn: 0.0744649	total: 1.01s	remaining: 1.82s
# 356:	learn: 0.0744152	total: 1.01s	remaining: 1.82s
# 357:	learn: 0.0743511	total: 1.01s	remaining: 1.82s
# 358:	learn: 0.0743246	total: 1.02s	remaining: 1.82s
# 359:	learn: 0.0742453	total: 1.02s	remaining: 1.81s
# 360:	learn: 0.0741465	total: 1.02s	remaining: 1.81s
# 361:	learn: 0.0740162	total: 1.03s	remaining: 1.81s
# 362:	learn: 0.0739928	total: 1.03s	remaining: 1.8s
# 363:	learn: 0.0739804	total: 1.03s	remaining: 1.8s
# 364:	learn: 0.0739270	total: 1.03s	remaining: 1.8s
# 365:	learn: 0.0738327	total: 1.04s	remaining: 1.79s
# 366:	learn: 0.0738080	total: 1.04s	remaining: 1.79s
# 367:	learn: 0.0737846	total: 1.04s	remaining: 1.79s
# 368:	learn: 0.0737101	total: 1.04s	remaining: 1.78s
# 369:	learn: 0.0736775	total: 1.04s	remaining: 1.78s
# 370:	learn: 0.0736337	total: 1.05s	remaining: 1.78s
# 371:	learn: 0.0735239	total: 1.05s	remaining: 1.77s
# 372:	learn: 0.0733818	total: 1.05s	remaining: 1.77s
# 373:	learn: 0.0732647	total: 1.05s	remaining: 1.76s
# 374:	learn: 0.0731175	total: 1.06s	remaining: 1.76s
# 375:	learn: 0.0729932	total: 1.06s	remaining: 1.76s
# 376:	learn: 0.0729168	total: 1.06s	remaining: 1.75s
# 377:	learn: 0.0728416	total: 1.06s	remaining: 1.75s
# 378:	learn: 0.0727726	total: 1.07s	remaining: 1.75s
# 379:	learn: 0.0726375	total: 1.07s	remaining: 1.75s
# 380:	learn: 0.0725878	total: 1.07s	remaining: 1.74s
# 381:	learn: 0.0724815	total: 1.07s	remaining: 1.74s
# 382:	learn: 0.0724076	total: 1.08s	remaining: 1.74s
# 383:	learn: 0.0723298	total: 1.08s	remaining: 1.73s
# 384:	learn: 0.0722453	total: 1.08s	remaining: 1.73s
# 385:	learn: 0.0721632	total: 1.09s	remaining: 1.73s
# 386:	learn: 0.0720885	total: 1.09s	remaining: 1.73s
# 387:	learn: 0.0719579	total: 1.09s	remaining: 1.72s
# 388:	learn: 0.0718129	total: 1.09s	remaining: 1.72s
# 389:	learn: 0.0717630	total: 1.1s	remaining: 1.72s
# 390:	learn: 0.0716484	total: 1.1s	remaining: 1.71s
# 391:	learn: 0.0715634	total: 1.1s	remaining: 1.71s
# 392:	learn: 0.0714573	total: 1.1s	remaining: 1.71s
# 393:	learn: 0.0713370	total: 1.11s	remaining: 1.7s
# 394:	learn: 0.0713151	total: 1.11s	remaining: 1.7s
# 395:	learn: 0.0712526	total: 1.11s	remaining: 1.7s
# 396:	learn: 0.0712410	total: 1.11s	remaining: 1.69s
# 397:	learn: 0.0711233	total: 1.12s	remaining: 1.69s
# 398:	learn: 0.0710584	total: 1.12s	remaining: 1.69s
# 399:	learn: 0.0709592	total: 1.12s	remaining: 1.68s
# 400:	learn: 0.0708609	total: 1.13s	remaining: 1.68s
# 401:	learn: 0.0707930	total: 1.13s	remaining: 1.68s
# 402:	learn: 0.0707600	total: 1.13s	remaining: 1.68s
# 403:	learn: 0.0706809	total: 1.13s	remaining: 1.67s
# 404:	learn: 0.0706526	total: 1.14s	remaining: 1.67s
# 405:	learn: 0.0705749	total: 1.14s	remaining: 1.67s
# 406:	learn: 0.0705301	total: 1.14s	remaining: 1.67s
# 407:	learn: 0.0704120	total: 1.15s	remaining: 1.66s
# 408:	learn: 0.0703699	total: 1.15s	remaining: 1.66s
# 409:	learn: 0.0702365	total: 1.15s	remaining: 1.66s
# 410:	learn: 0.0701257	total: 1.15s	remaining: 1.65s
# 411:	learn: 0.0700867	total: 1.16s	remaining: 1.65s
# 412:	learn: 0.0699604	total: 1.16s	remaining: 1.65s
# 413:	learn: 0.0698915	total: 1.16s	remaining: 1.64s
# 414:	learn: 0.0698228	total: 1.16s	remaining: 1.64s
# 415:	learn: 0.0697771	total: 1.17s	remaining: 1.64s
# 416:	learn: 0.0697113	total: 1.17s	remaining: 1.64s
# 417:	learn: 0.0696275	total: 1.17s	remaining: 1.63s
# 418:	learn: 0.0696110	total: 1.17s	remaining: 1.63s
# 419:	learn: 0.0694738	total: 1.18s	remaining: 1.63s
# 420:	learn: 0.0693975	total: 1.18s	remaining: 1.62s
# 421:	learn: 0.0693020	total: 1.18s	remaining: 1.62s
# 422:	learn: 0.0692111	total: 1.19s	remaining: 1.62s
# 423:	learn: 0.0691254	total: 1.19s	remaining: 1.61s
# 424:	learn: 0.0690616	total: 1.19s	remaining: 1.61s
# 425:	learn: 0.0689222	total: 1.19s	remaining: 1.61s
# 426:	learn: 0.0688388	total: 1.2s	remaining: 1.61s
# 427:	learn: 0.0686974	total: 1.2s	remaining: 1.6s
# 428:	learn: 0.0685781	total: 1.2s	remaining: 1.6s
# 429:	learn: 0.0685043	total: 1.21s	remaining: 1.6s
# 430:	learn: 0.0684682	total: 1.21s	remaining: 1.6s
# 431:	learn: 0.0683727	total: 1.21s	remaining: 1.59s
# 432:	learn: 0.0682755	total: 1.21s	remaining: 1.59s
# 433:	learn: 0.0682127	total: 1.22s	remaining: 1.59s
# 434:	learn: 0.0681956	total: 1.22s	remaining: 1.58s
# 435:	learn: 0.0681119	total: 1.22s	remaining: 1.58s
# 436:	learn: 0.0680419	total: 1.22s	remaining: 1.58s
# 437:	learn: 0.0679214	total: 1.23s	remaining: 1.57s
# 438:	learn: 0.0678229	total: 1.23s	remaining: 1.57s
# 439:	learn: 0.0677912	total: 1.23s	remaining: 1.56s
# 440:	learn: 0.0676786	total: 1.23s	remaining: 1.56s
# 441:	learn: 0.0676009	total: 1.23s	remaining: 1.56s
# 442:	learn: 0.0675418	total: 1.24s	remaining: 1.55s
# 443:	learn: 0.0674372	total: 1.24s	remaining: 1.55s
# 444:	learn: 0.0673230	total: 1.24s	remaining: 1.55s
# 445:	learn: 0.0672236	total: 1.25s	remaining: 1.55s
# 446:	learn: 0.0671439	total: 1.25s	remaining: 1.54s
# 447:	learn: 0.0671273	total: 1.25s	remaining: 1.54s
# 448:	learn: 0.0669969	total: 1.25s	remaining: 1.54s
# 449:	learn: 0.0669323	total: 1.26s	remaining: 1.54s
# 450:	learn: 0.0668838	total: 1.26s	remaining: 1.53s
# 451:	learn: 0.0668528	total: 1.26s	remaining: 1.53s
# 452:	learn: 0.0667514	total: 1.26s	remaining: 1.52s
# 453:	learn: 0.0666478	total: 1.27s	remaining: 1.52s
# 454:	learn: 0.0665427	total: 1.27s	remaining: 1.52s
# 455:	learn: 0.0664465	total: 1.27s	remaining: 1.52s
# 456:	learn: 0.0663417	total: 1.27s	remaining: 1.51s
# 457:	learn: 0.0662901	total: 1.28s	remaining: 1.51s
# 458:	learn: 0.0662145	total: 1.28s	remaining: 1.51s
# 459:	learn: 0.0661255	total: 1.28s	remaining: 1.5s
# 460:	learn: 0.0660568	total: 1.28s	remaining: 1.5s
# 461:	learn: 0.0659995	total: 1.29s	remaining: 1.5s
# 462:	learn: 0.0659234	total: 1.29s	remaining: 1.5s
# 463:	learn: 0.0657976	total: 1.29s	remaining: 1.49s
# 464:	learn: 0.0657299	total: 1.29s	remaining: 1.49s
# 465:	learn: 0.0657081	total: 1.29s	remaining: 1.48s
# 466:	learn: 0.0655929	total: 1.3s	remaining: 1.48s
# 467:	learn: 0.0655098	total: 1.3s	remaining: 1.48s
# 468:	learn: 0.0654642	total: 1.3s	remaining: 1.48s
# 469:	learn: 0.0654315	total: 1.3s	remaining: 1.47s
# 470:	learn: 0.0653401	total: 1.31s	remaining: 1.47s
# 471:	learn: 0.0652522	total: 1.31s	remaining: 1.47s
# 472:	learn: 0.0652080	total: 1.31s	remaining: 1.46s
# 473:	learn: 0.0651546	total: 1.31s	remaining: 1.46s
# 474:	learn: 0.0650383	total: 1.32s	remaining: 1.46s
# 475:	learn: 0.0649013	total: 1.32s	remaining: 1.45s
# 476:	learn: 0.0648517	total: 1.32s	remaining: 1.45s
# 477:	learn: 0.0647795	total: 1.32s	remaining: 1.45s
# 478:	learn: 0.0647196	total: 1.33s	remaining: 1.44s
# 479:	learn: 0.0645992	total: 1.33s	remaining: 1.44s
# 480:	learn: 0.0645335	total: 1.33s	remaining: 1.44s
# 481:	learn: 0.0644525	total: 1.33s	remaining: 1.43s
# 482:	learn: 0.0643515	total: 1.33s	remaining: 1.43s
# 483:	learn: 0.0642925	total: 1.34s	remaining: 1.43s
# 484:	learn: 0.0642348	total: 1.34s	remaining: 1.42s
# 485:	learn: 0.0641562	total: 1.34s	remaining: 1.42s
# 486:	learn: 0.0640583	total: 1.34s	remaining: 1.42s
# 487:	learn: 0.0639828	total: 1.35s	remaining: 1.41s
# 488:	learn: 0.0638967	total: 1.35s	remaining: 1.41s
# 489:	learn: 0.0638280	total: 1.35s	remaining: 1.41s
# 490:	learn: 0.0637440	total: 1.35s	remaining: 1.4s
# 491:	learn: 0.0636003	total: 1.36s	remaining: 1.4s
# 492:	learn: 0.0635172	total: 1.36s	remaining: 1.4s
# 493:	learn: 0.0634339	total: 1.36s	remaining: 1.39s
# 494:	learn: 0.0633608	total: 1.36s	remaining: 1.39s
# 495:	learn: 0.0632950	total: 1.37s	remaining: 1.39s
# 496:	learn: 0.0632550	total: 1.37s	remaining: 1.39s
# 497:	learn: 0.0631985	total: 1.37s	remaining: 1.38s
# 498:	learn: 0.0631260	total: 1.37s	remaining: 1.38s
# 499:	learn: 0.0630636	total: 1.38s	remaining: 1.38s
# 500:	learn: 0.0630505	total: 1.38s	remaining: 1.37s
# 501:	learn: 0.0630114	total: 1.38s	remaining: 1.37s
# 502:	learn: 0.0629281	total: 1.39s	remaining: 1.37s
# 503:	learn: 0.0628927	total: 1.39s	remaining: 1.37s
# 504:	learn: 0.0627971	total: 1.39s	remaining: 1.36s
# 505:	learn: 0.0627004	total: 1.39s	remaining: 1.36s
# 506:	learn: 0.0626445	total: 1.4s	remaining: 1.36s
# 507:	learn: 0.0626002	total: 1.4s	remaining: 1.35s
# 508:	learn: 0.0625906	total: 1.4s	remaining: 1.35s
# 509:	learn: 0.0625271	total: 1.4s	remaining: 1.35s
# 510:	learn: 0.0624596	total: 1.41s	remaining: 1.34s
# 511:	learn: 0.0624070	total: 1.41s	remaining: 1.34s
# 512:	learn: 0.0623134	total: 1.41s	remaining: 1.34s
# 513:	learn: 0.0622687	total: 1.41s	remaining: 1.34s
# 514:	learn: 0.0621948	total: 1.42s	remaining: 1.33s
# 515:	learn: 0.0621478	total: 1.42s	remaining: 1.33s
# 516:	learn: 0.0620502	total: 1.42s	remaining: 1.33s
# 517:	learn: 0.0619856	total: 1.42s	remaining: 1.32s
# 518:	learn: 0.0619272	total: 1.43s	remaining: 1.32s
# 519:	learn: 0.0618872	total: 1.43s	remaining: 1.32s
# 520:	learn: 0.0617999	total: 1.43s	remaining: 1.31s
# 521:	learn: 0.0617482	total: 1.43s	remaining: 1.31s
# 522:	learn: 0.0617290	total: 1.44s	remaining: 1.31s
# 523:	learn: 0.0616510	total: 1.44s	remaining: 1.31s
# 524:	learn: 0.0615509	total: 1.44s	remaining: 1.3s
# 525:	learn: 0.0614883	total: 1.44s	remaining: 1.3s
# 526:	learn: 0.0614377	total: 1.45s	remaining: 1.3s
# 527:	learn: 0.0613355	total: 1.45s	remaining: 1.29s
# 528:	learn: 0.0612761	total: 1.45s	remaining: 1.29s
# 529:	learn: 0.0612074	total: 1.45s	remaining: 1.29s
# 530:	learn: 0.0611807	total: 1.46s	remaining: 1.28s
# 531:	learn: 0.0610866	total: 1.46s	remaining: 1.28s
# 532:	learn: 0.0610017	total: 1.46s	remaining: 1.28s
# 533:	learn: 0.0609488	total: 1.46s	remaining: 1.28s
# 534:	learn: 0.0608810	total: 1.47s	remaining: 1.27s
# 535:	learn: 0.0608314	total: 1.47s	remaining: 1.27s
# 536:	learn: 0.0607029	total: 1.47s	remaining: 1.27s
# 537:	learn: 0.0605893	total: 1.47s	remaining: 1.26s
# 538:	learn: 0.0604877	total: 1.48s	remaining: 1.26s
# 539:	learn: 0.0603908	total: 1.48s	remaining: 1.26s
# 540:	learn: 0.0602817	total: 1.48s	remaining: 1.26s
# 541:	learn: 0.0602324	total: 1.48s	remaining: 1.25s
# 542:	learn: 0.0602120	total: 1.49s	remaining: 1.25s
# 543:	learn: 0.0601507	total: 1.49s	remaining: 1.25s
# 544:	learn: 0.0600917	total: 1.49s	remaining: 1.25s
# 545:	learn: 0.0599990	total: 1.49s	remaining: 1.24s
# 546:	learn: 0.0598992	total: 1.5s	remaining: 1.24s
# 547:	learn: 0.0598333	total: 1.5s	remaining: 1.24s
# 548:	learn: 0.0597228	total: 1.5s	remaining: 1.23s
# 549:	learn: 0.0596847	total: 1.5s	remaining: 1.23s
# 550:	learn: 0.0596015	total: 1.5s	remaining: 1.23s
# 551:	learn: 0.0595518	total: 1.51s	remaining: 1.22s
# 552:	learn: 0.0595014	total: 1.51s	remaining: 1.22s
# 553:	learn: 0.0594025	total: 1.51s	remaining: 1.22s
# 554:	learn: 0.0593846	total: 1.51s	remaining: 1.22s
# 555:	learn: 0.0592740	total: 1.52s	remaining: 1.21s
# 556:	learn: 0.0592134	total: 1.52s	remaining: 1.21s
# 557:	learn: 0.0591854	total: 1.52s	remaining: 1.21s
# 558:	learn: 0.0591094	total: 1.53s	remaining: 1.2s
# 559:	learn: 0.0590639	total: 1.53s	remaining: 1.2s
# 560:	learn: 0.0589679	total: 1.53s	remaining: 1.2s
# 561:	learn: 0.0589253	total: 1.53s	remaining: 1.2s
# 562:	learn: 0.0588542	total: 1.54s	remaining: 1.19s
# 563:	learn: 0.0587501	total: 1.54s	remaining: 1.19s
# 564:	learn: 0.0586957	total: 1.54s	remaining: 1.19s
# 565:	learn: 0.0586407	total: 1.54s	remaining: 1.18s
# 566:	learn: 0.0585818	total: 1.55s	remaining: 1.18s
# 567:	learn: 0.0585632	total: 1.55s	remaining: 1.18s
# 568:	learn: 0.0585530	total: 1.55s	remaining: 1.17s
# 569:	learn: 0.0584709	total: 1.55s	remaining: 1.17s
# 570:	learn: 0.0584269	total: 1.55s	remaining: 1.17s
# 571:	learn: 0.0583373	total: 1.56s	remaining: 1.17s
# 572:	learn: 0.0583107	total: 1.56s	remaining: 1.16s
# 573:	learn: 0.0582238	total: 1.56s	remaining: 1.16s
# 574:	learn: 0.0581591	total: 1.56s	remaining: 1.16s
# 575:	learn: 0.0581010	total: 1.57s	remaining: 1.15s
# 576:	learn: 0.0580434	total: 1.57s	remaining: 1.15s
# 577:	learn: 0.0580023	total: 1.57s	remaining: 1.15s
# 578:	learn: 0.0579101	total: 1.58s	remaining: 1.15s
# 579:	learn: 0.0578277	total: 1.58s	remaining: 1.14s
# 580:	learn: 0.0577561	total: 1.58s	remaining: 1.14s
# 581:	learn: 0.0576385	total: 1.58s	remaining: 1.14s
# 582:	learn: 0.0575394	total: 1.59s	remaining: 1.14s
# 583:	learn: 0.0574918	total: 1.59s	remaining: 1.13s
# 584:	learn: 0.0574288	total: 1.59s	remaining: 1.13s
# 585:	learn: 0.0573553	total: 1.59s	remaining: 1.13s
# 586:	learn: 0.0572895	total: 1.6s	remaining: 1.12s
# 587:	learn: 0.0572356	total: 1.6s	remaining: 1.12s
# 588:	learn: 0.0572290	total: 1.6s	remaining: 1.12s
# 589:	learn: 0.0571679	total: 1.6s	remaining: 1.11s
# 590:	learn: 0.0570965	total: 1.61s	remaining: 1.11s
# 591:	learn: 0.0570215	total: 1.61s	remaining: 1.11s
# 592:	learn: 0.0569717	total: 1.61s	remaining: 1.11s
# 593:	learn: 0.0569103	total: 1.61s	remaining: 1.1s
# 594:	learn: 0.0568197	total: 1.62s	remaining: 1.1s
# 595:	learn: 0.0567618	total: 1.62s	remaining: 1.1s
# 596:	learn: 0.0566983	total: 1.62s	remaining: 1.09s
# 597:	learn: 0.0566181	total: 1.62s	remaining: 1.09s
# 598:	learn: 0.0565309	total: 1.63s	remaining: 1.09s
# 599:	learn: 0.0564867	total: 1.63s	remaining: 1.09s
# 600:	learn: 0.0564378	total: 1.63s	remaining: 1.08s
# 601:	learn: 0.0563733	total: 1.63s	remaining: 1.08s
# 602:	learn: 0.0562861	total: 1.64s	remaining: 1.08s
# 603:	learn: 0.0562180	total: 1.64s	remaining: 1.07s
# 604:	learn: 0.0561645	total: 1.64s	remaining: 1.07s
# 605:	learn: 0.0561113	total: 1.64s	remaining: 1.07s
# 606:	learn: 0.0560630	total: 1.65s	remaining: 1.07s
# 607:	learn: 0.0559755	total: 1.65s	remaining: 1.06s
# 608:	learn: 0.0559128	total: 1.65s	remaining: 1.06s
# 609:	learn: 0.0558351	total: 1.66s	remaining: 1.06s
# 610:	learn: 0.0557695	total: 1.66s	remaining: 1.05s
# 611:	learn: 0.0556946	total: 1.66s	remaining: 1.05s
# 612:	learn: 0.0556003	total: 1.66s	remaining: 1.05s
# 613:	learn: 0.0555441	total: 1.67s	remaining: 1.05s
# 614:	learn: 0.0554511	total: 1.67s	remaining: 1.04s
# 615:	learn: 0.0553655	total: 1.67s	remaining: 1.04s
# 616:	learn: 0.0552995	total: 1.68s	remaining: 1.04s
# 617:	learn: 0.0552652	total: 1.68s	remaining: 1.04s
# 618:	learn: 0.0552028	total: 1.68s	remaining: 1.03s
# 619:	learn: 0.0551435	total: 1.68s	remaining: 1.03s
# 620:	learn: 0.0551005	total: 1.69s	remaining: 1.03s
# 621:	learn: 0.0550653	total: 1.69s	remaining: 1.03s
# 622:	learn: 0.0550396	total: 1.69s	remaining: 1.02s
# 623:	learn: 0.0549873	total: 1.69s	remaining: 1.02s
# 624:	learn: 0.0549286	total: 1.7s	remaining: 1.02s
# 625:	learn: 0.0548838	total: 1.7s	remaining: 1.01s
# 626:	learn: 0.0547930	total: 1.7s	remaining: 1.01s
# 627:	learn: 0.0547746	total: 1.71s	remaining: 1.01s
# 628:	learn: 0.0547513	total: 1.71s	remaining: 1.01s
# 629:	learn: 0.0546975	total: 1.71s	remaining: 1s
# 630:	learn: 0.0546431	total: 1.71s	remaining: 1s
# 631:	learn: 0.0546104	total: 1.72s	remaining: 1000ms
# 632:	learn: 0.0545491	total: 1.72s	remaining: 997ms
# 633:	learn: 0.0544738	total: 1.72s	remaining: 994ms
# 634:	learn: 0.0543940	total: 1.72s	remaining: 991ms
# 635:	learn: 0.0543055	total: 1.73s	remaining: 989ms
# 636:	learn: 0.0542357	total: 1.73s	remaining: 986ms
# 637:	learn: 0.0541998	total: 1.73s	remaining: 984ms
# 638:	learn: 0.0541377	total: 1.74s	remaining: 981ms
# 639:	learn: 0.0540869	total: 1.74s	remaining: 978ms
# 640:	learn: 0.0540830	total: 1.74s	remaining: 975ms
# 641:	learn: 0.0540206	total: 1.74s	remaining: 973ms
# 642:	learn: 0.0539586	total: 1.75s	remaining: 970ms
# 643:	learn: 0.0539209	total: 1.75s	remaining: 968ms
# 644:	learn: 0.0538717	total: 1.75s	remaining: 965ms
# 645:	learn: 0.0537942	total: 1.75s	remaining: 962ms
# 646:	learn: 0.0537457	total: 1.76s	remaining: 960ms
# 647:	learn: 0.0536829	total: 1.76s	remaining: 957ms
# 648:	learn: 0.0536499	total: 1.76s	remaining: 955ms
# 649:	learn: 0.0535743	total: 1.77s	remaining: 952ms
# 650:	learn: 0.0535279	total: 1.77s	remaining: 949ms
# 651:	learn: 0.0534726	total: 1.77s	remaining: 946ms
# 652:	learn: 0.0534669	total: 1.77s	remaining: 944ms
# 653:	learn: 0.0534400	total: 1.78s	remaining: 941ms
# 654:	learn: 0.0533221	total: 1.78s	remaining: 938ms
# 655:	learn: 0.0532593	total: 1.78s	remaining: 935ms
# 656:	learn: 0.0532162	total: 1.79s	remaining: 933ms
# 657:	learn: 0.0531723	total: 1.79s	remaining: 930ms
# 658:	learn: 0.0531061	total: 1.79s	remaining: 927ms
# 659:	learn: 0.0531021	total: 1.79s	remaining: 925ms
# 660:	learn: 0.0530520	total: 1.8s	remaining: 922ms
# 661:	learn: 0.0529684	total: 1.8s	remaining: 919ms
# 662:	learn: 0.0529321	total: 1.8s	remaining: 917ms
# 663:	learn: 0.0528719	total: 1.81s	remaining: 914ms
# 664:	learn: 0.0527908	total: 1.81s	remaining: 912ms
# 665:	learn: 0.0527481	total: 1.81s	remaining: 909ms
# 666:	learn: 0.0526471	total: 1.81s	remaining: 906ms
# 667:	learn: 0.0525837	total: 1.82s	remaining: 903ms
# 668:	learn: 0.0525801	total: 1.82s	remaining: 901ms
# 669:	learn: 0.0525435	total: 1.82s	remaining: 898ms
# 670:	learn: 0.0525278	total: 1.82s	remaining: 895ms
# 671:	learn: 0.0524967	total: 1.83s	remaining: 892ms
# 672:	learn: 0.0524458	total: 1.83s	remaining: 889ms
# 673:	learn: 0.0523850	total: 1.83s	remaining: 887ms
# 674:	learn: 0.0522963	total: 1.84s	remaining: 884ms
# 675:	learn: 0.0522588	total: 1.84s	remaining: 881ms
# 676:	learn: 0.0522320	total: 1.84s	remaining: 879ms
# 677:	learn: 0.0521667	total: 1.84s	remaining: 876ms
# 678:	learn: 0.0521304	total: 1.85s	remaining: 873ms
# 679:	learn: 0.0520360	total: 1.85s	remaining: 870ms
# 680:	learn: 0.0519882	total: 1.85s	remaining: 868ms
# 681:	learn: 0.0519482	total: 1.85s	remaining: 865ms
# 682:	learn: 0.0519082	total: 1.86s	remaining: 862ms
# 683:	learn: 0.0518814	total: 1.86s	remaining: 860ms
# 684:	learn: 0.0518130	total: 1.86s	remaining: 857ms
# 685:	learn: 0.0517495	total: 1.87s	remaining: 854ms
# 686:	learn: 0.0517092	total: 1.87s	remaining: 852ms
# 687:	learn: 0.0516545	total: 1.87s	remaining: 849ms
# 688:	learn: 0.0515955	total: 1.87s	remaining: 846ms
# 689:	learn: 0.0515061	total: 1.88s	remaining: 843ms
# 690:	learn: 0.0514560	total: 1.88s	remaining: 840ms
# 691:	learn: 0.0513953	total: 1.88s	remaining: 838ms
# 692:	learn: 0.0513920	total: 1.88s	remaining: 835ms
# 693:	learn: 0.0513252	total: 1.89s	remaining: 832ms
# 694:	learn: 0.0512813	total: 1.89s	remaining: 830ms
# 695:	learn: 0.0512251	total: 1.89s	remaining: 827ms
# 696:	learn: 0.0511522	total: 1.89s	remaining: 824ms
# 697:	learn: 0.0511006	total: 1.9s	remaining: 821ms
# 698:	learn: 0.0510425	total: 1.9s	remaining: 818ms
# 699:	learn: 0.0509632	total: 1.9s	remaining: 815ms
# 700:	learn: 0.0509173	total: 1.9s	remaining: 812ms
# 701:	learn: 0.0508831	total: 1.91s	remaining: 809ms
# 702:	learn: 0.0508453	total: 1.91s	remaining: 807ms
# 703:	learn: 0.0507639	total: 1.91s	remaining: 804ms
# 704:	learn: 0.0507046	total: 1.92s	remaining: 801ms
# 705:	learn: 0.0507015	total: 1.92s	remaining: 799ms
# 706:	learn: 0.0506696	total: 1.92s	remaining: 796ms
# 707:	learn: 0.0506354	total: 1.92s	remaining: 793ms
# 708:	learn: 0.0505948	total: 1.93s	remaining: 790ms
# 709:	learn: 0.0505516	total: 1.93s	remaining: 788ms
# 710:	learn: 0.0505491	total: 1.93s	remaining: 785ms
# 711:	learn: 0.0504650	total: 1.93s	remaining: 782ms
# 712:	learn: 0.0503960	total: 1.94s	remaining: 779ms
# 713:	learn: 0.0503345	total: 1.94s	remaining: 777ms
# 714:	learn: 0.0502755	total: 1.94s	remaining: 774ms
# 715:	learn: 0.0502233	total: 1.94s	remaining: 771ms
# 716:	learn: 0.0502203	total: 1.95s	remaining: 768ms
# 717:	learn: 0.0501634	total: 1.95s	remaining: 766ms
# 718:	learn: 0.0501118	total: 1.95s	remaining: 763ms
# 719:	learn: 0.0500537	total: 1.95s	remaining: 760ms
# 720:	learn: 0.0499950	total: 1.96s	remaining: 757ms
# 721:	learn: 0.0499004	total: 1.96s	remaining: 755ms
# 722:	learn: 0.0498515	total: 1.96s	remaining: 752ms
# 723:	learn: 0.0497950	total: 1.97s	remaining: 749ms
# 724:	learn: 0.0497572	total: 1.97s	remaining: 747ms
# 725:	learn: 0.0496944	total: 1.97s	remaining: 744ms
# 726:	learn: 0.0496450	total: 1.98s	remaining: 742ms
# 727:	learn: 0.0495668	total: 1.98s	remaining: 739ms
# 728:	learn: 0.0495632	total: 1.98s	remaining: 737ms
# 729:	learn: 0.0494970	total: 1.99s	remaining: 734ms
# 730:	learn: 0.0494333	total: 1.99s	remaining: 732ms
# 731:	learn: 0.0493514	total: 1.99s	remaining: 729ms
# 732:	learn: 0.0493031	total: 1.99s	remaining: 727ms
# 733:	learn: 0.0492572	total: 2s	remaining: 724ms
# 734:	learn: 0.0491722	total: 2s	remaining: 721ms
# 735:	learn: 0.0490898	total: 2s	remaining: 718ms
# 736:	learn: 0.0490447	total: 2s	remaining: 715ms
# 737:	learn: 0.0490076	total: 2.01s	remaining: 713ms
# 738:	learn: 0.0489371	total: 2.01s	remaining: 710ms
# 739:	learn: 0.0489112	total: 2.01s	remaining: 708ms
# 740:	learn: 0.0488307	total: 2.02s	remaining: 705ms
# 741:	learn: 0.0487839	total: 2.02s	remaining: 702ms
# 742:	learn: 0.0487252	total: 2.02s	remaining: 699ms
# 743:	learn: 0.0486635	total: 2.02s	remaining: 697ms
# 744:	learn: 0.0486138	total: 2.03s	remaining: 694ms
# 745:	learn: 0.0485616	total: 2.03s	remaining: 691ms
# 746:	learn: 0.0485170	total: 2.03s	remaining: 689ms
# 747:	learn: 0.0484620	total: 2.04s	remaining: 686ms
# 748:	learn: 0.0483894	total: 2.04s	remaining: 683ms
# 749:	learn: 0.0483264	total: 2.04s	remaining: 681ms
# 750:	learn: 0.0482801	total: 2.04s	remaining: 678ms
# 751:	learn: 0.0482365	total: 2.05s	remaining: 675ms
# 752:	learn: 0.0481925	total: 2.05s	remaining: 672ms
# 753:	learn: 0.0481203	total: 2.05s	remaining: 669ms
# 754:	learn: 0.0480639	total: 2.05s	remaining: 667ms
# 755:	learn: 0.0480386	total: 2.06s	remaining: 664ms
# 756:	learn: 0.0480249	total: 2.06s	remaining: 661ms
# 757:	learn: 0.0479791	total: 2.06s	remaining: 658ms
# 758:	learn: 0.0479602	total: 2.06s	remaining: 655ms
# 759:	learn: 0.0479103	total: 2.06s	remaining: 652ms
# 760:	learn: 0.0478496	total: 2.07s	remaining: 649ms
# 761:	learn: 0.0477826	total: 2.07s	remaining: 647ms
# 762:	learn: 0.0477452	total: 2.07s	remaining: 644ms
# 763:	learn: 0.0476929	total: 2.08s	remaining: 641ms
# 764:	learn: 0.0476377	total: 2.08s	remaining: 638ms
# 765:	learn: 0.0475853	total: 2.08s	remaining: 636ms
# 766:	learn: 0.0475462	total: 2.08s	remaining: 633ms
# 767:	learn: 0.0475396	total: 2.08s	remaining: 630ms
# 768:	learn: 0.0474874	total: 2.09s	remaining: 627ms
# 769:	learn: 0.0474338	total: 2.09s	remaining: 624ms
# 770:	learn: 0.0473795	total: 2.09s	remaining: 621ms
# 771:	learn: 0.0473433	total: 2.09s	remaining: 618ms
# 772:	learn: 0.0473131	total: 2.1s	remaining: 616ms
# 773:	learn: 0.0472868	total: 2.1s	remaining: 613ms
# 774:	learn: 0.0472565	total: 2.1s	remaining: 610ms
# 775:	learn: 0.0471924	total: 2.1s	remaining: 607ms
# 776:	learn: 0.0471455	total: 2.1s	remaining: 604ms
# 777:	learn: 0.0470777	total: 2.11s	remaining: 601ms
# 778:	learn: 0.0470427	total: 2.11s	remaining: 599ms
# 779:	learn: 0.0469948	total: 2.11s	remaining: 596ms
# 780:	learn: 0.0469339	total: 2.11s	remaining: 593ms
# 781:	learn: 0.0468716	total: 2.12s	remaining: 590ms
# 782:	learn: 0.0468199	total: 2.12s	remaining: 587ms
# 783:	learn: 0.0467587	total: 2.12s	remaining: 585ms
# 784:	learn: 0.0467246	total: 2.12s	remaining: 582ms
# 785:	learn: 0.0467219	total: 2.13s	remaining: 579ms
# 786:	learn: 0.0466931	total: 2.13s	remaining: 576ms
# 787:	learn: 0.0466781	total: 2.13s	remaining: 573ms
# 788:	learn: 0.0466253	total: 2.13s	remaining: 570ms
# 789:	learn: 0.0465764	total: 2.13s	remaining: 568ms
# 790:	learn: 0.0465097	total: 2.14s	remaining: 565ms
# 791:	learn: 0.0464610	total: 2.14s	remaining: 562ms
# 792:	learn: 0.0464556	total: 2.14s	remaining: 559ms
# 793:	learn: 0.0464109	total: 2.14s	remaining: 556ms
# 794:	learn: 0.0463598	total: 2.15s	remaining: 554ms
# 795:	learn: 0.0462952	total: 2.15s	remaining: 551ms
# 796:	learn: 0.0462601	total: 2.15s	remaining: 548ms
# 797:	learn: 0.0462232	total: 2.15s	remaining: 546ms
# 798:	learn: 0.0461635	total: 2.16s	remaining: 543ms
# 799:	learn: 0.0461575	total: 2.16s	remaining: 540ms
# 800:	learn: 0.0461295	total: 2.16s	remaining: 538ms
# 801:	learn: 0.0461171	total: 2.17s	remaining: 535ms
# 802:	learn: 0.0460603	total: 2.17s	remaining: 532ms
# 803:	learn: 0.0460452	total: 2.17s	remaining: 529ms
# 804:	learn: 0.0460133	total: 2.17s	remaining: 526ms
# 805:	learn: 0.0459819	total: 2.17s	remaining: 524ms
# 806:	learn: 0.0459598	total: 2.18s	remaining: 521ms
# 807:	learn: 0.0458998	total: 2.18s	remaining: 518ms
# 808:	learn: 0.0458546	total: 2.18s	remaining: 515ms
# 809:	learn: 0.0458112	total: 2.18s	remaining: 512ms
# 810:	learn: 0.0457919	total: 2.19s	remaining: 510ms
# 811:	learn: 0.0457545	total: 2.19s	remaining: 507ms
# 812:	learn: 0.0456944	total: 2.19s	remaining: 504ms
# 813:	learn: 0.0456475	total: 2.19s	remaining: 501ms
# 814:	learn: 0.0456329	total: 2.2s	remaining: 499ms
# 815:	learn: 0.0455937	total: 2.2s	remaining: 496ms
# 816:	learn: 0.0455401	total: 2.2s	remaining: 493ms
# 817:	learn: 0.0454871	total: 2.2s	remaining: 490ms
# 818:	learn: 0.0454577	total: 2.21s	remaining: 487ms
# 819:	learn: 0.0453966	total: 2.21s	remaining: 485ms
# 820:	learn: 0.0453362	total: 2.21s	remaining: 482ms
# 821:	learn: 0.0453015	total: 2.21s	remaining: 479ms
# 822:	learn: 0.0452580	total: 2.21s	remaining: 476ms
# 823:	learn: 0.0452020	total: 2.22s	remaining: 473ms
# 824:	learn: 0.0451575	total: 2.22s	remaining: 471ms
# 825:	learn: 0.0451153	total: 2.22s	remaining: 468ms
# 826:	learn: 0.0450672	total: 2.22s	remaining: 465ms
# 827:	learn: 0.0450318	total: 2.23s	remaining: 462ms
# 828:	learn: 0.0450059	total: 2.23s	remaining: 460ms
# 829:	learn: 0.0449614	total: 2.23s	remaining: 457ms
# 830:	learn: 0.0449266	total: 2.23s	remaining: 454ms
# 831:	learn: 0.0449100	total: 2.23s	remaining: 451ms
# 832:	learn: 0.0448805	total: 2.24s	remaining: 448ms
# 833:	learn: 0.0448012	total: 2.24s	remaining: 446ms
# 834:	learn: 0.0447334	total: 2.24s	remaining: 443ms
# 835:	learn: 0.0447215	total: 2.24s	remaining: 440ms
# 836:	learn: 0.0446973	total: 2.25s	remaining: 437ms
# 837:	learn: 0.0445995	total: 2.25s	remaining: 435ms
# 838:	learn: 0.0445933	total: 2.25s	remaining: 432ms
# 839:	learn: 0.0445870	total: 2.25s	remaining: 429ms
# 840:	learn: 0.0445540	total: 2.25s	remaining: 426ms
# 841:	learn: 0.0444914	total: 2.26s	remaining: 423ms
# 842:	learn: 0.0444396	total: 2.26s	remaining: 421ms
# 843:	learn: 0.0444074	total: 2.26s	remaining: 418ms
# 844:	learn: 0.0443798	total: 2.26s	remaining: 415ms
# 845:	learn: 0.0443464	total: 2.27s	remaining: 412ms
# 846:	learn: 0.0443442	total: 2.27s	remaining: 410ms
# 847:	learn: 0.0442897	total: 2.27s	remaining: 407ms
# 848:	learn: 0.0442592	total: 2.27s	remaining: 404ms
# 849:	learn: 0.0442211	total: 2.27s	remaining: 401ms
# 850:	learn: 0.0441663	total: 2.28s	remaining: 399ms
# 851:	learn: 0.0441376	total: 2.28s	remaining: 396ms
# 852:	learn: 0.0441063	total: 2.28s	remaining: 393ms
# 853:	learn: 0.0440443	total: 2.28s	remaining: 390ms
# 854:	learn: 0.0440061	total: 2.29s	remaining: 388ms
# 855:	learn: 0.0439797	total: 2.29s	remaining: 385ms
# 856:	learn: 0.0439774	total: 2.29s	remaining: 382ms
# 857:	learn: 0.0439479	total: 2.29s	remaining: 379ms
# 858:	learn: 0.0439453	total: 2.29s	remaining: 377ms
# 859:	learn: 0.0439025	total: 2.3s	remaining: 374ms
# 860:	learn: 0.0438677	total: 2.3s	remaining: 371ms
# 861:	learn: 0.0438038	total: 2.3s	remaining: 368ms
# 862:	learn: 0.0437761	total: 2.3s	remaining: 366ms
# 863:	learn: 0.0437426	total: 2.31s	remaining: 363ms
# 864:	learn: 0.0437330	total: 2.31s	remaining: 360ms
# 865:	learn: 0.0436791	total: 2.31s	remaining: 357ms
# 866:	learn: 0.0436469	total: 2.31s	remaining: 355ms
# 867:	learn: 0.0436069	total: 2.31s	remaining: 352ms
# 868:	learn: 0.0435499	total: 2.32s	remaining: 349ms
# 869:	learn: 0.0435072	total: 2.32s	remaining: 347ms
# 870:	learn: 0.0434529	total: 2.32s	remaining: 344ms
# 871:	learn: 0.0433932	total: 2.32s	remaining: 341ms
# 872:	learn: 0.0433632	total: 2.33s	remaining: 338ms
# 873:	learn: 0.0433154	total: 2.33s	remaining: 336ms
# 874:	learn: 0.0432618	total: 2.33s	remaining: 333ms
# 875:	learn: 0.0432248	total: 2.33s	remaining: 330ms
# 876:	learn: 0.0431918	total: 2.33s	remaining: 327ms
# 877:	learn: 0.0431575	total: 2.34s	remaining: 325ms
# 878:	learn: 0.0431253	total: 2.34s	remaining: 322ms
# 879:	learn: 0.0430795	total: 2.34s	remaining: 319ms
# 880:	learn: 0.0430645	total: 2.35s	remaining: 317ms
# 881:	learn: 0.0430201	total: 2.35s	remaining: 314ms
# 882:	learn: 0.0429768	total: 2.35s	remaining: 311ms
# 883:	learn: 0.0429303	total: 2.35s	remaining: 309ms
# 884:	learn: 0.0429022	total: 2.35s	remaining: 306ms
# 885:	learn: 0.0428804	total: 2.36s	remaining: 303ms
# 886:	learn: 0.0428538	total: 2.36s	remaining: 301ms
# 887:	learn: 0.0428040	total: 2.36s	remaining: 298ms
# 888:	learn: 0.0427741	total: 2.37s	remaining: 296ms
# 889:	learn: 0.0427564	total: 2.37s	remaining: 293ms
# 890:	learn: 0.0426898	total: 2.37s	remaining: 290ms
# 891:	learn: 0.0426533	total: 2.37s	remaining: 287ms
# 892:	learn: 0.0426167	total: 2.38s	remaining: 285ms
# 893:	learn: 0.0425739	total: 2.38s	remaining: 282ms
# 894:	learn: 0.0425350	total: 2.38s	remaining: 279ms
# 895:	learn: 0.0425058	total: 2.38s	remaining: 277ms
# 896:	learn: 0.0424500	total: 2.38s	remaining: 274ms
# 897:	learn: 0.0424198	total: 2.39s	remaining: 271ms
# 898:	learn: 0.0423847	total: 2.39s	remaining: 268ms
# 899:	learn: 0.0423315	total: 2.39s	remaining: 266ms
# 900:	learn: 0.0423186	total: 2.39s	remaining: 263ms
# 901:	learn: 0.0422853	total: 2.4s	remaining: 260ms
# 902:	learn: 0.0422671	total: 2.4s	remaining: 258ms
# 903:	learn: 0.0422241	total: 2.4s	remaining: 255ms
# 904:	learn: 0.0421892	total: 2.4s	remaining: 252ms
# 905:	learn: 0.0421549	total: 2.41s	remaining: 250ms
# 906:	learn: 0.0421494	total: 2.41s	remaining: 247ms
# 907:	learn: 0.0420847	total: 2.41s	remaining: 244ms
# 908:	learn: 0.0420406	total: 2.41s	remaining: 242ms
# 909:	learn: 0.0419931	total: 2.42s	remaining: 239ms
# 910:	learn: 0.0419218	total: 2.42s	remaining: 236ms
# 911:	learn: 0.0418966	total: 2.42s	remaining: 233ms
# 912:	learn: 0.0418625	total: 2.42s	remaining: 231ms
# 913:	learn: 0.0417967	total: 2.42s	remaining: 228ms
# 914:	learn: 0.0417403	total: 2.43s	remaining: 225ms
# 915:	learn: 0.0416959	total: 2.43s	remaining: 223ms
# 916:	learn: 0.0416639	total: 2.43s	remaining: 220ms
# 917:	learn: 0.0416547	total: 2.43s	remaining: 217ms
# 918:	learn: 0.0416481	total: 2.44s	remaining: 215ms
# 919:	learn: 0.0416135	total: 2.44s	remaining: 212ms
# 920:	learn: 0.0415924	total: 2.44s	remaining: 209ms
# 921:	learn: 0.0415559	total: 2.44s	remaining: 207ms
# 922:	learn: 0.0415174	total: 2.44s	remaining: 204ms
# 923:	learn: 0.0414619	total: 2.45s	remaining: 201ms
# 924:	learn: 0.0414107	total: 2.45s	remaining: 199ms
# 925:	learn: 0.0413965	total: 2.45s	remaining: 196ms
# 926:	learn: 0.0413553	total: 2.45s	remaining: 193ms
# 927:	learn: 0.0413122	total: 2.46s	remaining: 191ms
# 928:	learn: 0.0412785	total: 2.46s	remaining: 188ms
# 929:	learn: 0.0412750	total: 2.46s	remaining: 185ms
# 930:	learn: 0.0412296	total: 2.46s	remaining: 183ms
# 931:	learn: 0.0411898	total: 2.46s	remaining: 180ms
# 932:	learn: 0.0411404	total: 2.47s	remaining: 177ms
# 933:	learn: 0.0411387	total: 2.47s	remaining: 175ms
# 934:	learn: 0.0410842	total: 2.47s	remaining: 172ms
# 935:	learn: 0.0410615	total: 2.47s	remaining: 169ms
# 936:	learn: 0.0410223	total: 2.48s	remaining: 167ms
# 937:	learn: 0.0409836	total: 2.48s	remaining: 164ms
# 938:	learn: 0.0409806	total: 2.48s	remaining: 161ms
# 939:	learn: 0.0409428	total: 2.48s	remaining: 158ms
# 940:	learn: 0.0409347	total: 2.48s	remaining: 156ms
# 941:	learn: 0.0409314	total: 2.49s	remaining: 153ms
# 942:	learn: 0.0409097	total: 2.49s	remaining: 150ms
# 943:	learn: 0.0408917	total: 2.49s	remaining: 148ms
# 944:	learn: 0.0408488	total: 2.49s	remaining: 145ms
# 945:	learn: 0.0408132	total: 2.5s	remaining: 143ms
# 946:	learn: 0.0407838	total: 2.5s	remaining: 140ms
# 947:	learn: 0.0407682	total: 2.5s	remaining: 137ms
# 948:	learn: 0.0407451	total: 2.5s	remaining: 135ms
# 949:	learn: 0.0407061	total: 2.5s	remaining: 132ms
# 950:	learn: 0.0406695	total: 2.51s	remaining: 129ms
# 951:	learn: 0.0406229	total: 2.51s	remaining: 127ms
# 952:	learn: 0.0405882	total: 2.51s	remaining: 124ms
# 953:	learn: 0.0405480	total: 2.51s	remaining: 121ms
# 954:	learn: 0.0404941	total: 2.52s	remaining: 119ms
# 955:	learn: 0.0404177	total: 2.52s	remaining: 116ms
# 956:	learn: 0.0403810	total: 2.52s	remaining: 113ms
# 957:	learn: 0.0403296	total: 2.52s	remaining: 111ms
# 958:	learn: 0.0402950	total: 2.53s	remaining: 108ms
# 959:	learn: 0.0402921	total: 2.53s	remaining: 105ms
# 960:	learn: 0.0402587	total: 2.53s	remaining: 103ms
# 961:	learn: 0.0402232	total: 2.53s	remaining: 100ms
# 962:	learn: 0.0401860	total: 2.54s	remaining: 97.4ms
# 963:	learn: 0.0401844	total: 2.54s	remaining: 94.8ms
# 964:	learn: 0.0401599	total: 2.54s	remaining: 92.2ms
# 965:	learn: 0.0401247	total: 2.54s	remaining: 89.5ms
# 966:	learn: 0.0400806	total: 2.55s	remaining: 86.9ms
# 967:	learn: 0.0400466	total: 2.55s	remaining: 84.3ms
# 968:	learn: 0.0399911	total: 2.55s	remaining: 81.6ms
# 969:	learn: 0.0399623	total: 2.55s	remaining: 79ms
# 970:	learn: 0.0399269	total: 2.56s	remaining: 76.4ms
# 971:	learn: 0.0399008	total: 2.56s	remaining: 73.7ms
# 972:	learn: 0.0398697	total: 2.56s	remaining: 71.1ms
# 973:	learn: 0.0398499	total: 2.56s	remaining: 68.4ms
# 974:	learn: 0.0398257	total: 2.57s	remaining: 65.8ms
# 975:	learn: 0.0397682	total: 2.57s	remaining: 63.2ms
# 976:	learn: 0.0397151	total: 2.57s	remaining: 60.5ms
# 977:	learn: 0.0396584	total: 2.57s	remaining: 57.9ms
# 978:	learn: 0.0396565	total: 2.58s	remaining: 55.2ms
# 979:	learn: 0.0396211	total: 2.58s	remaining: 52.6ms
# 980:	learn: 0.0395940	total: 2.58s	remaining: 50ms
# 981:	learn: 0.0395604	total: 2.58s	remaining: 47.3ms
# 982:	learn: 0.0395259	total: 2.58s	remaining: 44.7ms
# 983:	learn: 0.0394803	total: 2.59s	remaining: 42.1ms
# 984:	learn: 0.0394343	total: 2.59s	remaining: 39.4ms
# 985:	learn: 0.0393934	total: 2.59s	remaining: 36.8ms
# 986:	learn: 0.0393407	total: 2.59s	remaining: 34.2ms
# 987:	learn: 0.0393143	total: 2.6s	remaining: 31.5ms
# 988:	learn: 0.0392680	total: 2.6s	remaining: 28.9ms
# 989:	learn: 0.0392274	total: 2.6s	remaining: 26.3ms
# 990:	learn: 0.0391898	total: 2.6s	remaining: 23.7ms
# 991:	learn: 0.0391362	total: 2.61s	remaining: 21ms
# 992:	learn: 0.0391348	total: 2.61s	remaining: 18.4ms
# 993:	learn: 0.0390873	total: 2.61s	remaining: 15.8ms
# 994:	learn: 0.0390586	total: 2.61s	remaining: 13.1ms
# 995:	learn: 0.0390347	total: 2.62s	remaining: 10.5ms
# 996:	learn: 0.0390169	total: 2.62s	remaining: 7.88ms
# 997:	learn: 0.0389831	total: 2.62s	remaining: 5.25ms
# 998:	learn: 0.0389288	total: 2.62s	remaining: 2.63ms
# 999:	learn: 0.0389001	total: 2.63s	remaining: 0us

# %%
submit_predict = cat.predict(test)
submit_predict = np.exp(submit_predict)

# %%
submit['SalePrice'] = submit_predict

# %%
submit.to_csv('submit_init_cat_boost.csv', index=False)

# %% [markdown]
# Reducing feature skewness actually slightly increased the Kaggle score.
