# %% [markdown]
# # Overall Result and Questions

# %% [markdown]
# One of the data checks I wanted to do was to compare whether the change in the x coordinate of the ball from the first frame to the last frame was the same as the playResult variable.
#
# As you can see below this analysis shows a significant variance between the reported play result and the actual movement of the ball along the x coordinate from the first frame to the last frame.
#
# So the questions I have are:
# 1. Is my assumption correct that the play result should equal the movement of the ball along the x coordinate from the first frame to the last frame?
# 2. If so, have I done this analysis correctly to find that answer?
# 3. If so, why would this situation of having variances this large occur?

# %% [markdown]
# # The Analysis

# %%
import pandas as pd
import numpy as np
pd.options.display.max_columns = None

# %% [markdown]
# For this comparison I'll need the playResult from the plays dataset. The best way I can see to track the ball across frames is to track where the ball carrier is at on the x coordinate in each frame. So I'll also need the plays dataset for the ballCarrierId information.
#
# To keep this simple, I'll just do this comparison for the first week. I'm assuming whatever I find will be reflected in the other 8 weeks.

# %%
plays = pd.read_csv('/kaggle/input/nfl-big-data-bowl-2024/plays.csv')
week1 = pd.read_csv('/kaggle/input/nfl-big-data-bowl-2024/tracking_week_1.csv')

# %%
plays
# Out:
#            gameId  playId  ballCarrierId ballCarrierDisplayName  \
# 0      2022100908    3537          48723           Parker Hesse
# 1      2022091103    3126          52457         Chase Claypool
# 2      2022091111    1148          42547          Darren Waller
# 3      2022100212    2007          46461             Mike Boone
# 4      2022091900    1372          47857       Devin Singletary
# ...           ...     ...            ...                    ...
# 12481  2022100204     123          43293        Ezekiel Elliott
# 12482  2022091200    3467          46189            Will Dissly
# 12483  2022101605    3371          44860              Joe Mixon
# 12484  2022100207    2777          52449        Jonathan Taylor
# 12485  2022102308     905          54572          Dameon Pierce
#
#                                          playDescription  quarter  down  \
# 0      (7:52) (Shotgun) M.Mariota pass short middle t...        4     1
# 1      (7:38) (Shotgun) C.Claypool right end to PIT 3...        4     1
# 2      (8:57) D.Carr pass short middle to D.Waller to...        2     2
# 3      (13:12) M.Boone left tackle to DEN 44 for 7 ya...        3     2
# 4      (8:33) D.Singletary right guard to TEN 32 for ...        2     1
# ...                                                  ...      ...   ...
# 12481  (13:31) E.Elliott right tackle to WAS 38 for 1...        1     1
# 12482  (6:08) G.Smith pass short right to W.Dissly to...        4     1
# 12483  (9:35) (Shotgun) J.Mixon left end to CIN 47 fo...        4     1
# 12484  (2:02) (Shotgun) J.Taylor up the middle to TEN...        3     1
# 12485  (12:51) C.Heck reported in as eligible.  D.Pie...        2     3
#
#        yardsToGo possessionTeam defensiveTeam yardlineSide  yardlineNumber  \
# 0             10            ATL            TB          ATL              41
# 1             10            PIT           CIN          PIT              34
# 2              5             LV           LAC           LV              30
# 3             10            DEN            LV          DEN              37
# 4             10            BUF           TEN          TEN              35
# ...          ...            ...           ...          ...             ...
# 12481         10            DAL           WAS          WAS              39
# 12482         10            SEA           DEN          SEA              30
# 12483         10            CIN            NO          CIN              41
# 12484         10            IND           TEN          TEN              34
# 12485          1            HOU            LV           LV              17
#
#       gameClock  preSnapHomeScore  preSnapVisitorScore passResult  passLength  \
# 0          7:52                21                    7          C         6.0
# 1          7:38                14                   20        NaN         NaN
# 2          8:57                10                    3          C        11.0
# 3         13:12                19                   16        NaN         NaN
# 4          8:33                 7                    7        NaN         NaN
# ...         ...               ...                  ...        ...         ...
# 12481     13:31                 0                    0        NaN         NaN
# 12482      6:08                17                   16          C         0.0
# 12483      9:35                26                   21        NaN         NaN
# 12484      2:02                17                   24        NaN         NaN
# 12485     12:51                 3                    0        NaN         NaN
#
#        penaltyYards  prePenaltyPlayResult  playResult playNullifiedByPenalty  \
# 0               NaN                     9           9                      N
# 1               NaN                     3           3                      N
# 2               NaN                    15          15                      N
# 3               NaN                     7           7                      N
# 4               NaN                     3           3                      N
# ...             ...                   ...         ...                    ...
# 12481           NaN                     1           1                      N
# 12482           NaN                     2           2                      N
# 12483           NaN                     6           6                      N
# 12484           NaN                    -2          -2                      N
# 12485           NaN                     3           3                      N
#
#        absoluteYardlineNumber offenseFormation  defendersInTheBox  \
# 0                          69          SHOTGUN                7.0
# 1                          76          SHOTGUN                7.0
# 2                          40           I_FORM                6.0
# 3                          47       SINGLEBACK                6.0
# 4                          75           I_FORM                7.0
# ...                       ...              ...                ...
# 12481                      49       SINGLEBACK                6.0
# 12482                      40       SINGLEBACK                7.0
# 12483                      69          SHOTGUN                6.0
# 12484                      44          SHOTGUN                6.0
# 12485                      27           I_FORM                8.0
#
#        passProbability  preSnapHomeTeamWinProbability  \
# 0             0.747284                       0.976785
# 1             0.416454                       0.160485
# 2             0.267933                       0.756661
# 3             0.592704                       0.620552
# 4             0.470508                       0.836290
# ...                ...                            ...
# 12481         0.577800                       0.638600
# 12482         0.298983                       0.615241
# 12483         0.639439                       0.667054
# 12484         0.518695                       0.410611
# 12485         0.101552                       0.726639
#
#        preSnapVisitorTeamWinProbability  homeTeamWinProbabilityAdded  \
# 0                              0.023215                    -0.006110
# 1                              0.839515                    -0.010865
# 2                              0.243339                    -0.037409
# 3                              0.379448                    -0.002451
# 4                              0.163710                     0.001053
# ...                                 ...                          ...
# 12481                          0.361400                    -0.011542
# 12482                          0.384759                    -0.025458
# 12483                          0.332946                    -0.005164
# 12484                          0.589389                    -0.046648
# 12485                          0.273361                    -0.015028
#
#        visitorTeamWinProbilityAdded  expectedPoints  expectedPointsAdded  \
# 0                          0.006110        2.360609             0.981955
# 1                          0.010865        1.733344            -0.263424
# 2                          0.037409        1.312855             1.133666
# 3                          0.002451        1.641006            -0.043580
# 4                         -0.001053        3.686428            -0.167903
# ...                             ...             ...                  ...
# 12481                      0.011542        3.642571            -0.504018
# 12482                      0.025458        1.434580            -0.444642
# 12483                      0.005164        2.115356             0.203819
# 12484                      0.046648        3.946232            -0.976039
# 12485                      0.015028        4.685974             0.251580
#
#       foulName1 foulName2  foulNFLId1  foulNFLId2
# 0           NaN       NaN         NaN         NaN
# 1           NaN       NaN         NaN         NaN
# 2           NaN       NaN         NaN         NaN
# 3           NaN       NaN         NaN         NaN
# 4           NaN       NaN         NaN         NaN
# ...         ...       ...         ...         ...
# 12481       NaN       NaN         NaN         NaN
# 12482       NaN       NaN         NaN         NaN
# 12483       NaN       NaN         NaN         NaN
# 12484       NaN       NaN         NaN         NaN
# 12485       NaN       NaN         NaN         NaN
#
# [12486 rows x 35 columns]

# %% [markdown]
# Since playId is "...not unique across games" I'll combine that column and gameId to create a new variable called gamePlayId to have a unique identifier for each play.

# %%
plays['gamePlayId'] = plays[['gameId', 'playId']].astype(str).apply(lambda x: ''.join(x), axis=1)
plays['gamePlayId'] = plays['gamePlayId'].astype('int64')

# %% [markdown]
# I'll do the same thing on the week1 dataset.

# %%
week1['gamePlayId'] = week1[['gameId', 'playId']].astype(str).apply(lambda x: ''.join(x), axis=1)
week1['gamePlayId'] = week1['gamePlayId'].astype('int64')

# %% [markdown]
# To only include the columns I need from the plays dataset to merge into the week1 dataset.

# %%
plays_merge = plays[['gamePlayId', 'ballCarrierId', 'playResult']]

# %%
plays_merge
# Out:
#            gamePlayId  ballCarrierId  playResult
# 0      20221009083537          48723           9
# 1      20220911033126          52457           3
# 2      20220911111148          42547          15
# 3      20221002122007          46461           7
# 4      20220919001372          47857           3
# ...               ...            ...         ...
# 12481   2022100204123          43293           1
# 12482  20220912003467          46189           2
# 12483  20221016053371          44860           6
# 12484  20221002072777          52449          -2
# 12485   2022102308905          54572           3
#
# [12486 rows x 3 columns]

# %%
week1 = pd.merge(week1, plays_merge, on=['gamePlayId'], how='left')

# %%
week1
# Out:
#              gameId  playId    nflId     displayName  frameId  \
# 0        2022090800      56  35472.0  Rodger Saffold        1
# 1        2022090800      56  35472.0  Rodger Saffold        2
# 2        2022090800      56  35472.0  Rodger Saffold        3
# 3        2022090800      56  35472.0  Rodger Saffold        4
# 4        2022090800      56  35472.0  Rodger Saffold        5
# ...             ...     ...      ...             ...      ...
# 1407434  2022091200    3826      NaN        football       49
# 1407435  2022091200    3826      NaN        football       50
# 1407436  2022091200    3826      NaN        football       51
# 1407437  2022091200    3826      NaN        football       52
# 1407438  2022091200    3826      NaN        football       53
#
#                                time  jerseyNumber      club playDirection  \
# 0        2022-09-08 20:24:05.200000          76.0       BUF          left
# 1        2022-09-08 20:24:05.299999          76.0       BUF          left
# 2        2022-09-08 20:24:05.400000          76.0       BUF          left
# 3        2022-09-08 20:24:05.500000          76.0       BUF          left
# 4        2022-09-08 20:24:05.599999          76.0       BUF          left
# ...                             ...           ...       ...           ...
# 1407434  2022-09-12 23:05:57.799999           NaN  football          left
# 1407435  2022-09-12 23:05:57.900000           NaN  football          left
# 1407436  2022-09-12 23:05:58.000000           NaN  football          left
# 1407437  2022-09-12 23:05:58.099999           NaN  football          left
# 1407438  2022-09-12 23:05:58.200000           NaN  football          left
#
#                  x      y     s     a   dis       o     dir         event  \
# 0        88.370000  27.27  1.62  1.15  0.16  231.74  147.90           NaN
# 1        88.470000  27.13  1.67  0.61  0.17  230.98  148.53  pass_arrived
# 2        88.560000  27.01  1.57  0.49  0.15  230.98  147.05           NaN
# 3        88.640000  26.90  1.44  0.89  0.14  232.38  145.42           NaN
# 4        88.720000  26.80  1.29  1.24  0.13  233.36  141.95           NaN
# ...            ...    ...   ...   ...   ...     ...     ...           ...
# 1407434  56.220001   9.89  2.56  1.25  0.25     NaN     NaN        tackle
# 1407435  56.060001  10.08  2.50  1.14  0.24     NaN     NaN           NaN
# 1407436  55.889999  10.27  2.38  1.70  0.25     NaN     NaN           NaN
# 1407437  55.730000  10.44  2.07  2.83  0.24     NaN     NaN           NaN
# 1407438  55.570000  10.57  1.86  3.00  0.20     NaN     NaN           NaN
#
#              gamePlayId  ballCarrierId  playResult
# 0          202209080056          42489           6
# 1          202209080056          42489           6
# 2          202209080056          42489           6
# 3          202209080056          42489           6
# 4          202209080056          42489           6
# ...                 ...            ...         ...
# 1407434  20220912003826          53464           9
# 1407435  20220912003826          53464           9
# 1407436  20220912003826          53464           9
# 1407437  20220912003826          53464           9
# 1407438  20220912003826          53464           9
#
# [1407439 rows x 20 columns]

# %% [markdown]
# In order to track where the ball is on any frame, I'll want to find each frame where the nflId is equal to the ballCarrierId. However, there are 61,193 rows where the nflId is 'NaN'. These correspond to where the displayName is 'football'. So for this exercise, I'll just fill the "NaN' nflId's with zeros.

# %%
week1['nflId'].isna().sum()
# Out:
# 61193

# %%
week1['displayName'].value_counts()
# Out:
# displayName
# football             61193
# Josh Allen            3280
# David Long            3261
# Jalen Pitre           2854
# Jonathan Owens        2854
#                      ...
# Keisean Nixon           20
# P.J. Locke              16
# Eric Johnson            15
# Jonathan Williams       14
# J.C. Hassenauer         13
# Name: count, Length: 1166, dtype: int64

# %%
week1['nflId'] = week1['nflId'].fillna(0)
week1['nflId'] = week1['nflId'].astype(int)

# %% [markdown]
# The new variable xBallLocation will be the x coordinate of that player where that player is the ball carrier. That should be the yard line the ball is on for each frame of a particular play.

# %%
week1['xBallLocation'] = np.where(week1['ballCarrierId'] == week1['nflId'], week1['x'], 0)

# %% [markdown]
# To identify the first and last frame of each play.

# %%
week1['firstFrame'] = week1.groupby('gamePlayId')['frameId'].transform('min')
week1['lastFrame'] = week1.groupby('gamePlayId')['frameId'].transform('max')

# %% [markdown]
# Next, I'll create the xFirstFrame and xLastFrame variables to identify where the ball location is on those frames. Then spread those values to all the plays on that frame, not just the ones that include the ball carrier.

# %%
week1['xFirstFrame'] = np.where(week1['frameId'] == week1['firstFrame'], week1['xBallLocation'], 0)
week1['xLastFrame'] = np.where(week1['frameId'] == week1['lastFrame'], week1['xBallLocation'], 0)

# %%
week1['xFirstFrame'] = week1.groupby('gamePlayId')['xFirstFrame'].transform(max)
week1['xLastFrame'] = week1.groupby('gamePlayId')['xLastFrame'].transform(max)

# %%
week1
# Out:
#              gameId  playId  nflId     displayName  frameId  \
# 0        2022090800      56  35472  Rodger Saffold        1
# 1        2022090800      56  35472  Rodger Saffold        2
# 2        2022090800      56  35472  Rodger Saffold        3
# 3        2022090800      56  35472  Rodger Saffold        4
# 4        2022090800      56  35472  Rodger Saffold        5
# ...             ...     ...    ...             ...      ...
# 1407434  2022091200    3826      0        football       49
# 1407435  2022091200    3826      0        football       50
# 1407436  2022091200    3826      0        football       51
# 1407437  2022091200    3826      0        football       52
# 1407438  2022091200    3826      0        football       53
#
#                                time  jerseyNumber      club playDirection  \
# 0        2022-09-08 20:24:05.200000          76.0       BUF          left
# 1        2022-09-08 20:24:05.299999          76.0       BUF          left
# 2        2022-09-08 20:24:05.400000          76.0       BUF          left
# 3        2022-09-08 20:24:05.500000          76.0       BUF          left
# 4        2022-09-08 20:24:05.599999          76.0       BUF          left
# ...                             ...           ...       ...           ...
# 1407434  2022-09-12 23:05:57.799999           NaN  football          left
# 1407435  2022-09-12 23:05:57.900000           NaN  football          left
# 1407436  2022-09-12 23:05:58.000000           NaN  football          left
# 1407437  2022-09-12 23:05:58.099999           NaN  football          left
# 1407438  2022-09-12 23:05:58.200000           NaN  football          left
#
#                  x      y     s     a   dis       o     dir         event  \
# 0        88.370000  27.27  1.62  1.15  0.16  231.74  147.90           NaN
# 1        88.470000  27.13  1.67  0.61  0.17  230.98  148.53  pass_arrived
# 2        88.560000  27.01  1.57  0.49  0.15  230.98  147.05           NaN
# 3        88.640000  26.90  1.44  0.89  0.14  232.38  145.42           NaN
# 4        88.720000  26.80  1.29  1.24  0.13  233.36  141.95           NaN
# ...            ...    ...   ...   ...   ...     ...     ...           ...
# 1407434  56.220001   9.89  2.56  1.25  0.25     NaN     NaN        tackle
# 1407435  56.060001  10.08  2.50  1.14  0.24     NaN     NaN           NaN
# 1407436  55.889999  10.27  2.38  1.70  0.25     NaN     NaN           NaN
# 1407437  55.730000  10.44  2.07  2.83  0.24     NaN     NaN           NaN
# 1407438  55.570000  10.57  1.86  3.00  0.20     NaN     NaN           NaN
#
#              gamePlayId  ballCarrierId  playResult  xBallLocation  firstFrame  \
# 0          202209080056          42489           6            0.0           1
# 1          202209080056          42489           6            0.0           1
# 2          202209080056          42489           6            0.0           1
# 3          202209080056          42489           6            0.0           1
# 4          202209080056          42489           6            0.0           1
# ...                 ...            ...         ...            ...         ...
# 1407434  20220912003826          53464           9            0.0           1
# 1407435  20220912003826          53464           9            0.0           1
# 1407436  20220912003826          53464           9            0.0           1
# 1407437  20220912003826          53464           9            0.0           1
# 1407438  20220912003826          53464           9            0.0           1
#
#          lastFrame  xFirstFrame  xLastFrame
# 0               22        80.60       79.51
# 1               22        80.60       79.51
# 2               22        80.60       79.51
# 3               22        80.60       79.51
# 4               22        80.60       79.51
# ...            ...          ...         ...
# 1407434         53        70.71       55.72
# 1407435         53        70.71       55.72
# 1407436         53        70.71       55.72
# 1407437         53        70.71       55.72
# 1407438         53        70.71       55.72
#
# [1407439 rows x 25 columns]

# %% [markdown]
# Finally, I'll create the xFrameChange variable to measure the change in the ball location from the first frame to the last frame. I'm using absolute values since many of the changes in the x coordinate might be negative numbers as the offensive team moves onto their opponent's side of the field (for example a 10 yard gain from their opponent's 35 yard line to their opponent's 25 yard line). I know this will create positive values for negative yard plays, but for this overall analysis, that shouldn't be a material problem.
#
# Additionally, I'll create a framePlayVariance variable to track the difference between the frame change and the play result.

# %%
week1['xFrameChange'] = (week1['xLastFrame'] - week1['xFirstFrame']).abs()
week1['framePlayVariance'] = week1['playResult'] - week1['xFrameChange']

# %%
week1
# Out:
#              gameId  playId  nflId     displayName  frameId  \
# 0        2022090800      56  35472  Rodger Saffold        1
# 1        2022090800      56  35472  Rodger Saffold        2
# 2        2022090800      56  35472  Rodger Saffold        3
# 3        2022090800      56  35472  Rodger Saffold        4
# 4        2022090800      56  35472  Rodger Saffold        5
# ...             ...     ...    ...             ...      ...
# 1407434  2022091200    3826      0        football       49
# 1407435  2022091200    3826      0        football       50
# 1407436  2022091200    3826      0        football       51
# 1407437  2022091200    3826      0        football       52
# 1407438  2022091200    3826      0        football       53
#
#                                time  jerseyNumber      club playDirection  \
# 0        2022-09-08 20:24:05.200000          76.0       BUF          left
# 1        2022-09-08 20:24:05.299999          76.0       BUF          left
# 2        2022-09-08 20:24:05.400000          76.0       BUF          left
# 3        2022-09-08 20:24:05.500000          76.0       BUF          left
# 4        2022-09-08 20:24:05.599999          76.0       BUF          left
# ...                             ...           ...       ...           ...
# 1407434  2022-09-12 23:05:57.799999           NaN  football          left
# 1407435  2022-09-12 23:05:57.900000           NaN  football          left
# 1407436  2022-09-12 23:05:58.000000           NaN  football          left
# 1407437  2022-09-12 23:05:58.099999           NaN  football          left
# 1407438  2022-09-12 23:05:58.200000           NaN  football          left
#
#                  x      y     s     a   dis       o     dir         event  \
# 0        88.370000  27.27  1.62  1.15  0.16  231.74  147.90           NaN
# 1        88.470000  27.13  1.67  0.61  0.17  230.98  148.53  pass_arrived
# 2        88.560000  27.01  1.57  0.49  0.15  230.98  147.05           NaN
# 3        88.640000  26.90  1.44  0.89  0.14  232.38  145.42           NaN
# 4        88.720000  26.80  1.29  1.24  0.13  233.36  141.95           NaN
# ...            ...    ...   ...   ...   ...     ...     ...           ...
# 1407434  56.220001   9.89  2.56  1.25  0.25     NaN     NaN        tackle
# 1407435  56.060001  10.08  2.50  1.14  0.24     NaN     NaN           NaN
# 1407436  55.889999  10.27  2.38  1.70  0.25     NaN     NaN           NaN
# 1407437  55.730000  10.44  2.07  2.83  0.24     NaN     NaN           NaN
# 1407438  55.570000  10.57  1.86  3.00  0.20     NaN     NaN           NaN
#
#              gamePlayId  ballCarrierId  playResult  xBallLocation  firstFrame  \
# 0          202209080056          42489           6            0.0           1
# 1          202209080056          42489           6            0.0           1
# 2          202209080056          42489           6            0.0           1
# 3          202209080056          42489           6            0.0           1
# 4          202209080056          42489           6            0.0           1
# ...                 ...            ...         ...            ...         ...
# 1407434  20220912003826          53464           9            0.0           1
# 1407435  20220912003826          53464           9            0.0           1
# 1407436  20220912003826          53464           9            0.0           1
# 1407437  20220912003826          53464           9            0.0           1
# 1407438  20220912003826          53464           9            0.0           1
#
#          lastFrame  xFirstFrame  xLastFrame  xFrameChange  framePlayVariance
# 0               22        80.60       79.51          1.09               4.91
# 1               22        80.60       79.51          1.09               4.91
# 2               22        80.60       79.51          1.09               4.91
# 3               22        80.60       79.51          1.09               4.91
# 4               22        80.60       79.51          1.09               4.91
# ...            ...          ...         ...           ...                ...
# 1407434         53        70.71       55.72         14.99              -5.99
# 1407435         53        70.71       55.72         14.99              -5.99
# 1407436         53        70.71       55.72         14.99              -5.99
# 1407437         53        70.71       55.72         14.99              -5.99
# 1407438         53        70.71       55.72         14.99              -5.99
#
# [1407439 rows x 27 columns]

# %% [markdown]
# # The Results

# %% [markdown]
# The first 15 plays show a significant variance between these two values.

# %%
play_yards = week1.groupby('gamePlayId').agg(
    PlayResult = ('playResult', max),
    FrameChange = ('xFrameChange', max),
    Variance = ('framePlayVariance', max)
    
    
).reset_index()

play_yards_sorted = play_yards.sort_values(by='gamePlayId')
play_yards_sorted.head(15)
# Out:
#       gamePlayId  PlayResult  FrameChange  Variance
# 0   202209080056           6         1.09      4.91
# 1   202209080080           7        11.47     -4.47
# 2   202209110057          11        18.24     -7.24
# 3   202209110078           6        13.94     -7.94
# 4   202209110185          -5         3.08     -8.08
# 5   202209110286           3         7.91     -4.91
# 6   202209110358           3         4.94     -1.94
# 7   202209110382           5         1.01      3.99
# 8   202209110458          -1         6.08     -7.08
# 9   202209110486          50        58.80     -8.80
# 10  202209110556           4         9.02     -5.02
# 11  202209110577           3         7.49     -4.49
# 12  202209110659           9         1.38      7.62
# 13  202209110683          12        20.15     -8.15
# 14  202209110768          19        27.25     -8.25

# %% [markdown]
# The average variances for all 16 games of the first week are also significant.

# %%
play_yards = week1.groupby('gameId').agg(
    PlayResult = ('playResult', 'mean'),
    FrameChange = ('xFrameChange', 'mean'),
    Variance = ('framePlayVariance', 'mean'),
    
).reset_index()

play_yards_sorted = play_yards.sort_values(by='gameId')
play_yards_sorted
# Out:
#         gameId  PlayResult  FrameChange  Variance
# 0   2022090800    6.730256     8.833769 -2.103513
# 1   2022091100    7.906611    12.334940 -4.428329
# 2   2022091101    8.269632    12.620509 -4.350877
# 3   2022091102    6.157533    10.326426 -4.168893
# 4   2022091103    6.678283     9.788816 -3.110533
# 5   2022091104    9.133441    13.444933 -4.311492
# 6   2022091105    6.612102    10.075265 -3.463163
# 7   2022091106    6.928593    10.088701 -3.160107
# 8   2022091107    5.617452     9.494224 -3.876773
# 9   2022091108    8.784129    14.063491 -5.279362
# 10  2022091109    7.673869    11.453685 -3.779816
# 11  2022091110    8.279684    11.329570 -3.049886
# 12  2022091111    6.893365     9.391789 -2.498424
# 13  2022091112    8.964060    11.674765 -2.710705
# 14  2022091113    5.854795    10.296985 -4.442190
# 15  2022091200    6.746162    11.579339 -4.833177
